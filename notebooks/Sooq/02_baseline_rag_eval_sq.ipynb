# %% [markdown]
# # Cell 1. 기본 경로 및 환경 설정

# %% [markdown]
# 사용하는 내부 모듈:
# src/utils/path_utils.py
# - find_project_root
#
# src/utils/file_utils.py
# - load_jsonl
#
# src/utils/eval_dataset_utils.py
# - load_json
# - save_json
# - create_and_save_eval_sample
#
# src/utils/progress_utils.py
# - ProgressLogger
# - progress_iter
# - log_step
#
# src/evaluation/rag_evaluator.py
# - RAGEvaluator
#
# 처음 실행할 때:
# FORCE_REBUILD_INDEX = True
#
# 다음부터 같은 청크와 같은 임베딩 모델을 재사용할 때:
# FORCE_REBUILD_INDEX = False
#
# 단, 아래를 바꾸면 반드시 FAISS를 다시 만들어야 합니다.
# section_chunks.jsonl 변경
# embedding_model 변경
# 청크 정제/청킹 방식 변경
#
# 그 경우:
# FORCE_REBUILD_INDEX = True

# %%
from pathlib import Path
import sys
import json
import pickle
import time
from typing import List, Dict, Any

import numpy as np
import pandas as pd

# 현재 노트북 위치:
# ?? ??? ??? notebooks/ ?? notebooks/Sooq/ ??? ?????
# Resolve project root from either notebooks/ or notebooks/Sooq/.
NOTEBOOK_DIR = Path.cwd().resolve()

PROJECT_ROOT = next(
    path for path in [NOTEBOOK_DIR, *NOTEBOOK_DIR.parents]
    if (path / "src").exists()
)

# Add project root before importing src modules.
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.chunking.hybrid_section_chunker import (
    create_section_chunks as create_chunks
)

from src.utils.path_utils import find_project_root
from src.utils.file_utils import load_jsonl
from src.utils.eval_dataset_utils import (
    load_json,
    save_json,
    create_and_save_eval_sample,
)
from src.utils.progress_utils import ProgressLogger, progress_iter, log_step
from src.evaluation.evaluator import RAGEvaluator

# 프로젝트 이름 기준으로 root 검증
PROJECT_ROOT = find_project_root("RFP-RAG-Extractor")

DATA_DIR = PROJECT_ROOT / "data"

# 01번 노트북에서 생성한 청크 파일
SECTION_CHUNK_PATH = DATA_DIR / "chunks" / "section" / "section_chunks.jsonl"

# 평가 데이터 경로
EVAL_DIR = DATA_DIR / "processed" / "eval"
EVAL_DATASET_PATH = EVAL_DIR / "eval_dataset.json"
EVAL_SAMPLE_PATH = EVAL_DIR / "eval_dataset_sample_20.json"

# 벡터 DB 저장 경로
VECTOR_DB_DIR = DATA_DIR / "vector_db"
BASELINE_VECTOR_DIR = VECTOR_DB_DIR / "baseline_section_kure_faiss"
BASELINE_VECTOR_DIR.mkdir(parents=True, exist_ok=True)

# RAG 실행 결과 저장 경로
RAG_OUTPUT_PATH = EVAL_DIR / "rag_outputs_baseline_section_sample_20.json"
RAG_OUTPUT_SCORED_PATH = EVAL_DIR / "rag_outputs_baseline_section_sample_20_scored.json"

# 평가 리포트 저장 경로
REPORT_DIR = PROJECT_ROOT / "reports" / "evaluation"
REPORT_DIR.mkdir(parents=True, exist_ok=True)

METRICS_PATH = REPORT_DIR / "baseline_section_sample20_metrics.json"
METRICS_BY_QTYPE_PATH = REPORT_DIR / "baseline_section_sample20_by_question_type.json"
METRICS_BY_SOURCE_TYPE_PATH = REPORT_DIR / "baseline_section_sample20_by_source_type.json"
METRICS_BY_ANSWER_FORMAT_PATH = REPORT_DIR / "baseline_section_sample20_by_answer_format.json"
METRICS_BY_FILE_TYPE_PATH = REPORT_DIR / "baseline_section_sample20_by_file_type.json"

RETRIEVAL_FAILURE_PATH = REPORT_DIR / "baseline_section_sample20_retrieval_failures.csv"
KEYWORD_FAILURE_PATH = REPORT_DIR / "baseline_section_sample20_keyword_failures.csv"
SUMMARY_CSV_PATH = REPORT_DIR / "baseline_section_sample20_summary.csv"

print("현재 작업 위치:", Path.cwd())
print("PROJECT_ROOT:", PROJECT_ROOT)
print("SECTION_CHUNK_PATH:", SECTION_CHUNK_PATH)
print("EVAL_DATASET_PATH:", EVAL_DATASET_PATH)
print("EVAL_SAMPLE_PATH:", EVAL_SAMPLE_PATH)
print("BASELINE_VECTOR_DIR:", BASELINE_VECTOR_DIR)
# Out:
# /home/user2/RFP-RAG-Extractor/.venv/lib/python3.12/site-packages/ranx/data_structures/report.py:202: SyntaxWarning: invalid escape sequence '\c'
#   + """\\begin{table*}[ht]\n\centering\n\caption{\nOverall effectiveness of the models.\nThe best results are highlighted in boldface.\nSuperscripts denote significant differences in """
# /home/user2/RFP-RAG-Extractor/.venv/lib/python3.12/site-packages/ranx/data_structures/report.py:204: SyntaxWarning: invalid escape sequence '\l'
#   + """ with $p \le """
# /home/user2/RFP-RAG-Extractor/.venv/lib/python3.12/site-packages/ranx/data_structures/report.py:211: SyntaxWarning: invalid escape sequence '\#'
#   + "\n\\textbf{\#}"
# /home/user2/RFP-RAG-Extractor/.venv/lib/python3.12/site-packages/ranx/data_structures/report.py:216: SyntaxWarning: invalid escape sequence '\m'
#   + " \\\\ \n\midrule"
# /home/user2/RFP-RAG-Extractor/.venv/lib/python3.12/site-packages/ranx/data_structures/report.py:246: SyntaxWarning: invalid escape sequence '\e'
#   "\\bottomrule\n\end{tabular}\n}\n\label{tab:results}\n\end{table*}"
# 현재 작업 위치: /home/user2/RFP-RAG-Extractor/notebooks/Sooq
# PROJECT_ROOT: /home/user2/RFP-RAG-Extractor
# SECTION_CHUNK_PATH: /home/user2/RFP-RAG-Extractor/data/chunks/section/section_chunks.jsonl
# EVAL_DATASET_PATH: /home/user2/RFP-RAG-Extractor/data/processed/eval/eval_dataset.json
# EVAL_SAMPLE_PATH: /home/user2/RFP-RAG-Extractor/data/processed/eval/eval_dataset_sample_20.json
# BASELINE_VECTOR_DIR: /home/user2/RFP-RAG-Extractor/data/vector_db/baseline_section_kure_faiss

# %% [markdown]
# # Cell 2. 베이스라인 설정

# %%
BASELINE_CONFIG = {
    "llm_model_name": "Qwen/Qwen2.5-1.5B-Instruct",
    "embedding_model_name": "nlpai-lab/KURE-v1",
    "vector_db": "FAISS",
    "chunking_strategy": "section",
    "top_k": 5,
    "sample_size": 20,
    "random_seed": 42,
    "max_new_tokens": 512,
    "temperature": 0.0,
    "do_sample": False,
}

# section_chunks.jsonl을 새로 만들었으면 True
# 이미 같은 청크로 FAISS 인덱스를 만들어뒀으면 False
FORCE_REBUILD_INDEX = True

BASELINE_CONFIG
# Out:
# {'llm_model_name': 'Qwen/Qwen2.5-1.5B-Instruct',
#  'embedding_model_name': 'nlpai-lab/KURE-v1',
#  'vector_db': 'FAISS',
#  'chunking_strategy': 'section',
#  'top_k': 5,
#  'sample_size': 20,
#  'random_seed': 42,
#  'max_new_tokens': 512,
#  'temperature': 0.0,
#  'do_sample': False}

# %% [markdown]
# # Cell 3. 평가 데이터셋 로드 및 샘플 n개 생성

# %%
if not EVAL_DATASET_PATH.exists():
    raise FileNotFoundError(
        f"평가 데이터셋이 없습니다: {EVAL_DATASET_PATH}"
    )

eval_dataset = load_json(EVAL_DATASET_PATH)

print("전체 평가 문항 수:", len(eval_dataset))
print(pd.Series([x.get("question_type") for x in eval_dataset]).value_counts())
# Out:
# 전체 평가 문항 수: 243
# llm_1          82
# llm_2          82
# fact_budget    79
# Name: count, dtype: int64

# %%
if EVAL_SAMPLE_PATH.exists():
    print("기존 샘플 평가셋 로드:", EVAL_SAMPLE_PATH)
    sample_eval_dataset = load_json(EVAL_SAMPLE_PATH)

else:
    print("샘플 평가셋 새로 생성:", EVAL_SAMPLE_PATH)
    sample_eval_dataset = create_and_save_eval_sample(
        input_path=EVAL_DATASET_PATH,
        output_path=EVAL_SAMPLE_PATH,
        sample_size=BASELINE_CONFIG["sample_size"],
        random_seed=BASELINE_CONFIG["random_seed"],
    )

print("샘플 문항 수:", len(sample_eval_dataset))
print(pd.Series([x.get("question_type") for x in sample_eval_dataset]).value_counts())

sample_eval_dataset[:2]
# Out:
# 기존 샘플 평가셋 로드: /home/user2/RFP-RAG-Extractor/data/processed/eval/eval_dataset_sample_20.json
# 샘플 문항 수: 20
# llm_2          8
# llm_1          7
# fact_budget    5
# Name: count, dtype: int64
# [{'qid': '20240330003_llm_1',
#   'question': '2024년 벤처확인종합관리시스템 기능 고도화 사업에서 고도화하거나 신규로 구축하는 주요 기능은 무엇인가요?',
#   'reference': '복수의결권주식의 발행 보고 업무처리 시스템 구축, 벤처기업법에 따라 부여된 스톡옵션(주식매수선택권)의 부여·취소·철회 신고 및 업무시스템 구축, 성과조건부주식교부계약(RS)의 신고 및 업무처리 시스템 구축 등 세 가지 기능의 구축 및 고도화이다.',
#   'required_keyword_groups': [['복수의결권주식', '복수 의결권'],
#    ['스톡옵션', '주식매수선택권', '스톡 옵션'],
#    ['성과조건부주식교부', '성과조건부주식교부계약', 'RS']],
#   'doc_id': '20240330003',
#   'question_type': 'llm_1',
#   'source_type': 'document',
#   'answer_format': 'list',
#   'source_row_id': 86,
#   'project_name': '2024년 벤처확인종합관리시스템 기능 고도화 용역사업 입찰공고',
#   'organization': '(사)벤처기업협회',
#   'file_name': '(사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .hwp',
#   'file_type': 'hwp'},
#  {'qid': '20240404154_fact_budget',
#   'question': "서울특별시에서 발주한 '2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 용역' 사업의 배정 예산은 얼마인가요?",
#   'reference': '493,763,000원 입니다.',
#   'required_keyword_groups': [['493,763,000원', '493763000원', '4억9천3백7십6만원']],
#   'doc_id': '20240404154',
#   'question_type': 'fact_budget',
#   'source_type': 'metadata',
#   'answer_format': 'money',
#   'source_row_id': 39,
#   'project_name': '2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 용역',
#   'organization': '서울특별시',
#   'file_name': '서울특별시_2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 용.pdf',
#   'file_type': 'pdf'}]

# %% [markdown]
# # Cell 4. section_chunks.jsonl 로드

# %%
if not SECTION_CHUNK_PATH.exists():
    raise FileNotFoundError(
        f"section_chunks.jsonl 파일이 없습니다: {SECTION_CHUNK_PATH}\n"
        "먼저 01_extract_clean_chunk.ipynb를 실행해서 청크를 생성해야 합니다."
    )

chunks = load_jsonl(SECTION_CHUNK_PATH)

print("로드된 청크 수:", len(chunks))
print("첫 번째 청크 keys:", chunks[0].keys())
chunks[0]
# Out:
# 로드된 청크 수: 14377
# 첫 번째 청크 keys: dict_keys(['chunk_id', 'doc_id', 'file_name', 'file_type', 'project_name', 'organization', 'chunking_strategy', 'section_title', 'section_path', 'text'])
# {'chunk_id': '20241001798_section_0024_00',
#  'doc_id': '20241001798',
#  'file_name': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp',
#  'file_type': 'hwp',
#  'project_name': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화',
#  'organization': '한영대학',
#  'chunking_strategy': 'section',
#  'section_title': '□ 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)',
#  'section_path': ['□ 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)'],
#  'text': '□ 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n\n2\n\n추진배경 및 필요성\n\n학사제도·제도개편과 연계하湯湷여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대\n\n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화\n\n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성\n\n3\n\n기대효과\n\n◦ 트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n\n◦ 교수자·학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n\n◦ 학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n\nII\n\n구축 방안\n\n1\n\n구축목표\n\n◦ 트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n\n(교과과정 개발에서 성적 이수까지)\n\n◦ 트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n\n(교육과정 / 수강신청 / 성적 / 학적관리 외)\n\n◦ 확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n\n◦ 다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n\n2\n\n구축일정\n\n❍ 구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n\n일 정\n\n내 용\n\n진 행 일 정\n\n비고\n\n구축\n\n안정화\n\nw1\n\nw2\n\nw3\n\nw4\n\nw5\n\nw6\n\nw7\n\nw8\n\nw9\n\nw10\n\nw11\n\nw12\n\n사업발주 및 착수\n\n※ 사업수행 이전\n\n분석\n\n-업무 분석\n\n구현'}

# %% [markdown]
# # Cell 5. 청크 필드 표준화

# %%
def get_chunk_text(chunk: Dict[str, Any]) -> str:
    for key in ["text", "page_content", "content", "chunk_text"]:
        value = chunk.get(key)
        if value:
            return str(value)
    return ""


def get_chunk_doc_id(chunk: Dict[str, Any]) -> str:
    if chunk.get("doc_id") is not None:
        return str(chunk["doc_id"])

    metadata = chunk.get("metadata", {}) or {}
    if metadata.get("doc_id") is not None:
        return str(metadata["doc_id"])

    return ""


def get_chunk_id(chunk: Dict[str, Any], idx: int) -> str:
    if chunk.get("chunk_id") is not None:
        return str(chunk["chunk_id"])

    metadata = chunk.get("metadata", {}) or {}
    if metadata.get("chunk_id") is not None:
        return str(metadata["chunk_id"])

    return f"chunk_{idx:06d}"


standard_chunks = []

for idx, chunk in enumerate(chunks):
    text = get_chunk_text(chunk)
    doc_id = get_chunk_doc_id(chunk)
    chunk_id = get_chunk_id(chunk, idx)

    if not text.strip():
        continue

    if not doc_id.strip():
        continue

    standard_chunks.append({
        **chunk,
        "chunk_id": chunk_id,
        "doc_id": doc_id,
        "text": text,
    })

print("표준화 전 청크 수:", len(chunks))
print("표준화 후 청크 수:", len(standard_chunks))

pd.DataFrame([
    {
        "chunk_id": x["chunk_id"],
        "doc_id": x["doc_id"],
        "file_type": x.get("file_type"),
        "text_len": len(x["text"]),
    }
    for x in standard_chunks[:5]
])
# Out:
# 표준화 전 청크 수: 14377
# 표준화 후 청크 수: 14377
#                       chunk_id       doc_id file_type  text_len
# 0  20241001798_section_0024_00  20241001798       hwp       746
# 1  20241001798_section_0036_00  20241001798       hwp       126
# 2  20241001798_section_0037_00  20241001798       hwp      1098
# 3  20241001798_section_0044_00  20241001798       hwp       780
# 4  20241001798_section_0057_00  20241001798       hwp       111

# %% [markdown]
# # Cell 6. 청크 통계 확인

# %%
chunk_stat_df = pd.DataFrame([
    {
        "chunk_id": chunk["chunk_id"],
        "doc_id": chunk["doc_id"],
        "file_type": chunk.get("file_type"),
        "chunking_strategy": chunk.get("chunking_strategy"),
        "text_len": len(chunk.get("text", "")),
    }
    for chunk in standard_chunks
])

print("청크 수:", len(chunk_stat_df))
display(chunk_stat_df["text_len"].describe())
display(chunk_stat_df.groupby("doc_id")["chunk_id"].count().describe())
display(chunk_stat_df["file_type"].value_counts(dropna=False))
# Out:
# 청크 수: 14377
# count    14377.000000
# mean       377.706893
# std        455.044028
# min        100.000000
# 25%        135.000000
# 50%        212.000000
# 75%        402.000000
# max       3000.000000
# Name: text_len, dtype: float64
# count    100.000000
# mean     143.770000
# std       63.107709
# min       50.000000
# 25%      104.750000
# 50%      128.000000
# 75%      165.000000
# max      481.000000
# Name: chunk_id, dtype: float64
# file_type
# hwp    13229
# pdf     1148
# Name: count, dtype: int64

# %% [markdown]
# # Cell 6. 임베딩 모델 로드

# %%
import os
import gc
import torch
from sentence_transformers import SentenceTransformer

# 1. PyTorch 가비지 세그먼트 수집 활성화 (단편화 해결)
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# 2. 임베딩 로드 전 미사용 메모리 및 캐시 즉시 비우기
gc.collect()
torch.cuda.empty_cache()

# 3. 모델 이름 변수 지정
embedding_model_name = "nlpai-lab/KURE-v1"

with log_step(f"Embedding model load: {embedding_model_name}"):
    try:
        # 우선 GPU(CUDA) 로드 시도
        embedding_model = SentenceTransformer(embedding_model_name)
        print("💡 GPU 메모리에 KURE-v1 로드 완료")
    except torch.cuda.OutOfMemoryError:
        # 만약 정리가 안 된 상태여서 OOM이 또 터지면 안전하게 CPU로 우회
        print("⚠️ GPU 메모리가 부족하여 CPU로 우회 로드합니다.")
        embedding_model = SentenceTransformer(embedding_model_name, device="cpu")

print("Embedding model loaded:", embedding_model_name)
# Out:
# [Embedding model load: nlpai-lab/KURE-v1] start
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/220 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/807 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/297 [00:00<?, ?B/s]
# 💡 GPU 메모리에 KURE-v1 로드 완료
# [Embedding model load: nlpai-lab/KURE-v1] done | elapsed=27s
# Embedding model loaded: nlpai-lab/KURE-v1

# %%
from sentence_transformers import SentenceTransformer

embedding_model_name = BASELINE_CONFIG["embedding_model_name"]

with log_step(f"Embedding model load: {embedding_model_name}"):
    embedding_model = SentenceTransformer(embedding_model_name)

print("Embedding model loaded:", embedding_model_name)
# Out:
# [Embedding model load: nlpai-lab/KURE-v1] start
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# [Embedding model load: nlpai-lab/KURE-v1] done | elapsed=4s
# Embedding model loaded: nlpai-lab/KURE-v1

# %% [markdown]
# # Cell 8. FAISS 인덱스 생성 함수

# %%
import faiss


def build_faiss_index(
    chunks: List[Dict[str, Any]],
    embedding_model: SentenceTransformer,
    batch_size: int = 32,
    log_every: int = 10,
):
    """
    청크 텍스트를 임베딩하고 FAISS IndexFlatIP 인덱스를 생성합니다.

    JupyterHub/GCP 환경에서 tqdm 렌더링 문제가 있을 수 있으므로
    ProgressLogger 기반으로 진행 상황을 출력합니다.
    """
    texts = [chunk["text"] for chunk in chunks]

    total = len(texts)
    num_batches = (total + batch_size - 1) // batch_size

    logger = ProgressLogger(
        total=num_batches,
        desc="Embedding batches",
        log_every=log_every,
        min_interval_sec=5.0,
    )

    all_embeddings = []

    logger.start()

    for start in range(0, total, batch_size):
        end = min(start + batch_size, total)
        batch_texts = texts[start:end]

        batch_embeddings = embedding_model.encode(
            batch_texts,
            batch_size=batch_size,
            show_progress_bar=False,
            convert_to_numpy=True,
            normalize_embeddings=True,
        )

        all_embeddings.append(batch_embeddings)

        logger.update(
            1,
            message=f"chunks={end}/{total}"
        )

    logger.done(message="embedding complete")

    embeddings = np.vstack(all_embeddings).astype("float32")

    dim = embeddings.shape[1]
    index = faiss.IndexFlatIP(dim)
    index.add(embeddings)

    print("FAISS index 생성 완료")
    print("embedding shape:", embeddings.shape)
    print("FAISS ntotal:", index.ntotal)

    return index, embeddings

# %% [markdown]
# # Cell 9. FAISS 인덱스 생성/로드

# %%
import gc
import torch
import faiss
import pickle

FAISS_INDEX_PATH = BASELINE_VECTOR_DIR / "index.faiss"
CHUNK_META_PATH = BASELINE_VECTOR_DIR / "chunks.pkl"
EMBEDDING_CONFIG_PATH = BASELINE_VECTOR_DIR / "config.json"

if (
    not FORCE_REBUILD_INDEX
    and FAISS_INDEX_PATH.exists()
    and CHUNK_META_PATH.exists()
):
    with log_step("FAISS index load"):
        index = faiss.read_index(str(FAISS_INDEX_PATH))

        with open(CHUNK_META_PATH, "rb") as f:
            indexed_chunks = pickle.load(f)

else:
    print("FAISS 인덱스 새로 생성")
    
    # 1. 인덱스 생성 직전, 이전에 쌓인 GPU 가비지 캐시를 한 번 더 완벽히 청소합니다.
    gc.collect()
    torch.cuda.empty_cache()

    # 2. OOM을 방지하기 위해 batch_size를 기존 32에서 8~16 정도로 낮추어 인덱스를 생성합니다.
    #    이렇게 하면 한 번에 GPU가 처리하는 양이 줄어들어 8GB 메모리에서도 안전하게 돌아갑니다.
    index, embeddings = build_faiss_index(
        chunks=standard_chunks,
        embedding_model=embedding_model,
        batch_size=8,  # 임베딩 중 OOM 방지를 위해 32 -> 8로 하향 조정
        log_every=10,
    )

    indexed_chunks = standard_chunks

    with log_step("FAISS index save"):
        faiss.write_index(index, str(FAISS_INDEX_PATH))

        with open(CHUNK_META_PATH, "wb") as f:
            pickle.dump(indexed_chunks, f)

        save_json(BASELINE_CONFIG, EMBEDDING_CONFIG_PATH)

    # 3. 큰 연산(인덱스 생성)이 끝난 후 사용이 끝난 대용량 embeddings 리스트 등을 메모리에서 해제합니다.
    if 'embeddings' in locals():
        del embeddings
    gc.collect()
    torch.cuda.empty_cache()

print("인덱스 청크 수:", len(indexed_chunks))
print("FAISS ntotal:", index.ntotal)
# Out:
# FAISS 인덱스 새로 생성
# [Embedding batches] start | total=1798
# [Embedding batches] 1/1798 (0.1%) | elapsed=0s | eta=16m 37s | chunks=8/14377
# [Embedding batches] 10/1798 (0.6%) | elapsed=3s | eta=10m 31s | chunks=80/14377
# [Embedding batches] 20/1798 (1.1%) | elapsed=7s | eta=10m 50s | chunks=160/14377
# [Embedding batches] 30/1798 (1.7%) | elapsed=10s | eta=10m 30s | chunks=240/14377
# [Embedding batches] 40/1798 (2.2%) | elapsed=11s | eta=8m 44s | chunks=320/14377
# [Embedding batches] 50/1798 (2.8%) | elapsed=15s | eta=8m 50s | chunks=400/14377
# [Embedding batches] 60/1798 (3.3%) | elapsed=20s | eta=9m 47s | chunks=480/14377
# [Embedding batches] 70/1798 (3.9%) | elapsed=24s | eta=10m 0s | chunks=560/14377
# [Embedding batches] 80/1798 (4.4%) | elapsed=27s | eta=9m 52s | chunks=640/14377
# [Embedding batches] 90/1798 (5.0%) | elapsed=31s | eta=9m 49s | chunks=720/14377
# [Embedding batches] 100/1798 (5.6%) | elapsed=34s | eta=9m 42s | chunks=800/14377
# [Embedding batches] 1700/1798 (94.5%) | elapsed=10m 25s | eta=36s | chunks=13600/14377
# [Embedding batches] 1710/1798 (95.1%) | elapsed=10m 31s | eta=32s | chunks=13680/14377
# [Embedding batches] 1720/1798 (95.7%) | elapsed=10m 33s | eta=28s | chunks=13760/14377
# [Embedding batches] 1730/1798 (96.2%) | elapsed=10m 37s | eta=25s | chunks=13840/14377
# [Embedding batches] 1737/1798 (96.6%) | elapsed=10m 42s | eta=22s | chunks=13896/14377
# [Embedding batches] 1740/1798 (96.8%) | elapsed=10m 43s | eta=21s | chunks=13920/14377
# [Embedding batches] 1750/1798 (97.3%) | elapsed=10m 48s | eta=17s | chunks=14000/14377
# [Embedding batches] 1760/1798 (97.9%) | elapsed=10m 51s | eta=14s | chunks=14080/14377
# [Embedding batches] 1770/1798 (98.4%) | elapsed=10m 56s | eta=10s | chunks=14160/14377
# [Embedding batches] 1780/1798 (99.0%) | elapsed=10m 59s | eta=6s | chunks=14240/14377
# [Embedding batches] 1790/1798 (99.6%) | elapsed=11m 2s | eta=2s | chunks=14320/14377
# [Embedding batches] 1798/1798 (100.0%) | elapsed=11m 5s | eta=0s | chunks=14377/14377
# [Embedding batches] done | elapsed=11m 5s | completed=1798/1798 | embedding complete
# FAISS index 생성 완료
# embedding shape: (14377, 1024)
# FAISS ntotal: 14377
# [FAISS index save] start
# [FAISS index save] done | elapsed=0s
# 인덱스 청크 수: 14377
# FAISS ntotal: 14377

# %%
FAISS_INDEX_PATH = BASELINE_VECTOR_DIR / "index.faiss"
CHUNK_META_PATH = BASELINE_VECTOR_DIR / "chunks.pkl"
EMBEDDING_CONFIG_PATH = BASELINE_VECTOR_DIR / "config.json"

if (
    not FORCE_REBUILD_INDEX
    and FAISS_INDEX_PATH.exists()
    and CHUNK_META_PATH.exists()
):
    with log_step("FAISS index load"):
        index = faiss.read_index(str(FAISS_INDEX_PATH))

        with open(CHUNK_META_PATH, "rb") as f:
            indexed_chunks = pickle.load(f)

else:
    print("FAISS 인덱스 새로 생성")

    index, embeddings = build_faiss_index(
        chunks=standard_chunks,
        embedding_model=embedding_model,
        batch_size=32,
        log_every=10,
    )

    indexed_chunks = standard_chunks

    with log_step("FAISS index save"):
        faiss.write_index(index, str(FAISS_INDEX_PATH))

        with open(CHUNK_META_PATH, "wb") as f:
            pickle.dump(indexed_chunks, f)

        save_json(BASELINE_CONFIG, EMBEDDING_CONFIG_PATH)

print("인덱스 청크 수:", len(indexed_chunks))
print("FAISS ntotal:", index.ntotal)
# Out:
# FAISS 인덱스 새로 생성
# [Embedding batches] start | total=450
# [Embedding batches] 1/450 (0.2%) | elapsed=4s | eta=32m 8s | chunks=32/14377
# [Embedding batches] 4/450 (0.9%) | elapsed=10s | eta=18m 52s | chunks=128/14377
# [Embedding batches] 6/450 (1.3%) | elapsed=15s | eta=19m 36s | chunks=192/14377
# [Embedding batches] 10/450 (2.2%) | elapsed=21s | eta=15m 46s | chunks=320/14377
# [Embedding batches] 12/450 (2.7%) | elapsed=27s | eta=16m 28s | chunks=384/14377
# [Embedding batches] 14/450 (3.1%) | elapsed=32s | eta=16m 45s | chunks=448/14377
# [Embedding batches] 403/450 (89.6%) | elapsed=16m 28s | eta=1m 55s | chunks=12896/14377
# [Embedding batches] 405/450 (90.0%) | elapsed=16m 38s | eta=1m 50s | chunks=12960/14377
# [Embedding batches] 406/450 (90.2%) | elapsed=16m 43s | eta=1m 48s | chunks=12992/14377
# [Embedding batches] 408/450 (90.7%) | elapsed=16m 51s | eta=1m 44s | chunks=13056/14377
# [Embedding batches] 410/450 (91.1%) | elapsed=16m 58s | eta=1m 39s | chunks=13120/14377
# [Embedding batches] 412/450 (91.6%) | elapsed=17m 6s | eta=1m 34s | chunks=13184/14377
# [Embedding batches] 414/450 (92.0%) | elapsed=17m 11s | eta=1m 29s | chunks=13248/14377
# [Embedding batches] 416/450 (92.4%) | elapsed=17m 20s | eta=1m 25s | chunks=13312/14377
# [Embedding batches] 418/450 (92.9%) | elapsed=17m 26s | eta=1m 20s | chunks=13376/14377
# [Embedding batches] 420/450 (93.3%) | elapsed=17m 34s | eta=1m 15s | chunks=13440/14377
# [Embedding batches] 424/450 (94.2%) | elapsed=17m 39s | eta=1m 4s | chunks=13568/14377
# [Embedding batches] 426/450 (94.7%) | elapsed=17m 45s | eta=1m 0s | chunks=13632/14377
# [Embedding batches] 428/450 (95.1%) | elapsed=17m 51s | eta=55s | chunks=13696/14377
# [Embedding batches] 430/450 (95.6%) | elapsed=17m 54s | eta=49s | chunks=13760/14377
# [Embedding batches] 433/450 (96.2%) | elapsed=18m 3s | eta=42s | chunks=13856/14377
# [Embedding batches] 435/450 (96.7%) | elapsed=18m 9s | eta=37s | chunks=13920/14377
# [Embedding batches] 438/450 (97.3%) | elapsed=18m 18s | eta=30s | chunks=14016/14377
# [Embedding batches] 440/450 (97.8%) | elapsed=18m 21s | eta=25s | chunks=14080/14377
# [Embedding batches] 442/450 (98.2%) | elapsed=18m 30s | eta=20s | chunks=14144/14377
# [Embedding batches] 445/450 (98.9%) | elapsed=18m 36s | eta=12s | chunks=14240/14377
# [Embedding batches] 447/450 (99.3%) | elapsed=18m 43s | eta=7s | chunks=14304/14377
# [Embedding batches] 450/450 (100.0%) | elapsed=18m 47s | eta=0s | chunks=14377/14377
# [Embedding batches] done | elapsed=18m 47s | completed=450/450 | embedding complete
# FAISS index 생성 완료
# embedding shape: (14377, 1024)
# FAISS ntotal: 14377
# [FAISS index save] start
# [FAISS index save] done | elapsed=0s
# 인덱스 청크 수: 14377
# FAISS ntotal: 14377

# %% [markdown]
# # Cell 10. 검색 함수 구현

# %%
def retrieve(
    query: str,
    top_k: int = 5,
) -> List[Dict[str, Any]]:
    """
    질문을 임베딩한 뒤 FAISS에서 top_k 청크를 검색합니다.

    반환 결과의 doc_id는 RAGEvaluator의 retrieval 평가에 사용됩니다.
    """
    query_emb = embedding_model.encode(
        [query],
        convert_to_numpy=True,
        normalize_embeddings=True,
        show_progress_bar=False,
    ).astype("float32")

    scores, indices = index.search(query_emb, top_k)

    results = []

    for rank, (score, idx) in enumerate(zip(scores[0], indices[0]), start=1):
        if idx < 0:
            continue

        chunk = indexed_chunks[int(idx)]

        results.append({
            "rank": rank,
            "score": float(score),
            "chunk_id": chunk.get("chunk_id"),
            "doc_id": chunk.get("doc_id"),
            "text": chunk.get("text", ""),
            "metadata": {
                k: v
                for k, v in chunk.items()
                if k not in {"text"}
            },
        })

    return results

# %%
# Cell 11. 검색 단일 테스트

# %%
test_question = sample_eval_dataset[0]["question"]
retrieved = retrieve(test_question, top_k=BASELINE_CONFIG["top_k"])

print("질문:", test_question)
print("정답 doc_id:", sample_eval_dataset[0]["doc_id"])
print()

for item in retrieved:
    print(
        item["rank"],
        item["score"],
        item["doc_id"],
        item["chunk_id"],
        item["text"][:100].replace("\n", " ")
    )
# Out:
# 질문: 2024년 벤처확인종합관리시스템 기능 고도화 사업에서 고도화하거나 신규로 구축하는 주요 기능은 무엇인가요?
# 정답 doc_id: 20240330003
#
# 1 0.6914679408073425 20240330003 20240330003_section_0550_00 □ 별지서식  <별지서식 1호> 2024년 벤처확인종합관리시스템 기능 고도화 용역사업 제안서 표지  <별지서식 2호> 제안요청서 수용 여부 참조표  <별지서식 3호> 일반현황 및
# 2 0.6390254497528076 20240330003 20240330003_section_0018_00 □ 추진체계  중소벤처기업부  벤처기업확인기관  (시스템 고도화 발주)  자문위원  (법률, 검수·검사 등)  사업 수행업체  벤처확인종합관리시스템 기능 고도화 수행  (복수의결권
# 3 0.6308194398880005 20240330003 20240330003_section_0019_00 □ 추진역할  구 분  역 할  중소벤처기업부  ᆞ사업총괄 운영ᆞ관리 감독  벤처기업확인기관  汤捯ᆞ벤처확인제도 운영기관  ᆞ사업계획 수립, 제안요청서 작성  ᆞ사업관리 및 검사
# 4 0.6127172112464905 20240330003 20240330003_section_0107_00 □ 요구사항 상세  가  기능 요구사항(System Function Requirement)  요구사항 고유번호  SFR-001  요구사항 분류  기능 요구사항  요구사항 명칭  사
# 5 0.6051326990127563 20240330003 20240330003_section_0551_00 □ 붙임자료  [붙임1] 청렴서약서  [붙임2] 근로자 권리보호 이행 서약서  [붙임3] 보안서약서  [붙임4] 정보화 용역사업 보안특약  [붙임5] 소프트웨어 개발사업의 적정 사

# %% [markdown]
# # Cell 12. Qwen LLM 로드

# %%
import os
import gc
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# 1. 메모리 단편화 방지 및 시스템 가비지 캐시 청소
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
gc.collect()
torch.cuda.empty_cache()

# 실제 검증 모델명 지정
llm_model_name = "Qwen/Qwen2.5-1.5B-Instruct"

print("CUDA 사용 가능:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# 2. log_step 의존성 제거 후 토크나이저 로드
print(f"[시작] Tokenizer load: {llm_model_name}")
tokenizer = AutoTokenizer.from_pretrained(
    llm_model_name,
    trust_remote_code=True,
)
print(f"[완료] Tokenizer loaded")

# 3. log_step 의존성 제거 후 LLM 모델 로드
print(f"[시작] LLM model load: {llm_model_name}")
model = AutoModelForCausalLM.from_pretrained(
    llm_model_name,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
    device_map="auto",
    low_cpu_mem_usage=True,  # 페이징 파일 부족 에러(1455) 방지
    trust_remote_code=True,
)
print(f"[완료] LLM model loaded")

model.eval()

# 4. 로드가 끝난 후 잔여 캐시 정리
gc.collect()
torch.cuda.empty_cache()

print("LLM loaded:", llm_model_name)
# Out:
# CUDA 사용 가능: True
# GPU: NVIDIA L4
# [시작] Tokenizer load: Qwen/Qwen2.5-1.5B-Instruct
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# [완료] Tokenizer loaded
# [시작] LLM model load: Qwen/Qwen2.5-1.5B-Instruct
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# [완료] LLM model loaded
# LLM loaded: Qwen/Qwen2.5-1.5B-Instruct

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

llm_model_name = BASELINE_CONFIG["llm_model_name"]

print("CUDA 사용 가능:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

with log_step(f"Tokenizer load: {llm_model_name}"):
    tokenizer = AutoTokenizer.from_pretrained(
        llm_model_name,
        trust_remote_code=True,
    )

with log_step(f"LLM model load: {llm_model_name}"):
    model = AutoModelForCausalLM.from_pretrained(
        llm_model_name,
        torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
        device_map="auto",
        trust_remote_code=True,
    )

model.eval()

print("LLM loaded:", llm_model_name)
# Out:
# CUDA 사용 가능: True
# GPU: NVIDIA L4
# [Tokenizer load: Qwen/Qwen2.5-1.5B-Instruct] start
# [Tokenizer load: Qwen/Qwen2.5-1.5B-Instruct] done | elapsed=0s
# [LLM model load: Qwen/Qwen2.5-1.5B-Instruct] start
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# [LLM model load: Qwen/Qwen2.5-1.5B-Instruct] done | elapsed=1s
# LLM loaded: Qwen/Qwen2.5-1.5B-Instruct

# %% [markdown]
# # Cell 13. RFP RAG 프롬프트 구성

# %%
def format_context(retrieved_chunks: List[Dict[str, Any]]) -> str:
    """
    검색된 청크들을 LLM 프롬프트에 넣을 context 문자열로 변환합니다.
    """
    context_blocks = []

    for item in retrieved_chunks:
        metadata = item.get("metadata", {})

        doc_id = item.get("doc_id", "")
        chunk_id = item.get("chunk_id", "")
        score = item.get("score", "")
        text = item.get("text", "")

        section_title = metadata.get("section_title", "")
        section_path = metadata.get("section_path", "")

        block = f"""
[문서 {item['rank']}]
doc_id: {doc_id}
chunk_id: {chunk_id}
score: {score}
section_title: {section_title}
section_path: {section_path}

{text}
""".strip()

        context_blocks.append(block)

    return "\n\n---\n\n".join(context_blocks)


def build_messages(
    question: str,
    retrieved_chunks: List[Dict[str, Any]]
) -> List[Dict[str, str]]:
    """
    Qwen Instruct 모델용 chat messages를 구성합니다.
    """
    context = format_context(retrieved_chunks)

    system_prompt = """
당신은 기업 및 정부 제안요청서(RFP)를 분석하는 전문 RAG Assistant입니다.
반드시 제공된 문서 내용에 근거해서만 답변하세요.

규칙:
1. 문서에 근거가 있는 내용만 답변하세요.
2. 문서에서 확인할 수 없는 내용은 추측하지 말고 "제공된 문서에서 확인할 수 없습니다."라고 답변하세요.
3. 질문이 예산, 기간, 계약방법, 담당자, 연락처처럼 정확한 값을 요구하면 값 중심으로 간결하게 답변하세요.
4. 질문이 사업범위, 추진목표, 기대효과처럼 목록형 답변을 요구하면 핵심 항목을 bullet로 정리하세요.
5. 가능하면 답변 마지막에 근거가 된 doc_id를 적으세요.
""".strip()

    user_prompt = f"""
아래는 검색된 RFP 문서 일부입니다.

[검색 문서]
{context}

[질문]
{question}

[답변]
""".strip()

    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt},
    ]

# %% [markdown]
# # Cell 14. LLM 답변 생성 함수

# %%
def generate_answer(
    question: str,
    retrieved_chunks: List[Dict[str, Any]],
    max_new_tokens: int = 512,
) -> Dict[str, Any]:
    """
    검색된 청크와 질문을 바탕으로 LLM 답변을 생성합니다.

    반환:
    - response
    - input_tokens
    - output_tokens
    - total_tokens
    - generation_latency_sec
    - prompt_text
    """
    messages = build_messages(question, retrieved_chunks)

    prompt_text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
    )

    inputs = tokenizer(
        prompt_text,
        return_tensors="pt",
    ).to(model.device)

    input_tokens = int(inputs["input_ids"].shape[-1])

    start_time = time.perf_counter()

    generation_kwargs = {
        **inputs,
        "max_new_tokens": max_new_tokens,
        "do_sample": BASELINE_CONFIG["do_sample"],
        "pad_token_id": tokenizer.eos_token_id,
    }

    if BASELINE_CONFIG["do_sample"]:
        generation_kwargs["temperature"] = BASELINE_CONFIG["temperature"]

    with torch.no_grad():
        outputs = model.generate(**generation_kwargs)

    generation_latency_sec = time.perf_counter() - start_time

    output_tokens = int(outputs.shape[-1] - inputs["input_ids"].shape[-1])

    generated_ids = outputs[0][inputs["input_ids"].shape[-1]:]

    response_text = tokenizer.decode(
        generated_ids,
        skip_special_tokens=True,
    ).strip()

    return {
        "response": response_text,
        "input_tokens": input_tokens,
        "output_tokens": output_tokens,
        "total_tokens": input_tokens + output_tokens,
        "generation_latency_sec": generation_latency_sec,
        "prompt_text": prompt_text,
    }

# %% [markdown]
# # Cell 15. 단일 RAG 실행 함수

# %%
def run_single_rag(
    eval_item: Dict[str, Any],
    top_k: int = 5,
) -> Dict[str, Any]:
    """
    평가 문항 1개에 대해:
    1. 검색
    2. LLM 답변 생성
    3. 평가에 필요한 결과 row 생성
    """
    question = eval_item["question"]

    start_total = time.perf_counter()

    start_retrieval = time.perf_counter()
    retrieved_chunks = retrieve(question, top_k=top_k)
    retrieval_latency_sec = time.perf_counter() - start_retrieval

    generation_result = generate_answer(
        question=question,
        retrieved_chunks=retrieved_chunks,
        max_new_tokens=BASELINE_CONFIG["max_new_tokens"],
    )

    total_latency_sec = time.perf_counter() - start_total

    retrieved_ids = [
        item.get("doc_id")
        for item in retrieved_chunks
        if item.get("doc_id") is not None
    ]

    retrieved_contexts = [
        item.get("text", "")
        for item in retrieved_chunks
    ]

    result = {
        **eval_item,
        "retrieved_ids": retrieved_ids,
        "retrieved_chunks": [
            {
                "rank": item["rank"],
                "score": item["score"],
                "doc_id": item["doc_id"],
                "chunk_id": item["chunk_id"],
                "text": item["text"][:1500],
            }
            for item in retrieved_chunks
        ],
        "retrieved_contexts": retrieved_contexts,
        "response": generation_result["response"],
        "retrieval_latency_sec": retrieval_latency_sec,
        "generation_latency_sec": generation_result["generation_latency_sec"],
        "total_latency_sec": total_latency_sec,
        "input_tokens": generation_result["input_tokens"],
        "output_tokens": generation_result["output_tokens"],
        "total_tokens": generation_result["total_tokens"],

        # 현재는 로컬 모델이므로 API 비용은 0으로 둡니다.
        # API 모델 실험 시 RAGEvaluator.attach_costs()로 비용 계산 가능.
        "estimated_cost": 0.0,
    }

    return result

# %%
# Cell 16. 단일 질문 테스트

# %%
test_item = sample_eval_dataset[0]

test_result = run_single_rag(
    test_item,
    top_k=BASELINE_CONFIG["top_k"],
)

print("Q:", test_result["question"])
print()
print("A:", test_result["response"])
print()
print("Reference:", test_result["reference"])
print()
print("정답 doc_id:", test_result["doc_id"])
print("retrieved_ids:", test_result["retrieved_ids"])
print("latency:", test_result["total_latency_sec"])
# Out:
# Q: 2024년 벤처확인종합관리시스템 기능 고도화 사업에서 고도화하거나 신규로 구축하는 주요 기능은 무엇인가요?
#
# A: 고도화 또는 신규 구축되는 주요 기능은 다음과 같습니다:
#
# 1. 복수의결권주식 신청자/창업주/대리인 확인절차 기능
# 2. 스톡옵션 신청자/부여(대상자) 확인절차 기능
# 3. 주민등록번호 미수집에 따른 대체 인증 방안 제시
# 4. 벤처확인종합관리시스템 회원통합을 위한 인증방안 제시 및 구현
# 5. 복수의결권주식, 스톡옵션 업무 담당자 인증
# 6. 중소벤처24 스톡옵션 신청자 회원통합 방안/기획 및 기능 구현
# 7. 중소벤처24 Easy Pass 연계
# 8. 벤처확인종합관리시스템을 통한 복수의결권주식, 스톡옵션 업무 담당자 회원가입
# 9. 중소기업확인서 발급정보 연동
# 10. 중소기업확인서 발급정보 연동 불가시 파일업로드
# 11. 복수의결권주식 발행보고 및 스톡옵션 부여신고 신청단계 중소기업 확인 기능 구현
# 12. 법인등록번호 기준 비상장 조회기능 구현
#
# Reference: 복수의결권주식의 발행 보고 업무처리 시스템 구축, 벤처기업법에 따라 부여된 스톡옵션(주식매수선택권)의 부여·취소·철회 신고 및 업무시스템 구축, 성과조건부주식교부계약(RS)의 신고 및 업무처리 시스템 구축 등 세 가지 기능의 구축 및 고도화이다.
#
# 정답 doc_id: 20240330003
# retrieved_ids: ['20240330003', '20240330003', '20240330003', '20240330003', '20240330003']
# latency: 11.29985991306603

# %% [markdown]
# # Cell 17. 샘플 20개 전체 RAG 실행

# %%
rag_outputs = []

for item in progress_iter(
    sample_eval_dataset,
    total=len(sample_eval_dataset),
    desc="Running baseline RAG",
    log_every=1,
    min_interval_sec=0.0,
):
    try:
        result = run_single_rag(
            item,
            top_k=BASELINE_CONFIG["top_k"],
        )
        rag_outputs.append(result)

    except Exception as e:
        error_result = {
            **item,
            "retrieved_ids": [],
            "retrieved_chunks": [],
            "retrieved_contexts": [],
            "response": "",
            "error": repr(e),
            "retrieval_latency_sec": 0.0,
            "generation_latency_sec": 0.0,
            "total_latency_sec": 0.0,
            "input_tokens": 0,
            "output_tokens": 0,
            "total_tokens": 0,
            "estimated_cost": 0.0,
        }
        rag_outputs.append(error_result)

save_json(rag_outputs, RAG_OUTPUT_PATH)

print("RAG 실행 결과 저장:", RAG_OUTPUT_PATH)
print("결과 수:", len(rag_outputs))
# Out:
# [Running baseline RAG] start | total=20
# [Running baseline RAG] 1/20 (5.0%) | elapsed=11s | eta=3m 29s
# [Running baseline RAG] 2/20 (10.0%) | elapsed=12s | eta=1m 49s
# [Running baseline RAG] 3/20 (15.0%) | elapsed=13s | eta=1m 17s
# [Running baseline RAG] 4/20 (20.0%) | elapsed=22s | eta=1m 28s
# [Running baseline RAG] 5/20 (25.0%) | elapsed=30s | eta=1m 31s
# [Running baseline RAG] 6/20 (30.0%) | elapsed=41s | eta=1m 37s
# [Running baseline RAG] 7/20 (35.0%) | elapsed=44s | eta=1m 22s
# [Running baseline RAG] 8/20 (40.0%) | elapsed=53s | eta=1m 19s
# [Running baseline RAG] 9/20 (45.0%) | elapsed=55s | eta=1m 7s
# [Running baseline RAG] 10/20 (50.0%) | elapsed=1m 0s | eta=1m 0s
# [Running baseline RAG] 11/20 (55.0%) | elapsed=1m 2s | eta=51s
# [Running baseline RAG] 12/20 (60.0%) | elapsed=1m 3s | eta=42s
# [Running baseline RAG] 13/20 (65.0%) | elapsed=1m 5s | eta=35s
# [Running baseline RAG] 14/20 (70.0%) | elapsed=1m 13s | eta=31s
# [Running baseline RAG] 15/20 (75.0%) | elapsed=1m 19s | eta=26s
# [Running baseline RAG] 16/20 (80.0%) | elapsed=1m 27s | eta=21s
# [Running baseline RAG] 17/20 (85.0%) | elapsed=1m 30s | eta=15s
# [Running baseline RAG] 18/20 (90.0%) | elapsed=1m 32s | eta=10s
# [Running baseline RAG] 19/20 (95.0%) | elapsed=1m 39s | eta=5s
# [Running baseline RAG] 20/20 (100.0%) | elapsed=1m 48s | eta=0s
# [Running baseline RAG] done | elapsed=1m 48s | completed=20/20
# RAG 실행 결과 저장: /home/user2/RFP-RAG-Extractor/data/processed/eval/rag_outputs_baseline_section_sample_20.json
# 결과 수: 20

# %%
# Cell 18. RAG 실행 결과 확인

# %%
rag_df = pd.DataFrame([
    {
        "qid": row.get("qid"),
        "doc_id": row.get("doc_id"),
        "question_type": row.get("question_type"),
        "response_len": len(row.get("response", "")),
        "retrieved_ids": row.get("retrieved_ids"),
        "total_latency_sec": row.get("total_latency_sec"),
        "input_tokens": row.get("input_tokens"),
        "output_tokens": row.get("output_tokens"),
        "error": row.get("error", ""),
    }
    for row in rag_outputs
])

display(rag_df)
print("에러 개수:", rag_df["error"].astype(bool).sum())
# Out:
#                         qid         doc_id question_type  response_len  \
# 0         20240330003_llm_1    20240330003         llm_1           414
# 1   20240404154_fact_budget    20240404154   fact_budget            31
# 2         20240408682_llm_1    20240408682         llm_1            54
# 3         20240414353_llm_2    20240414353         llm_2           394
# 4         20240420207_llm_2    20240420207         llm_2           376
# 5         20240430896_llm_1    20240430896         llm_1           547
# 6   20240430918_fact_budget    20240430918   fact_budget           119
# 7         20240430918_llm_2    20240430918         llm_2           378
# 8         20240531542_llm_1    20240531542         llm_1            65
# 9         20240624914_llm_2    20240624914         llm_2           195
# 10  20240723270_fact_budget    20240723270   fact_budget            86
# 11        20240903688_llm_1    20240903688         llm_1            68
# 12  20240904268_fact_budget    20240904268   fact_budget            44
# 13        20240910050_llm_1    20240910050         llm_1           345
# 14        20240910050_llm_2    20240910050         llm_2           244
# 15        20240925413_llm_2    20240925413         llm_2           315
# 16  20241118572_fact_budget    20241118572   fact_budget            87
# 17        20241138828_llm_2    20241138828         llm_2            91
# 18        20241213403_llm_2    20241213403         llm_2           279
# 19      R25BK00601569_llm_1  R25BK00601569         llm_1           457
#
#                                         retrieved_ids  total_latency_sec  \
# 0   [20240330003, 20240330003, 20240330003, 202403...          11.048215
# 1   [20240404154, 20240404154, 20240404154, 202404...           1.094956
# 2   [20240408682, 20241030067, 20240408682, DOC_00...           1.524129
# 3   [20240404154, DOC_0012, 20240605366, 202404041...           8.553412
# 4   [DOC_0012, 20240541684, DOC_0049, DOC_0024, DO...           8.152413
# 5   [20240430918, 20240413838, R25BK00603533, 2024...          11.596221
# 6   [20240430918, 20240430918, 20240430918, 202404...           2.459207
# 7   [R25BK00604826, 20240414353, 20240419826, 2024...           8.902027
# 8   [20240623903, 20240331766, 20241130016, 202411...           1.830655
# 9   [20240925413, DOC_0046, 20240904268, R25BK0056...           4.925461
# 10  [20240812818, 20240815487, 20240723270, 202407...           2.297288
# 11  [20240541684, 20240539319, 20240541684, 202404...           1.229963
# 12  [20241217596, 20241002912, 20240539319, DOC_00...           1.410204
# 13  [20240910050, 20240910050, 20240910050, 202409...           8.311586
# 14  [20241138828, 20240430918, 20240531285, DOC_00...           5.916551
# 15  [20241118572, 20240910050, 20240419826, 202406...           8.645357
# 16  [20241118572, 20241118572, 20241118572, 202411...           2.504888
# 17  [20241138828, DOC_0013, R25BK00564730, DOC_002...           2.563458
# 18  [20240903688, DOC_0007, 20240420207, 202405416...           6.419139
# 19  [20240624914, 20240524568, 20240605366, 202404...           9.321453
#
#     input_tokens  output_tokens error
# 0           2195            317
# 1           2701             26
# 2           2429             39
# 3           1611            244
# 4           1385            233
# 5           1779            329
# 6           3713             62
# 7           2769            248
# 8           1560             50
# 9           1362            140
# 10          2343             61
# 11          2818             29
# 12          1629             38
# 13          2085            233
# 14          1555            167
# 15          5703            232
# 16          5571             59
# 17          1368             71
# 18          1414            180
# 19          1600            266
# 에러 개수: 0

# %%
# Cell 19. RAGEvaluator 생성

# %%
evaluator = RAGEvaluator(
    auto_download_nltk=False,
    use_nltk_tokenizer=False,
)

print("RAGEvaluator ready")
# Out:
# RAGEvaluator ready

# %% [markdown]
# # Cell 20. 전체 평가 실행

# %%
with log_step("Evaluate all metrics"):
    metrics = evaluator.evaluate_all(
        rag_outputs,
        k=BASELINE_CONFIG["top_k"],
    )

metrics
# Out:
# [Evaluate all metrics] start
# /home/user2/RFP-RAG-Extractor/.venv/lib/python3.12/site-packages/ranx/metrics/hits.py:41: NumbaTypeSafetyWarning: unsafe cast from uint64 to int64. Precision may be lost.
#   scores[i] = _hits(qrels[i], run[i], k, rel_lvl)
# [Evaluate all metrics] done | elapsed=42s
# {'hits@5': np.float64(0.45),
#  'precision@5': np.float64(0.09),
#  'recall@5': np.float64(0.45),
#  'mrr@5': np.float64(0.37666666666666665),
#  'retrieval_eval_count': 20,
#  'retrieval_eval_skipped_count': 0,
#  'avg_bleu': 0.006466982676252725,
#  'avg_rougeL': 0.19023809523809523,
#  'avg_token_f1': 0.07990977756504654,
#  'avg_keyword_group_recall': 0.39,
#  'exact_keyword_group_match_rate': 0.15,
#  'avg_matched_keyword_groups': 1.25,
#  'avg_total_keyword_groups': 2.9,
#  'avg_retrieval_latency_sec': 0.028883940196828918,
#  'avg_generation_latency_sec': 5.398221446468961,
#  'avg_total_latency_sec': 5.435329196596285,
#  'p50_total_latency_sec': 5.9165510579478,
#  'p95_total_latency_sec': 11.048214606009424,
#  'avg_input_tokens': 2379.5,
#  'avg_output_tokens': 151.2,
#  'avg_total_tokens': 2530.7,
#  'total_tokens': 50614.0,
#  'avg_cost_per_query': 0.0,
#  'total_cost': 0.0}

# %% [markdown]
# # Cell 21. 질문 유형별 평가

# %%
with log_step("Evaluate by question_type"):
    metrics_by_question_type = evaluator.evaluate_by_group(
        rag_outputs,
        group_key="question_type",
        k=BASELINE_CONFIG["top_k"],
    )

metrics_by_question_type
# Out:
# [Evaluate by question_type] start
# [Evaluate by question_type] done | elapsed=18s
# {'llm_1': {'hits@5': np.float64(0.42857142857142855),
#   'precision@5': np.float64(0.08571428571428573),
#   'recall@5': np.float64(0.42857142857142855),
#   'mrr@5': np.float64(0.42857142857142855),
#   'retrieval_eval_count': 7,
#   'retrieval_eval_skipped_count': 0,
#   'avg_bleu': 0.011139991046037575,
#   'avg_rougeL': 0.11904761904761904,
#   'avg_token_f1': 0.10046170442286947,
#   'avg_keyword_group_recall': 0.5833333333333333,
#   'exact_keyword_group_match_rate': 0.2857142857142857,
#   'avg_matched_keyword_groups': 1.5714285714285714,
#   'avg_total_keyword_groups': 3.2857142857142856,
#   'avg_retrieval_latency_sec': 0.028185545865978514,
#   'avg_generation_latency_sec': 6.373520184158614,
#   'avg_total_latency_sec': 6.408888872845897,
#   'p50_total_latency_sec': 8.311586322961375,
#   'p95_total_latency_sec': 11.596220765030012,
#   'avg_input_tokens': 2066.5714285714284,
#   'avg_output_tokens': 180.42857142857142,
#   'avg_total_tokens': 2247.0,
#   'total_tokens': 15729.0,
#   'avg_cost_per_query': 0.0,
#   'total_cost': 0.0,
#   'num_rows': 7},
#  'fact_budget': {'hits@5': np.float64(1.0),
#   'precision@5': np.float64(0.2),
#   'recall@5': np.float64(1.0),
#   'mrr@5': np.float64(0.7066666666666668),
#   'retrieval_eval_count': 5,
#   'retrieval_eval_skipped_count': 0,
#   'avg_bleu': 0.0,
#   'avg_rougeL': 0.29333333333333333,
#   'avg_token_f1': 0.0,
#   'avg_keyword_group_recall': 0.0,
#   'exact_keyword_group_match_rate': 0.0,
#   'avg_matched_keyword_groups': 0.0,
#   'avg_total_keyword_groups': 1.0,
#   'avg_retrieval_latency_sec': 0.02915457377675921,
#   'avg_generation_latency_sec': 1.913479449832812,
#   'avg_total_latency_sec': 1.9533087119925767,
#   'p50_total_latency_sec': 2.2972882270114496,
#   'p95_total_latency_sec': 2.5048875600332394,
#   'avg_input_tokens': 3191.4,
#   'avg_output_tokens': 49.2,
#   'avg_total_tokens': 3240.6,
#   'total_tokens': 16203.0,
#   'avg_cost_per_query': 0.0,
#   'total_cost': 0.0,
#   'num_rows': 5},
#  'llm_2': {'hits@5': np.float64(0.125),
#   'precision@5': np.float64(0.025),
#   'recall@5': np.float64(0.125),
#   'mrr@5': np.float64(0.125),
#   'retrieval_eval_count': 8,
#   'retrieval_eval_skipped_count': 0,
#   'avg_bleu': 0.006419964525348935,
#   'avg_rougeL': 0.1880952380952381,
#   'avg_token_f1': 0.11187045254260555,
#   'avg_keyword_group_recall': 0.46458333333333335,
#   'exact_keyword_group_match_rate': 0.125,
#   'avg_matched_keyword_groups': 1.75,
#   'avg_total_keyword_groups': 3.75,
#   'avg_retrieval_latency_sec': 0.029325889248866588,
#   'avg_generation_latency_sec': 6.722798798888107,
#   'avg_total_latency_sec': 6.759727282755193,
#   'p50_total_latency_sec': 8.152413332951255,
#   'p95_total_latency_sec': 8.902026936993934,
#   'avg_input_tokens': 2145.875,
#   'avg_output_tokens': 189.375,
#   'avg_total_tokens': 2335.25,
#   'total_tokens': 18682.0,
#   'avg_cost_per_query': 0.0,
#   'total_cost': 0.0,
#   'num_rows': 8}}

# %%
evaluator.save_metrics(
    metrics_by_question_type,
    str(METRICS_BY_QTYPE_PATH),
)
# Out:
# 평가 결과 저장 완료: /home/user2/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_by_question_type.json

# %% [markdown]
# # Cell 22. source_type / answer_format / file_type별 평가

# %%
with log_step("Evaluate by source_type"):
    metrics_by_source_type = evaluator.evaluate_by_group(
        rag_outputs,
        group_key="source_type",
        k=BASELINE_CONFIG["top_k"],
    )

with log_step("Evaluate by answer_format"):
    metrics_by_answer_format = evaluator.evaluate_by_group(
        rag_outputs,
        group_key="answer_format",
        k=BASELINE_CONFIG["top_k"],
    )

with log_step("Evaluate by file_type"):
    metrics_by_file_type = evaluator.evaluate_by_group(
        rag_outputs,
        group_key="file_type",
        k=BASELINE_CONFIG["top_k"],
    )

metrics_by_source_type, metrics_by_answer_format, metrics_by_file_type
# Out:
# [Evaluate by source_type] start
# [Evaluate by source_type] done | elapsed=0s
# [Evaluate by answer_format] start
# [Evaluate by answer_format] done | elapsed=0s
# [Evaluate by file_type] start
# [Evaluate by file_type] done | elapsed=0s
# ({'document': {'hits@5': np.float64(0.26666666666666666),
#    'precision@5': np.float64(0.05333333333333334),
#    'recall@5': np.float64(0.26666666666666666),
#    'mrr@5': np.float64(0.26666666666666666),
#    'retrieval_eval_count': 15,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.008622643568336967,
#    'avg_rougeL': 0.15587301587301589,
#    'avg_token_f1': 0.10654637008672871,
#    'avg_keyword_group_recall': 0.52,
#    'exact_keyword_group_match_rate': 0.2,
#    'avg_matched_keyword_groups': 1.6666666666666667,
#    'avg_total_keyword_groups': 3.533333333333333,
#    'avg_retrieval_latency_sec': 0.02879372900351882,
#    'avg_generation_latency_sec': 6.559802112014343,
#    'avg_total_latency_sec': 6.5960026914641885,
#    'p50_total_latency_sec': 8.152413332951255,
#    'p95_total_latency_sec': 11.048214606009424,
#    'avg_input_tokens': 2108.866666666667,
#    'avg_output_tokens': 185.2,
#    'avg_total_tokens': 2294.0666666666666,
#    'total_tokens': 34411.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 15},
#   'metadata': {'hits@5': np.float64(1.0),
#    'precision@5': np.float64(0.2),
#    'recall@5': np.float64(1.0),
#    'mrr@5': np.float64(0.7066666666666668),
#    'retrieval_eval_count': 5,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.0,
#    'avg_rougeL': 0.29333333333333333,
#    'avg_token_f1': 0.0,
#    'avg_keyword_group_recall': 0.0,
#    'exact_keyword_group_match_rate': 0.0,
#    'avg_matched_keyword_groups': 0.0,
#    'avg_total_keyword_groups': 1.0,
#    'avg_retrieval_latency_sec': 0.02915457377675921,
#    'avg_generation_latency_sec': 1.913479449832812,
#    'avg_total_latency_sec': 1.9533087119925767,
#    'p50_total_latency_sec': 2.2972882270114496,
#    'p95_total_latency_sec': 2.5048875600332394,
#    'avg_input_tokens': 3191.4,
#    'avg_output_tokens': 49.2,
#    'avg_total_tokens': 3240.6,
#    'total_tokens': 16203.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 5}},
#  {'list': {'hits@5': np.float64(0.2),
#    'precision@5': np.float64(0.04),
#    'recall@5': np.float64(0.2),
#    'mrr@5': np.float64(0.2),
#    'retrieval_eval_count': 10,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.0034677959803375105,
#    'avg_rougeL': 0.03333333333333333,
#    'avg_token_f1': 0.08049390473730851,
#    'avg_keyword_group_recall': 0.4383333333333333,
#    'exact_keyword_group_match_rate': 0.2,
#    'avg_matched_keyword_groups': 1.5,
#    'avg_total_keyword_groups': 3.8,
#    'avg_retrieval_latency_sec': 0.029140077205374836,
#    'avg_generation_latency_sec': 7.882612343609798,
#    'avg_total_latency_sec': 7.919431033486035,
#    'p50_total_latency_sec': 8.311586322961375,
#    'p95_total_latency_sec': 11.596220765030012,
#    'avg_input_tokens': 2214.5,
#    'avg_output_tokens': 223.0,
#    'avg_total_tokens': 2437.5,
#    'total_tokens': 24375.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 10},
#   'money': {'hits@5': np.float64(1.0),
#    'precision@5': np.float64(0.2),
#    'recall@5': np.float64(1.0),
#    'mrr@5': np.float64(0.7066666666666668),
#    'retrieval_eval_count': 5,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.0,
#    'avg_rougeL': 0.29333333333333333,
#    'avg_token_f1': 0.0,
#    'avg_keyword_group_recall': 0.0,
#    'exact_keyword_group_match_rate': 0.0,
#    'avg_matched_keyword_groups': 0.0,
#    'avg_total_keyword_groups': 1.0,
#    'avg_retrieval_latency_sec': 0.02915457377675921,
#    'avg_generation_latency_sec': 1.913479449832812,
#    'avg_total_latency_sec': 1.9533087119925767,
#    'p50_total_latency_sec': 2.2972882270114496,
#    'p95_total_latency_sec': 2.5048875600332394,
#    'avg_input_tokens': 3191.4,
#    'avg_output_tokens': 49.2,
#    'avg_total_tokens': 3240.6,
#    'total_tokens': 16203.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 5},
#   'period': {'hits@5': np.float64(0.3333333333333333),
#    'precision@5': np.float64(0.06666666666666667),
#    'recall@5': np.float64(0.3333333333333333),
#    'mrr@5': np.float64(0.3333333333333333),
#    'retrieval_eval_count': 3,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.026047380532833685,
#    'avg_rougeL': 0.27777777777777773,
#    'avg_token_f1': 0.17468630660120021,
#    'avg_keyword_group_recall': 0.6666666666666666,
#    'exact_keyword_group_match_rate': 0.3333333333333333,
#    'avg_matched_keyword_groups': 1.6666666666666667,
#    'avg_total_keyword_groups': 2.6666666666666665,
#    'avg_retrieval_latency_sec': 0.028103424701839685,
#    'avg_generation_latency_sec': 4.04957102437038,
#    'avg_total_latency_sec': 4.085603811312467,
#    'p50_total_latency_sec': 1.8306553759612143,
#    'p95_total_latency_sec': 8.902026936993934,
#    'avg_input_tokens': 2252.6666666666665,
#    'avg_output_tokens': 112.33333333333333,
#    'avg_total_tokens': 2365.0,
#    'total_tokens': 7095.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 3},
#   'summary': {'hits@5': np.float64(0.5),
#    'precision@5': np.float64(0.1),
#    'recall@5': np.float64(0.5),
#    'mrr@5': np.float64(0.5),
#    'retrieval_eval_count': 2,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.008259776061589168,
#    'avg_rougeL': 0.5857142857142857,
#    'avg_token_f1': 0.13459879206212252,
#    'avg_keyword_group_recall': 0.7083333333333333,
#    'exact_keyword_group_match_rate': 0.0,
#    'avg_matched_keyword_groups': 2.5,
#    'avg_total_keyword_groups': 3.5,
#    'avg_retrieval_latency_sec': 0.028097444446757436,
#    'avg_generation_latency_sec': 3.711097585503012,
#    'avg_total_latency_sec': 3.7444593015825376,
#    'p50_total_latency_sec': 2.5634577421005815,
#    'p95_total_latency_sec': 4.925460861064494,
#    'avg_input_tokens': 1365.0,
#    'avg_output_tokens': 105.5,
#    'avg_total_tokens': 1470.5,
#    'total_tokens': 2941.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 2}},
#  {'hwp': {'hits@5': np.float64(0.42105263157894735),
#    'precision@5': np.float64(0.08421052631578947),
#    'recall@5': np.float64(0.42105263157894735),
#    'mrr@5': np.float64(0.34385964912280703),
#    'retrieval_eval_count': 19,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.006807350185529184,
#    'avg_rougeL': 0.1581453634085213,
#    'avg_token_f1': 0.08411555533162793,
#    'avg_keyword_group_recall': 0.4105263157894737,
#    'exact_keyword_group_match_rate': 0.15789473684210525,
#    'avg_matched_keyword_groups': 1.3157894736842106,
#    'avg_total_keyword_groups': 3.0,
#    'avg_retrieval_latency_sec': 0.02891200320721653,
#    'avg_generation_latency_sec': 5.626682856071152,
#    'avg_total_latency_sec': 5.663769887049535,
#    'p50_total_latency_sec': 5.9165510579478,
#    'p95_total_latency_sec': 11.048214606009424,
#    'avg_input_tokens': 2362.5789473684213,
#    'avg_output_tokens': 157.78947368421052,
#    'avg_total_tokens': 2520.3684210526317,
#    'total_tokens': 47887.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 19},
#   'pdf': {'hits@5': np.float64(1.0),
#    'precision@5': np.float64(0.2),
#    'recall@5': np.float64(1.0),
#    'mrr@5': np.float64(1.0),
#    'retrieval_eval_count': 1,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.0,
#    'avg_rougeL': 0.8,
#    'avg_token_f1': 0.0,
#    'avg_keyword_group_recall': 0.0,
#    'exact_keyword_group_match_rate': 0.0,
#    'avg_matched_keyword_groups': 0.0,
#    'avg_total_keyword_groups': 1.0,
#    'avg_retrieval_latency_sec': 0.028350742999464273,
#    'avg_generation_latency_sec': 1.0574546640273184,
#    'avg_total_latency_sec': 1.0949560779845342,
#    'p50_total_latency_sec': 1.0949560779845342,
#    'p95_total_latency_sec': 1.0949560779845342,
#    'avg_input_tokens': 2701.0,
#    'avg_output_tokens': 26.0,
#    'avg_total_tokens': 2727.0,
#    'total_tokens': 2727.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 1}})

# %%
evaluator.save_metrics(
    metrics_by_source_type,
    str(METRICS_BY_SOURCE_TYPE_PATH),
)

evaluator.save_metrics(
    metrics_by_answer_format,
    str(METRICS_BY_ANSWER_FORMAT_PATH),
)

evaluator.save_metrics(
    metrics_by_file_type,
    str(METRICS_BY_FILE_TYPE_PATH),
)
# Out:
# 평가 결과 저장 완료: /home/user2/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_by_source_type.json
# 평가 결과 저장 완료: /home/user2/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_by_answer_format.json
# 평가 결과 저장 완료: /home/user2/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_by_file_type.json

# %% [markdown]
# # Cell 23. 검색 실패 케이스 분석

# %%
with log_step("Extract retrieval failure cases"):
    retrieval_failures = evaluator.get_retrieval_failure_cases(
        rag_outputs,
        k=BASELINE_CONFIG["top_k"],
    )

print("검색 실패 케이스 수:", len(retrieval_failures))

evaluator.save_rows_as_csv(
    retrieval_failures,
    str(RETRIEVAL_FAILURE_PATH),
)

pd.DataFrame(retrieval_failures).head()
# Out:
# [Extract retrieval failure cases] start
# [Extract retrieval failure cases] done | elapsed=0s
# 검색 실패 케이스 수: 11
# CSV 저장 완료: /home/user2/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_retrieval_failures.csv / 11건
#                  qid       doc_id question_type source_type answer_format  \
# 0  20240414353_llm_2  20240414353         llm_2    document          list
# 1  20240420207_llm_2  20240420207         llm_2    document          list
# 2  20240430896_llm_1  20240430896         llm_1    document          list
# 3  20240430918_llm_2  20240430918         llm_2    document        period
# 4  20240531542_llm_1  20240531542         llm_1    document        period
#
#                             project_name organization  \
# 0                           경영정보시스템 기능개선       부산관광공사
# 1    스마트 팹 서비스 활용체계 구축관련 설비온라인 시스템 구축 용역      나노종합기술원
# 2           봉화군 재난통합관리시스템 고도화 사업(협상)(긴급)     경상북도 봉화군
# 3                   도시계획위원회 통합관리시스템 구축용역        인천광역시
# 4  (긴급)「2024년도 차세대 응급의료 상황관리시스템 구축」 위탁용역      국립중앙의료원
#
#                                             question  \
# 0                          이 제안요청서가 밝히는 기대효과는 무엇인가요?
# 1                         이 사업이 추진되는 배경과 필요성은 무엇인가요?
# 2          이 사업이 공동수급(공동이행방식)을 허용하는 이유와 기대효과는 무엇인가요?
# 3  과업내용 변경이나 계약금액·기간 조정이 필요할 때 어떤 절차로 요청해야 하고, 그 ...
# 4                 이 사업의 예산은 얼마이고 사업기간(종료일)은 언제까지인가요?
#
#                                            reference  \
# 0                        기대효과는 업무처리 효율성 및 편의성 향상입니다.
# 1  추진배경은 나노 반도체를 국가 성장 동력으로 강화하고 글로벌 기술 경쟁에 대응하기 ...
# 2  사업은 공동수급(공동이행방식)을 허용하며, 기대효과로는 공동수급표준협정서를 활용한 ...
# 3  과업내용 변경 및 계약금액·계약기간 조정이 필요하면 계약상대자는 국가기관등의 장에게...
# 4  사업예산은 금일십사억원정(1,400,000,000원, VAT 포함)이며, 사업기간은...
#
#                                        retrieved_ids  \
# 0  [20240404154, DOC_0012, 20240605366, 202404041...
# 1  [DOC_0012, 20240541684, DOC_0049, DOC_0024, DO...
# 2  [20240430918, 20240413838, R25BK00603533, 2024...
# 3  [R25BK00604826, 20240414353, 20240419826, 2024...
# 4  [20240623903, 20240331766, 20241130016, 202411...
#
#                                             response
# 0  이 제안요청서는 다음과 같은 기대효과를 제시합니다:\n\n1. **서비스와 시스템의...
# 1  이 사업이 추진되는 배경과 필요성은 다음과 같습니다:\n\n1. **사업의 목적**...
# 2  이 사업이 공동수급(공동이행방식)을 허용하는 이유는 다음과 같습니다:\n\n1. *...
# 3  과업내용 변경이나 계약금액·기간 조정이 필요할 때, 다음과 같은 절차를 거쳐야 합니...
# 4  이 사업의 예산은 일금 육천만원정(₩ 60,000,000; 부가세 포함)이며, 사업...

# %% [markdown]
# # Cell 24. 키워드 실패 케이스 분석

# %%
with log_step("Extract keyword failure cases"):
    keyword_failures = evaluator.get_keyword_failure_cases(
        rag_outputs,
        threshold=1.0,
    )

print("키워드 실패 케이스 수:", len(keyword_failures))

evaluator.save_rows_as_csv(
    keyword_failures,
    str(KEYWORD_FAILURE_PATH),
)

pd.DataFrame(keyword_failures).head()
# Out:
# [Extract keyword failure cases] start
# [Extract keyword failure cases] done | elapsed=0s
# 키워드 실패 케이스 수: 17
# CSV 저장 완료: /home/user2/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_keyword_failures.csv / 17건
#                        qid       doc_id question_type source_type  \
# 0        20240330003_llm_1  20240330003         llm_1    document
# 1  20240404154_fact_budget  20240404154   fact_budget    metadata
# 2        20240408682_llm_1  20240408682         llm_1    document
# 3        20240414353_llm_2  20240414353         llm_2    document
# 4        20240420207_llm_2  20240420207         llm_2    document
#
#   answer_format                         project_name organization  \
# 0          list   2024년 벤처확인종합관리시스템 기능 고도화 용역사업 입찰공고    (사)벤처기업협회
# 1         money  2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 용역        서울특별시
# 2        period           2024년도 GKL  그룹웨어 시스템 구축 용역  그랜드코리아레저(주)
# 3          list                         경영정보시스템 기능개선       부산관광공사
# 4          list  스마트 팹 서비스 활용체계 구축관련 설비온라인 시스템 구축 용역      나노종합기술원
#
#                                             question  \
# 0  2024년 벤처확인종합관리시스템 기능 고도화 사업에서 고도화하거나 신규로 구축하는 ...
# 1  서울특별시에서 발주한 '2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 ...
# 2                  GKL 그룹웨어 시스템 구축사업의 사업기간은 언제까지인가요?
# 3                          이 제안요청서가 밝히는 기대효과는 무엇인가요?
# 4                         이 사업이 추진되는 배경과 필요성은 무엇인가요?
#
#                                            reference  \
# 0  복수의결권주식의 발행 보고 업무처리 시스템 구축, 벤처기업법에 따라 부여된 스톡옵션...
# 1                                  493,763,000원 입니다.
# 2                                  계약일로부터 6개월 이내입니다.
# 3                        기대효과는 업무처리 효율성 및 편의성 향상입니다.
# 4  추진배경은 나노 반도체를 국가 성장 동력으로 강화하고 글로벌 기술 경쟁에 대응하기 ...
#
#                                             response  keyword_group_recall  \
# 0  고도화 또는 신규 구축되는 주요 기능은 다음과 같습니다:\n\n1. 복수의결권주식 ...              0.666667
# 1                    배정 예산은 금493,763천원(부가가치세 포함)입니다.              0.000000
# 2  GKL 그룹웨어 시스템 구축사업의 사업기간은 계약체결일로부터 6개월 (안정화 1개월...              0.500000
# 3  이 제안요청서는 다음과 같은 기대효과를 제시합니다:\n\n1. **서비스와 시스템의...              0.000000
# 4  이 사업이 추진되는 배경과 필요성은 다음과 같습니다:\n\n1. **사업의 목적**...              0.400000
#
#    matched_keyword_group_count  total_keyword_group_count  \
# 0                            2                          3
# 1                            0                          1
# 2                            1                          2
# 3                            0                          2
# 4                            2                          5
#
#                                 matched_groups  \
# 0  [[복수의결권주식, 복수 의결권], [스톡옵션, 주식매수선택권, 스톡 옵션]]
# 1                                           []
# 2                   [[6개월, 6개월 이내, 6개월 이내입니다]]
# 3                                           []
# 4    [[추진배경, 배경, 목적], [나노 반도체, 반도체, 국가 성장 동력]]
#
#                                        missed_groups
# 0                     [[성과조건부주식교부, 성과조건부주식교부계약, RS]]
# 1          [[493,763,000원, 493763000원, 4억9천3백7십6만원]]
# 2                                    [[계약일로부터, 계약일]]
# 3  [[업무처리 효율성 향상, 업무처리 효율성, 효율성 향상], [편의성 향상, 업무 ...
# 4  [[대기업 중심, 중소, 벤처, 학연, 중소·벤처·학연, 다변화, 혁신주체], [공...

# %% [markdown]
# # Cell 25. row별 keyword score 부착 후 저장

# %%
with log_step("Attach keyword scores"):
    scored_outputs = evaluator.attach_keyword_scores(rag_outputs)

evaluator.save_rows_as_json(
    scored_outputs,
    str(RAG_OUTPUT_SCORED_PATH),
)

print("scored output 저장:", RAG_OUTPUT_SCORED_PATH)
# Out:
# [Attach keyword scores] start
# [Attach keyword scores] done | elapsed=0s
# JSON 저장 완료: /home/user2/RFP-RAG-Extractor/data/processed/eval/rag_outputs_baseline_section_sample_20_scored.json / 20건
# scored output 저장: /home/user2/RFP-RAG-Extractor/data/processed/eval/rag_outputs_baseline_section_sample_20_scored.json

# %% [markdown]
# # Cell 26. 요약 CSV 생성

# %%
summary_rows = []

for row in scored_outputs:
    retrieved_ids_topk = row.get("retrieved_ids", [])[:BASELINE_CONFIG["top_k"]]

    summary_rows.append({
        "qid": row.get("qid"),
        "doc_id": row.get("doc_id"),
        "question_type": row.get("question_type"),
        "source_type": row.get("source_type"),
        "answer_format": row.get("answer_format"),
        "file_type": row.get("file_type"),
        "project_name": row.get("project_name"),
        "organization": row.get("organization"),
        "question": row.get("question"),
        "reference": row.get("reference"),
        "response": row.get("response"),
        "retrieved_ids": json.dumps(row.get("retrieved_ids", []), ensure_ascii=False),
        "retrieval_hit": row.get("doc_id") in set(retrieved_ids_topk),
        "keyword_group_recall": row.get("keyword_group_recall"),
        "matched_keyword_group_count": row.get("matched_keyword_group_count"),
        "total_keyword_group_count": row.get("total_keyword_group_count"),
        "missed_groups": json.dumps(row.get("missed_groups", []), ensure_ascii=False),
        "retrieval_latency_sec": row.get("retrieval_latency_sec"),
        "generation_latency_sec": row.get("generation_latency_sec"),
        "total_latency_sec": row.get("total_latency_sec"),
        "input_tokens": row.get("input_tokens"),
        "output_tokens": row.get("output_tokens"),
        "error": row.get("error", ""),
    })

summary_df = pd.DataFrame(summary_rows)

summary_df.to_csv(
    SUMMARY_CSV_PATH,
    index=False,
    encoding="utf-8-sig",
)

print("요약 CSV 저장:", SUMMARY_CSV_PATH)
display(summary_df.head())
# Out:
# 요약 CSV 저장: /home/user2/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_summary.csv
#                        qid       doc_id question_type source_type  \
# 0        20240330003_llm_1  20240330003         llm_1    document
# 1  20240404154_fact_budget  20240404154   fact_budget    metadata
# 2        20240408682_llm_1  20240408682         llm_1    document
# 3        20240414353_llm_2  20240414353         llm_2    document
# 4        20240420207_llm_2  20240420207         llm_2    document
#
#   answer_format file_type                         project_name organization  \
# 0          list       hwp   2024년 벤처확인종합관리시스템 기능 고도화 용역사업 입찰공고    (사)벤처기업협회
# 1         money       pdf  2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 용역        서울특별시
# 2        period       hwp           2024년도 GKL  그룹웨어 시스템 구축 용역  그랜드코리아레저(주)
# 3          list       hwp                         경영정보시스템 기능개선       부산관광공사
# 4          list       hwp  스마트 팹 서비스 활용체계 구축관련 설비온라인 시스템 구축 용역      나노종합기술원
#
#                                             question  \
# 0  2024년 벤처확인종합관리시스템 기능 고도화 사업에서 고도화하거나 신규로 구축하는 ...
# 1  서울특별시에서 발주한 '2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 ...
# 2                  GKL 그룹웨어 시스템 구축사업의 사업기간은 언제까지인가요?
# 3                          이 제안요청서가 밝히는 기대효과는 무엇인가요?
# 4                         이 사업이 추진되는 배경과 필요성은 무엇인가요?
#
#                                            reference  ...  \
# 0  복수의결권주식의 발행 보고 업무처리 시스템 구축, 벤처기업법에 따라 부여된 스톡옵션...  ...
# 1                                  493,763,000원 입니다.  ...
# 2                                  계약일로부터 6개월 이내입니다.  ...
# 3                        기대효과는 업무처리 효율성 및 편의성 향상입니다.  ...
# 4  추진배경은 나노 반도체를 국가 성장 동력으로 강화하고 글로벌 기술 경쟁에 대응하기 ...  ...
#
#   keyword_group_recall matched_keyword_group_count  total_keyword_group_count  \
# 0             0.666667                           2                          3
# 1             0.000000                           0                          1
# 2             0.500000                           1                          2
# 3             0.000000                           0                          2
# 4             0.400000                           2                          5
#
#                                        missed_groups  retrieval_latency_sec  \
# 0               [["성과조건부주식교부", "성과조건부주식교부계약", "RS"]]               0.029850
# 1    [["493,763,000원", "493763000원", "4억9천3백7십6만원"]]               0.028351
# 2                                [["계약일로부터", "계약일"]]               0.027677
# 3  [["업무처리 효율성 향상", "업무처리 효율성", "효율성 향상"], ["편의성 ...               0.028845
# 4  [["대기업 중심", "중소", "벤처", "학연", "중소·벤처·학연", "다변화...               0.028770
#
#    generation_latency_sec total_latency_sec  input_tokens  output_tokens  \
# 0               11.011731         11.048215          2195            317
# 1                1.057455          1.094956          2701             26
# 2                1.487882          1.524129          2429             39
# 3                8.518962          8.553412          1611            244
# 4                8.117751          8.152413          1385            233
#
#    error
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 23 columns]

# %% [markdown]
# # Cell 27. 주요 지표 출력

# %%
top_k = BASELINE_CONFIG["top_k"]

print("===== Baseline RAG Evaluation =====")
print(f"LLM: {BASELINE_CONFIG['llm_model_name']}")
print(f"Embedding: {BASELINE_CONFIG['embedding_model_name']}")
print(f"Vector DB: {BASELINE_CONFIG['vector_db']}")
print(f"Chunking: {BASELINE_CONFIG['chunking_strategy']}")
print(f"Top-K: {top_k}")
print(f"Sample Size: {BASELINE_CONFIG['sample_size']}")

print("\n--- Retrieval ---")
for key in [
    f"hits@{top_k}",
    f"precision@{top_k}",
    f"recall@{top_k}",
    f"mrr@{top_k}",
    "retrieval_eval_count",
    "retrieval_eval_skipped_count",
]:
    print(f"{key}: {metrics.get(key)}")

print("\n--- Generation ---")
for key in [
    "avg_bleu",
    "avg_rougeL",
    "avg_token_f1",
]:
    print(f"{key}: {metrics.get(key)}")

print("\n--- Keyword ---")
for key in [
    "avg_keyword_group_recall",
    "exact_keyword_group_match_rate",
    "avg_matched_keyword_groups",
    "avg_total_keyword_groups",
]:
    print(f"{key}: {metrics.get(key)}")

print("\n--- Efficiency ---")
for key in [
    "avg_retrieval_latency_sec",
    "avg_generation_latency_sec",
    "avg_total_latency_sec",
    "p50_total_latency_sec",
    "p95_total_latency_sec",
    "avg_input_tokens",
    "avg_output_tokens",
    "avg_total_tokens",
    "total_tokens",
    "avg_cost_per_query",
    "total_cost",
]:
    print(f"{key}: {metrics.get(key)}")

print("\n--- Failures ---")
print("retrieval_failures:", len(retrieval_failures))
print("keyword_failures:", len(keyword_failures))
# Out:
# ===== Baseline RAG Evaluation =====
# LLM: Qwen/Qwen2.5-1.5B-Instruct
# Embedding: nlpai-lab/KURE-v1
# Vector DB: FAISS
# Chunking: section
# Top-K: 5
# Sample Size: 20
#
# --- Retrieval ---
# hits@5: 0.45
# precision@5: 0.09
# recall@5: 0.45
# mrr@5: 0.37666666666666665
# retrieval_eval_count: 20
# retrieval_eval_skipped_count: 0
#
# --- Generation ---
# avg_bleu: 0.006466982676252725
# avg_rougeL: 0.19023809523809523
# avg_token_f1: 0.07990977756504654
#
# --- Keyword ---
# avg_keyword_group_recall: 0.39
# exact_keyword_group_match_rate: 0.15
# avg_matched_keyword_groups: 1.25
# avg_total_keyword_groups: 2.9
#
# --- Efficiency ---
# avg_retrieval_latency_sec: 0.028883940196828918
# avg_generation_latency_sec: 5.398221446468961
# avg_total_latency_sec: 5.435329196596285
# p50_total_latency_sec: 5.9165510579478
# p95_total_latency_sec: 11.048214606009424
# avg_input_tokens: 2379.5
# avg_output_tokens: 151.2
# avg_total_tokens: 2530.7
# total_tokens: 50614.0
# avg_cost_per_query: 0.0
# total_cost: 0.0
#
# --- Failures ---
# retrieval_failures: 11
# keyword_failures: 17

# %% [markdown]
# # Cell 28. 다음 실험을 위한 메모 저장

# %%
experiment_summary = {
    "config": BASELINE_CONFIG,
    "paths": {
        "section_chunk_path": str(SECTION_CHUNK_PATH),
        "eval_dataset_path": str(EVAL_DATASET_PATH),
        "eval_sample_path": str(EVAL_SAMPLE_PATH),
        "vector_dir": str(BASELINE_VECTOR_DIR),
        "rag_output_path": str(RAG_OUTPUT_PATH),
        "metrics_path": str(METRICS_PATH),
        "summary_csv_path": str(SUMMARY_CSV_PATH),
    },
    "metrics": metrics,
    "num_rag_outputs": len(rag_outputs),
    "num_retrieval_failures": len(retrieval_failures),
    "num_keyword_failures": len(keyword_failures),
}

EXPERIMENT_SUMMARY_PATH = REPORT_DIR / "baseline_section_sample20_experiment_summary.json"

evaluator.save_metrics(
    experiment_summary,
    str(EXPERIMENT_SUMMARY_PATH),
)

print("실험 요약 저장:", EXPERIMENT_SUMMARY_PATH)
# Out:
# 평가 결과 저장 완료: /home/user2/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_experiment_summary.json
# 실험 요약 저장: /home/user2/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_experiment_summary.json
