# %% [markdown]
# # Cell 1. 기본 경로 및 환경 설정

# %% [markdown]
# 사용하는 내부 모듈:
# src/utils/path_utils.py
# - find_project_root
#
# src/utils/file_utils.py
# - load_jsonl
#
# src/utils/eval_dataset_utils.py
# - load_json
# - save_json
# - create_and_save_eval_sample
#
# src/utils/progress_utils.py
# - ProgressLogger
# - progress_iter
# - log_step
#
# src/evaluation/rag_evaluator.py
# - RAGEvaluator
#
# 처음 실행할 때:
# FORCE_REBUILD_INDEX = True
#
# 다음부터 같은 청크와 같은 임베딩 모델을 재사용할 때:
# FORCE_REBUILD_INDEX = False
#
# 단, 아래를 바꾸면 반드시 FAISS를 다시 만들어야 합니다.
# section_chunks.jsonl 변경
# embedding_model 변경
# 청크 정제/청킹 방식 변경
#
# 그 경우:
# FORCE_REBUILD_INDEX = True

# %%
from pathlib import Path
import sys
import json
import pickle
import time
from typing import List, Dict, Any

import numpy as np
import pandas as pd

# 현재 노트북 위치:
# ?? ??? ??? notebooks/ ?? notebooks/Sooq/ ??? ?????
# Resolve project root from either notebooks/ or notebooks/Sooq/.
NOTEBOOK_DIR = Path.cwd().resolve()

PROJECT_ROOT = next(
    path for path in [NOTEBOOK_DIR, *NOTEBOOK_DIR.parents]
    if (path / "src").exists()
)

# Add project root before importing src modules.
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.chunking.hybrid_section_chunker import (
    create_section_chunks as create_chunks
)

from src.utils.path_utils import find_project_root
from src.utils.file_utils import load_jsonl
from src.utils.eval_dataset_utils import (
    load_json,
    save_json,
    create_and_save_eval_sample,
)
from src.utils.progress_utils import ProgressLogger, progress_iter, log_step
from src.evaluation.evaluator import RAGEvaluator

# 프로젝트 이름 기준으로 root 검증
PROJECT_ROOT = find_project_root("RFP-RAG-Extractor")

DATA_DIR = PROJECT_ROOT / "data"

# 01번 노트북에서 생성한 청크 파일
SECTION_CHUNK_PATH = DATA_DIR / "chunks" / "section" / "section_chunks.jsonl"

# 평가 데이터 경로
EVAL_DIR = DATA_DIR / "processed" / "eval"
EVAL_DATASET_PATH = EVAL_DIR / "eval_dataset.json"
EVAL_SAMPLE_PATH = EVAL_DIR / "eval_dataset_sample_20.json"

# 벡터 DB 저장 경로
VECTOR_DB_DIR = DATA_DIR / "vector_db"
BASELINE_VECTOR_DIR = VECTOR_DB_DIR / "baseline_section_kure_faiss"
BASELINE_VECTOR_DIR.mkdir(parents=True, exist_ok=True)

# RAG 실행 결과 저장 경로
RAG_OUTPUT_PATH = EVAL_DIR / "rag_outputs_baseline_section_sample_20.json"
RAG_OUTPUT_SCORED_PATH = EVAL_DIR / "rag_outputs_baseline_section_sample_20_scored.json"

# 평가 리포트 저장 경로
REPORT_DIR = PROJECT_ROOT / "reports" / "evaluation"
REPORT_DIR.mkdir(parents=True, exist_ok=True)

METRICS_PATH = REPORT_DIR / "baseline_section_sample20_metrics.json"
METRICS_BY_QTYPE_PATH = REPORT_DIR / "baseline_section_sample20_by_question_type.json"
METRICS_BY_SOURCE_TYPE_PATH = REPORT_DIR / "baseline_section_sample20_by_source_type.json"
METRICS_BY_ANSWER_FORMAT_PATH = REPORT_DIR / "baseline_section_sample20_by_answer_format.json"
METRICS_BY_FILE_TYPE_PATH = REPORT_DIR / "baseline_section_sample20_by_file_type.json"

RETRIEVAL_FAILURE_PATH = REPORT_DIR / "baseline_section_sample20_retrieval_failures.csv"
KEYWORD_FAILURE_PATH = REPORT_DIR / "baseline_section_sample20_keyword_failures.csv"
SUMMARY_CSV_PATH = REPORT_DIR / "baseline_section_sample20_summary.csv"

print("현재 작업 위치:", Path.cwd())
print("PROJECT_ROOT:", PROJECT_ROOT)
print("SECTION_CHUNK_PATH:", SECTION_CHUNK_PATH)
print("EVAL_DATASET_PATH:", EVAL_DATASET_PATH)
print("EVAL_SAMPLE_PATH:", EVAL_SAMPLE_PATH)
print("BASELINE_VECTOR_DIR:", BASELINE_VECTOR_DIR)
# Out:
# 현재 작업 위치: d:\codeit\RAG\RFP-RAG-Extractor\notebooks\Sooq
# PROJECT_ROOT: D:\codeit\RAG\RFP-RAG-Extractor
# SECTION_CHUNK_PATH: D:\codeit\RAG\RFP-RAG-Extractor\data\chunks\section\section_chunks.jsonl
# EVAL_DATASET_PATH: D:\codeit\RAG\RFP-RAG-Extractor\data\processed\eval\eval_dataset.json
# EVAL_SAMPLE_PATH: D:\codeit\RAG\RFP-RAG-Extractor\data\processed\eval\eval_dataset_sample_20.json
# BASELINE_VECTOR_DIR: D:\codeit\RAG\RFP-RAG-Extractor\data\vector_db\baseline_section_kure_faiss

# %% [markdown]
# # Cell 2. 베이스라인 설정

# %%
BASELINE_CONFIG = {
    "llm_model_name": "Qwen/Qwen2.5-1.5B-Instruct",
    "embedding_model_name": "nlpai-lab/KURE-v1",
    "vector_db": "FAISS",
    "chunking_strategy": "section",
    "top_k": 5,
    "sample_size": 20,
    "random_seed": 42,
    "max_new_tokens": 512,
    "temperature": 0.0,
    "do_sample": False,
}

# section_chunks.jsonl을 새로 만들었으면 True
# 이미 같은 청크로 FAISS 인덱스를 만들어뒀으면 False
FORCE_REBUILD_INDEX = True

BASELINE_CONFIG
# Out:
# {'llm_model_name': 'Qwen/Qwen2.5-1.5B-Instruct',
#  'embedding_model_name': 'nlpai-lab/KURE-v1',
#  'vector_db': 'FAISS',
#  'chunking_strategy': 'section',
#  'top_k': 5,
#  'sample_size': 20,
#  'random_seed': 42,
#  'max_new_tokens': 512,
#  'temperature': 0.0,
#  'do_sample': False}

# %% [markdown]
# # Cell 3. 평가 데이터셋 로드 및 샘플 n개 생성

# %%
if not EVAL_DATASET_PATH.exists():
    raise FileNotFoundError(
        f"평가 데이터셋이 없습니다: {EVAL_DATASET_PATH}"
    )

eval_dataset = load_json(EVAL_DATASET_PATH)

print("전체 평가 문항 수:", len(eval_dataset))
print(pd.Series([x.get("question_type") for x in eval_dataset]).value_counts())
# Out:
# 전체 평가 문항 수: 243
# llm_1          82
# llm_2          82
# fact_budget    79
# Name: count, dtype: int64

# %%
if EVAL_SAMPLE_PATH.exists():
    print("기존 샘플 평가셋 로드:", EVAL_SAMPLE_PATH)
    sample_eval_dataset = load_json(EVAL_SAMPLE_PATH)

else:
    print("샘플 평가셋 새로 생성:", EVAL_SAMPLE_PATH)
    sample_eval_dataset = create_and_save_eval_sample(
        input_path=EVAL_DATASET_PATH,
        output_path=EVAL_SAMPLE_PATH,
        sample_size=BASELINE_CONFIG["sample_size"],
        random_seed=BASELINE_CONFIG["random_seed"],
    )

print("샘플 문항 수:", len(sample_eval_dataset))
print(pd.Series([x.get("question_type") for x in sample_eval_dataset]).value_counts())

sample_eval_dataset[:2]
# Out:
# 샘플 평가셋 새로 생성: D:\codeit\RAG\RFP-RAG-Extractor\data\processed\eval\eval_dataset_sample_20.json
# 샘플 문항 수: 20
# llm_2          8
# llm_1          7
# fact_budget    5
# Name: count, dtype: int64
# [{'qid': '20240330003_llm_1',
#   'question': '2024년 벤처확인종합관리시스템 기능 고도화 사업에서 고도화하거나 신규로 구축하는 주요 기능은 무엇인가요?',
#   'reference': '복수의결권주식의 발행 보고 업무처리 시스템 구축, 벤처기업법에 따라 부여된 스톡옵션(주식매수선택권)의 부여·취소·철회 신고 및 업무시스템 구축, 성과조건부주식교부계약(RS)의 신고 및 업무처리 시스템 구축 등 세 가지 기능의 구축 및 고도화이다.',
#   'required_keyword_groups': [['복수의결권주식', '복수 의결권'],
#    ['스톡옵션', '주식매수선택권', '스톡 옵션'],
#    ['성과조건부주식교부', '성과조건부주식교부계약', 'RS']],
#   'doc_id': '20240330003',
#   'question_type': 'llm_1',
#   'source_type': 'document',
#   'answer_format': 'list',
#   'source_row_id': 86,
#   'project_name': '2024년 벤처확인종합관리시스템 기능 고도화 용역사업 입찰공고',
#   'organization': '(사)벤처기업협회',
#   'file_name': '(사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .hwp',
#   'file_type': 'hwp'},
#  {'qid': '20240404154_fact_budget',
#   'question': "서울특별시에서 발주한 '2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 용역' 사업의 배정 예산은 얼마인가요?",
#   'reference': '493,763,000원 입니다.',
#   'required_keyword_groups': [['493,763,000원', '493763000원', '4억9천3백7십6만원']],
#   'doc_id': '20240404154',
#   'question_type': 'fact_budget',
#   'source_type': 'metadata',
#   'answer_format': 'money',
#   'source_row_id': 39,
#   'project_name': '2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 용역',
#   'organization': '서울특별시',
#   'file_name': '서울특별시_2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 용.pdf',
#   'file_type': 'pdf'}]

# %% [markdown]
# # Cell 4. section_chunks.jsonl 로드

# %%
if not SECTION_CHUNK_PATH.exists():
    raise FileNotFoundError(
        f"section_chunks.jsonl 파일이 없습니다: {SECTION_CHUNK_PATH}\n"
        "먼저 01_extract_clean_chunk.ipynb를 실행해서 청크를 생성해야 합니다."
    )

chunks = load_jsonl(SECTION_CHUNK_PATH)

print("로드된 청크 수:", len(chunks))
print("첫 번째 청크 keys:", chunks[0].keys())
chunks[0]
# Out:
# 로드된 청크 수: 14377
# 첫 번째 청크 keys: dict_keys(['chunk_id', 'doc_id', 'file_name', 'file_type', 'project_name', 'organization', 'chunking_strategy', 'section_title', 'section_path', 'text'])
# {'chunk_id': '20241001798_section_0024_00',
#  'doc_id': '20241001798',
#  'file_name': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp',
#  'file_type': 'hwp',
#  'project_name': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화',
#  'organization': '한영대학',
#  'chunking_strategy': 'section',
#  'section_title': '□ 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)',
#  'section_path': ['□ 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)'],
#  'text': '□ 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n\n2\n\n추진배경 및 필요성\n\n학사제도·제도개편과 연계하湯湷여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대\n\n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화\n\n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성\n\n3\n\n기대효과\n\n◦ 트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n\n◦ 교수자·학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n\n◦ 학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n\nII\n\n구축 방안\n\n1\n\n구축목표\n\n◦ 트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n\n(교과과정 개발에서 성적 이수까지)\n\n◦ 트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n\n(교육과정 / 수강신청 / 성적 / 학적관리 외)\n\n◦ 확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n\n◦ 다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n\n2\n\n구축일정\n\n❍ 구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n\n일 정\n\n내 용\n\n진 행 일 정\n\n비고\n\n구축\n\n안정화\n\nw1\n\nw2\n\nw3\n\nw4\n\nw5\n\nw6\n\nw7\n\nw8\n\nw9\n\nw10\n\nw11\n\nw12\n\n사업발주 및 착수\n\n※ 사업수행 이전\n\n분석\n\n-업무 분석\n\n구현'}

# %% [markdown]
# # Cell 5. 청크 필드 표준화

# %%
def get_chunk_text(chunk: Dict[str, Any]) -> str:
    for key in ["text", "page_content", "content", "chunk_text"]:
        value = chunk.get(key)
        if value:
            return str(value)
    return ""


def get_chunk_doc_id(chunk: Dict[str, Any]) -> str:
    if chunk.get("doc_id") is not None:
        return str(chunk["doc_id"])

    metadata = chunk.get("metadata", {}) or {}
    if metadata.get("doc_id") is not None:
        return str(metadata["doc_id"])

    return ""


def get_chunk_id(chunk: Dict[str, Any], idx: int) -> str:
    if chunk.get("chunk_id") is not None:
        return str(chunk["chunk_id"])

    metadata = chunk.get("metadata", {}) or {}
    if metadata.get("chunk_id") is not None:
        return str(metadata["chunk_id"])

    return f"chunk_{idx:06d}"


standard_chunks = []

for idx, chunk in enumerate(chunks):
    text = get_chunk_text(chunk)
    doc_id = get_chunk_doc_id(chunk)
    chunk_id = get_chunk_id(chunk, idx)

    if not text.strip():
        continue

    if not doc_id.strip():
        continue

    standard_chunks.append({
        **chunk,
        "chunk_id": chunk_id,
        "doc_id": doc_id,
        "text": text,
    })

print("표준화 전 청크 수:", len(chunks))
print("표준화 후 청크 수:", len(standard_chunks))

pd.DataFrame([
    {
        "chunk_id": x["chunk_id"],
        "doc_id": x["doc_id"],
        "file_type": x.get("file_type"),
        "text_len": len(x["text"]),
    }
    for x in standard_chunks[:5]
])
# Out:
# 표준화 전 청크 수: 14377
# 표준화 후 청크 수: 14377
#                       chunk_id       doc_id file_type  text_len
# 0  20241001798_section_0024_00  20241001798       hwp       746
# 1  20241001798_section_0036_00  20241001798       hwp       126
# 2  20241001798_section_0037_00  20241001798       hwp      1098
# 3  20241001798_section_0044_00  20241001798       hwp       780
# 4  20241001798_section_0057_00  20241001798       hwp       111

# %% [markdown]
# # Cell 6. 청크 통계 확인

# %%
chunk_stat_df = pd.DataFrame([
    {
        "chunk_id": chunk["chunk_id"],
        "doc_id": chunk["doc_id"],
        "file_type": chunk.get("file_type"),
        "chunking_strategy": chunk.get("chunking_strategy"),
        "text_len": len(chunk.get("text", "")),
    }
    for chunk in standard_chunks
])

print("청크 수:", len(chunk_stat_df))
display(chunk_stat_df["text_len"].describe())
display(chunk_stat_df.groupby("doc_id")["chunk_id"].count().describe())
display(chunk_stat_df["file_type"].value_counts(dropna=False))
# Out:
# 청크 수: 14377
# count    14377.000000
# mean       377.706893
# std        455.044028
# min        100.000000
# 25%        135.000000
# 50%        212.000000
# 75%        402.000000
# max       3000.000000
# Name: text_len, dtype: float64
# count    100.000000
# mean     143.770000
# std       63.107709
# min       50.000000
# 25%      104.750000
# 50%      128.000000
# 75%      165.000000
# max      481.000000
# Name: chunk_id, dtype: float64
# file_type
# hwp    13229
# pdf     1148
# Name: count, dtype: int64

# %% [markdown]
# # Cell 6. 임베딩 모델 로드

# %%
import os
import gc
import torch
from sentence_transformers import SentenceTransformer

# 1. PyTorch 가비지 세그먼트 수집 활성화 (단편화 해결)
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# 2. 임베딩 로드 전 미사용 메모리 및 캐시 즉시 비우기
gc.collect()
torch.cuda.empty_cache()

# 3. 모델 이름 변수 지정
embedding_model_name = "nlpai-lab/KURE-v1"

with log_step(f"Embedding model load: {embedding_model_name}"):
    try:
        # 우선 GPU(CUDA) 로드 시도
        embedding_model = SentenceTransformer(embedding_model_name)
        print("💡 GPU 메모리에 KURE-v1 로드 완료")
    except torch.cuda.OutOfMemoryError:
        # 만약 정리가 안 된 상태여서 OOM이 또 터지면 안전하게 CPU로 우회
        print("⚠️ GPU 메모리가 부족하여 CPU로 우회 로드합니다.")
        embedding_model = SentenceTransformer(embedding_model_name, device="cpu")

print("Embedding model loaded:", embedding_model_name)
# Out:
# [Embedding model load: nlpai-lab/KURE-v1] start
# 💡 GPU 메모리에 KURE-v1 로드 완료
# [Embedding model load: nlpai-lab/KURE-v1] done | elapsed=12s
# Embedding model loaded: nlpai-lab/KURE-v1

# %%
from sentence_transformers import SentenceTransformer

embedding_model_name = BASELINE_CONFIG["embedding_model_name"]

with log_step(f"Embedding model load: {embedding_model_name}"):
    embedding_model = SentenceTransformer(embedding_model_name)

print("Embedding model loaded:", embedding_model_name)
# Out:
# [Embedding model load: nlpai-lab/KURE-v1] start
# [Embedding model load: nlpai-lab/KURE-v1] done | elapsed=2s
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[12], line 6
#       2
#       3 embedding_model_name = BASELINE_CONFIG["embedding_model_name"]
#       4
#       5 with log_step(f"Embedding model load: {embedding_model_name}"):
# ----> 6     embedding_model = SentenceTransformer(embedding_model_name)
#       7
#       8 print("Embedding model loaded:", embedding_model_name)
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\sentence_transformers\util\decorators.py:41, in deprecated_kwargs.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      39         else:
#      40             kwargs.pop(old_name)
# ---> 41 return func(*args, **kwargs)
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\sentence_transformers\sentence_transformer\model.py:184, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, model_kwargs, processor_kwargs, config_kwargs, model_card_data, backend, similarity_fn_name, truncate_dim)
#     179         raise ValueError(
#     180             "Both `token` and `use_auth_token` are specified. Please only specify the `token` argument."
#     181         )
#     182     token = use_auth_token
# --> 184 super().__init__(
#     185     model_name_or_path=model_name_or_path,
#     186     modules=modules,
#     187     device=device,
#     188     cache_folder=cache_folder,
#     189     trust_remote_code=trust_remote_code,
#     190     revision=revision,
#     191     local_files_only=local_files_only,
#     192     token=token,
#     193     model_kwargs=model_kwargs,
#     194     processor_kwargs=processor_kwargs,
#     195     config_kwargs=config_kwargs,
#     196     model_card_data=model_card_data,
#     197     backend=backend,
#     198     prompts=prompts,
#     199     default_prompt_name=default_prompt_name,
#     200 )
#     201 self.model_card_data: SentenceTransformerModelCardData
#     203 # Handle INSTRUCTOR models
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\sentence_transformers\base\model.py:204, in BaseModel.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, cache_folder, trust_remote_code, revision, local_files_only, token, model_kwargs, processor_kwargs, config_kwargs, model_card_data, backend)
#     201         model_name_or_path = f"{self.default_huggingface_organization}/{model_name_or_path}"
#     203 if model_name_or_path:
# --> 204     modules, self.module_kwargs = self._load_modules(
#     205         model_name_or_path,
#     206         token=token,
#     207         cache_folder=cache_folder,
#     208         revision=revision,
#     209         trust_remote_code=trust_remote_code,
#     210         local_files_only=local_files_only,
#     211         model_kwargs=model_kwargs,
#     212         processor_kwargs=processor_kwargs,
#     213         config_kwargs=config_kwargs,
#     214     )
#     216 if modules is not None and not isinstance(modules, OrderedDict):
#     217     modules = OrderedDict([(str(idx), module) for idx, module in enumerate(modules)])
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\sentence_transformers\base\model.py:993, in BaseModel._load_modules(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, processor_kwargs, config_kwargs)
#     991 if model_type_being_loaded == self.model_type:
#     992     logger.info(f"Loading {self.model_type} model from {model_name_or_path}.")
# --> 993     return self._load_config_modules(model_name_or_path, **load_kwargs)
#     995 logger.info(f"Converting {model_type_being_loaded} model {model_name_or_path} to {self.model_type}.")
#     996 return self._load_converted_modules(model_name_or_path, **load_kwargs, model_type=model_type_being_loaded)
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\sentence_transformers\base\model.py:1199, in BaseModel._load_config_modules(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, processor_kwargs, config_kwargs)
#    1194         module = module_class.load(local_path)
#    1196 else:
#    1197     # Newer modules that support the new loading method are loaded with the new style
#    1198     # i.e. with many keyword arguments that can optionally be used by the modules
# -> 1199     module = module_class.load(
#    1200         model_name_or_path,
#    1201         # Loading-specific keyword arguments
#    1202         subfolder=module_config["path"],
#    1203         token=token,
#    1204         cache_folder=cache_folder,
#    1205         revision=revision,
#    1206         local_files_only=local_files_only,
#    1207         # Module-specific keyword arguments
#    1208         trust_remote_code=trust_remote_code,
#    1209         model_kwargs=model_kwargs,
#    1210         processor_kwargs=processor_kwargs,
#    1211         config_kwargs=config_kwargs,
#    1212         backend=self.backend,
#    1213     )
#    1215 modules[module_config["name"]] = module
#    1216 module_kwargs[module_config["name"]] = module_config.get("kwargs", [])
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\sentence_transformers\base\modules\transformer.py:1793, in Transformer.load(cls, model_name_or_path, subfolder, token, cache_folder, revision, local_files_only, trust_remote_code, model_kwargs, processor_kwargs, config_kwargs, backend, **kwargs)
#    1779 """Load a Transformer module from a pretrained model directory or Hugging Face model name."""
#    1780 init_kwargs = cls._load_init_kwargs(
#    1781     model_name_or_path=model_name_or_path,
#    1782     subfolder=subfolder,
#    (...)   1791     backend=backend,
#    1792 )
# -> 1793 return cls(model_name_or_path=model_name_or_path, **init_kwargs)
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\sentence_transformers\util\decorators.py:87, in transformer_kwargs_decorator.<locals>.wrapper(*args, **kwargs)
#      84             kwargs.setdefault(dict_name, {})
#      85             kwargs[dict_name].setdefault("cache_dir", cache_dir)
# ---> 87 return func(*args, **kwargs)
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\sentence_transformers\base\modules\transformer.py:645, in Transformer.__init__(self, model_name_or_path, transformer_task, model_kwargs, processor_kwargs, config_kwargs, processing_kwargs, backend, modality_config, module_output_name, unpad_inputs, max_seq_length, do_lower_case, tokenizer_name_or_path)
#     633 if (
#     634     transformer_task == "sequence-classification"
#     635     and "num_labels" not in config_kwargs
#    (...)    641     # If we're loading a model for sequence-classification, but the base architecture is not for sequence-classification,
#     642     # and num_labels is not specified, we default to 1 label for CrossEncoder-like behavior
#     643     config.num_labels = 1
# --> 645 self.model = self._load_model(
#     646     model_name_or_path, transformer_task, config, backend, is_peft_model, **model_kwargs
#     647 )
#     649 # Start from the forward signature and add common parameter names as a safety net
#     650 # for models that use **kwargs or a wrapper that hides them from the signature.
#     651 self.model_forward_params = set(inspect.signature(self.model.forward).parameters) | {
#     652     "input_ids",
#     653     "attention_mask",
#    (...)    656     "return_dict",
#     657 }
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\sentence_transformers\base\modules\transformer.py:1499, in Transformer._load_model(self, model_name_or_path, transformer_task, config, backend, is_peft_model, **model_kwargs)
#    1496             return model
#    1498     model_cls = TRANSFORMER_TASK_TO_AUTO_MODEL[transformer_task]
# -> 1499     return model_cls.from_pretrained(model_name_or_path, config=config, **model_kwargs)
#    1500 elif backend == "onnx":
#    1501     return load_onnx_model(
#    1502         model_name_or_path=model_name_or_path,
#    1503         config=config,
#    1504         task_name=transformer_task,
#    1505         **model_kwargs,
#    1506     )
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\transformers\models\auto\auto_factory.py:600, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     598     if model_class.config_class == config.sub_configs.get("text_config", None):
#     599         config = config.get_text_config()
# --> 600     return model_class.from_pretrained(
#     601         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     602     )
#     603 raise ValueError(
#     604     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     605     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     606 )
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\transformers\modeling_utils.py:317, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     315 old_dtype = torch.get_default_dtype()
#     316 try:
# --> 317     return func(*args, **kwargs)
#     318 finally:
#     319     torch.set_default_dtype(old_dtype)
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\transformers\modeling_utils.py:4953, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4945 is_from_file = pretrained_model_name_or_path is not None or gguf_file is not None
#    4947 if (
#    4948     is_safetensors_available()
#    4949     and is_from_file
#    4950     and not is_sharded
#    4951     and checkpoint_files[0].endswith(".safetensors")
#    4952 ):
# -> 4953     with safe_open(checkpoint_files[0], framework="pt") as f:
#    4954         metadata = f.metadata()
#    4956     if metadata is None:
#    4957         # Assume it's a pytorch checkpoint (introduced for timm checkpoints)
#
# OSError: 이 작업을 완료하기 위한 페이징 파일이 너무 작습니다. (os error 1455)

# %% [markdown]
# # Cell 8. FAISS 인덱스 생성 함수

# %%
import faiss


def build_faiss_index(
    chunks: List[Dict[str, Any]],
    embedding_model: SentenceTransformer,
    batch_size: int = 32,
    log_every: int = 10,
):
    """
    청크 텍스트를 임베딩하고 FAISS IndexFlatIP 인덱스를 생성합니다.

    JupyterHub/GCP 환경에서 tqdm 렌더링 문제가 있을 수 있으므로
    ProgressLogger 기반으로 진행 상황을 출력합니다.
    """
    texts = [chunk["text"] for chunk in chunks]

    total = len(texts)
    num_batches = (total + batch_size - 1) // batch_size

    logger = ProgressLogger(
        total=num_batches,
        desc="Embedding batches",
        log_every=log_every,
        min_interval_sec=5.0,
    )

    all_embeddings = []

    logger.start()

    for start in range(0, total, batch_size):
        end = min(start + batch_size, total)
        batch_texts = texts[start:end]

        batch_embeddings = embedding_model.encode(
            batch_texts,
            batch_size=batch_size,
            show_progress_bar=False,
            convert_to_numpy=True,
            normalize_embeddings=True,
        )

        all_embeddings.append(batch_embeddings)

        logger.update(
            1,
            message=f"chunks={end}/{total}"
        )

    logger.done(message="embedding complete")

    embeddings = np.vstack(all_embeddings).astype("float32")

    dim = embeddings.shape[1]
    index = faiss.IndexFlatIP(dim)
    index.add(embeddings)

    print("FAISS index 생성 완료")
    print("embedding shape:", embeddings.shape)
    print("FAISS ntotal:", index.ntotal)

    return index, embeddings

# %% [markdown]
# # Cell 9. FAISS 인덱스 생성/로드

# %%
import gc
import torch
import faiss
import pickle

FAISS_INDEX_PATH = BASELINE_VECTOR_DIR / "index.faiss"
CHUNK_META_PATH = BASELINE_VECTOR_DIR / "chunks.pkl"
EMBEDDING_CONFIG_PATH = BASELINE_VECTOR_DIR / "config.json"

if (
    not FORCE_REBUILD_INDEX
    and FAISS_INDEX_PATH.exists()
    and CHUNK_META_PATH.exists()
):
    with log_step("FAISS index load"):
        index = faiss.read_index(str(FAISS_INDEX_PATH))

        with open(CHUNK_META_PATH, "rb") as f:
            indexed_chunks = pickle.load(f)

else:
    print("FAISS 인덱스 새로 생성")
    
    # 1. 인덱스 생성 직전, 이전에 쌓인 GPU 가비지 캐시를 한 번 더 완벽히 청소합니다.
    gc.collect()
    torch.cuda.empty_cache()

    # 2. OOM을 방지하기 위해 batch_size를 기존 32에서 8~16 정도로 낮추어 인덱스를 생성합니다.
    #    이렇게 하면 한 번에 GPU가 처리하는 양이 줄어들어 8GB 메모리에서도 안전하게 돌아갑니다.
    index, embeddings = build_faiss_index(
        chunks=standard_chunks,
        embedding_model=embedding_model,
        batch_size=8,  # 임베딩 중 OOM 방지를 위해 32 -> 8로 하향 조정
        log_every=10,
    )

    indexed_chunks = standard_chunks

    with log_step("FAISS index save"):
        faiss.write_index(index, str(FAISS_INDEX_PATH))

        with open(CHUNK_META_PATH, "wb") as f:
            pickle.dump(indexed_chunks, f)

        save_json(BASELINE_CONFIG, EMBEDDING_CONFIG_PATH)

    # 3. 큰 연산(인덱스 생성)이 끝난 후 사용이 끝난 대용량 embeddings 리스트 등을 메모리에서 해제합니다.
    if 'embeddings' in locals():
        del embeddings
    gc.collect()
    torch.cuda.empty_cache()

print("인덱스 청크 수:", len(indexed_chunks))
print("FAISS ntotal:", index.ntotal)
# Out:
# FAISS 인덱스 새로 생성
# [Embedding batches] start | total=1798
# [Embedding batches] 1/1798 (0.1%) | elapsed=3s | eta=1h 41m 2s | chunks=8/14377
# [Embedding batches] 10/1798 (0.6%) | elapsed=6s | eta=18m 8s | chunks=80/14377
# [Embedding batches] 20/1798 (1.1%) | elapsed=9s | eta=13m 57s | chunks=160/14377
# [Embedding batches] 30/1798 (1.7%) | elapsed=12s | eta=12m 10s | chunks=240/14377
# [Embedding batches] 40/1798 (2.2%) | elapsed=13s | eta=9m 51s | chunks=320/14377
# [Embedding batches] 50/1798 (2.8%) | elapsed=16s | eta=9m 30s | chunks=400/14377
# [Embedding batches] 60/1798 (3.3%) | elapsed=20s | eta=10m 1s | chunks=480/14377
# [Embedding batches] 70/1798 (3.9%) | elapsed=24s | eta=10m 0s | chunks=560/14377
# [Embedding batches] 80/1798 (4.4%) | elapsed=27s | eta=9m 41s | chunks=640/14377
# [Embedding batches] 90/1798 (5.0%) | elapsed=30s | eta=9m 32s | chunks=720/14377
# [Embedding batches] 100/1798 (5.6%) | elapsed=32s | eta=9m 19s | chunks=800/14377
# [Embedding batches] 110/1798 (6.1%) | elapsed=36s | eta=9m 19s | chunks=880/14377
# [Embedding batches] 120/1798 (6.7%) | elapsed=39s | eta=9m 14s | chunks=960/14377
# [Embedding batches] 130/1798 (7.2%) | elapsed=40s | eta=8m 42s | chunks=1040/14377
# [Embedding batches] 140/1798 (7.8%) | elapsed=41s | eta=8m 14s | chunks=1120/14377
# [Embedding batches] 150/1798 (8.3%) | elapsed=42s | eta=7m 48s | chunks=1200/14377
# [Embedding batches] 160/1798 (8.9%) | elapsed=43s | eta=7m 28s | chunks=1280/14377
# [Embedding batches] 170/1798 (9.5%) | elapsed=46s | eta=7m 26s | chunks=1360/14377
# [Embedding batches] 180/1798 (10.0%) | elapsed=49s | eta=7m 25s | chunks=1440/14377
# [Embedding batches] 190/1798 (10.6%) | elapsed=53s | eta=7m 30s | chunks=1520/14377
# [Embedding batches] 200/1798 (11.1%) | elapsed=56s | eta=7m 35s | chunks=1600/14377
# [Embedding batches] 210/1798 (11.7%) | elapsed=58s | eta=7m 19s | chunks=1680/14377
# [Embedding batches] 220/1798 (12.2%) | elapsed=58s | eta=7m 3s | chunks=1760/14377
# [Embedding batches] 230/1798 (12.8%) | elapsed=1m 1s | eta=7m 2s | chunks=1840/14377
# [Embedding batches] 240/1798 (13.3%) | elapsed=1m 6s | eta=7m 8s | chunks=1920/14377
# [Embedding batches] 250/1798 (13.9%) | elapsed=1m 9s | eta=7m 10s | chunks=2000/14377
# [Embedding batches] 260/1798 (14.5%) | elapsed=1m 10s | eta=6m 58s | chunks=2080/14377
# [Embedding batches] 270/1798 (15.0%) | elapsed=1m 12s | eta=6m 51s | chunks=2160/14377
# [Embedding batches] 280/1798 (15.6%) | elapsed=1m 14s | eta=6m 44s | chunks=2240/14377
# [Embedding batches] 290/1798 (16.1%) | elapsed=1m 17s | eta=6m 43s | chunks=2320/14377
# [Embedding batches] 300/1798 (16.7%) | elapsed=1m 21s | eta=6m 47s | chunks=2400/14377
# [Embedding batches] 310/1798 (17.2%) | elapsed=1m 25s | eta=6m 49s | chunks=2480/14377
# [Embedding batches] 320/1798 (17.8%) | elapsed=1m 27s | eta=6m 41s | chunks=2560/14377
# [Embedding batches] 330/1798 (18.4%) | elapsed=1m 29s | eta=6m 39s | chunks=2640/14377
# [Embedding batches] 340/1798 (18.9%) | elapsed=1m 32s | eta=6m 36s | chunks=2720/14377
# [Embedding batches] 350/1798 (19.5%) | elapsed=1m 37s | eta=6m 43s | chunks=2800/14377
# [Embedding batches] 360/1798 (20.0%) | elapsed=1m 40s | eta=6m 41s | chunks=2880/14377
# [Embedding batches] 370/1798 (20.6%) | elapsed=1m 43s | eta=6m 40s | chunks=2960/14377
# [Embedding batches] 380/1798 (21.1%) | elapsed=1m 45s | eta=6m 33s | chunks=3040/14377
# [Embedding batches] 390/1798 (21.7%) | elapsed=1m 47s | eta=6m 28s | chunks=3120/14377
# [Embedding batches] 400/1798 (22.2%) | elapsed=1m 50s | eta=6m 27s | chunks=3200/14377
# [Embedding batches] 410/1798 (22.8%) | elapsed=1m 53s | eta=6m 23s | chunks=3280/14377
# [Embedding batches] 420/1798 (23.4%) | elapsed=1m 56s | eta=6m 22s | chunks=3360/14377
# [Embedding batches] 430/1798 (23.9%) | elapsed=2m 0s | eta=6m 24s | chunks=3440/14377
# [Embedding batches] 440/1798 (24.5%) | elapsed=2m 5s | eta=6m 26s | chunks=3520/14377
# [Embedding batches] 450/1798 (25.0%) | elapsed=2m 9s | eta=6m 28s | chunks=3600/14377
# [Embedding batches] 460/1798 (25.6%) | elapsed=2m 10s | eta=6m 20s | chunks=3680/14377
# [Embedding batches] 470/1798 (26.1%) | elapsed=2m 13s | eta=6m 16s | chunks=3760/14377
# [Embedding batches] 480/1798 (26.7%) | elapsed=2m 17s | eta=6m 16s | chunks=3840/14377
# [Embedding batches] 490/1798 (27.3%) | elapsed=2m 21s | eta=6m 19s | chunks=3920/14377
# [Embedding batches] 499/1798 (27.8%) | elapsed=2m 27s | eta=6m 22s | chunks=3992/14377
# [Embedding batches] 500/1798 (27.8%) | elapsed=2m 27s | eta=6m 22s | chunks=4000/14377
# [Embedding batches] 510/1798 (28.4%) | elapsed=2m 31s | eta=6m 23s | chunks=4080/14377
# [Embedding batches] 520/1798 (28.9%) | elapsed=2m 35s | eta=6m 21s | chunks=4160/14377
# [Embedding batches] 530/1798 (29.5%) | elapsed=2m 38s | eta=6m 19s | chunks=4240/14377
# [Embedding batches] 540/1798 (30.0%) | elapsed=2m 40s | eta=6m 13s | chunks=4320/14377
# [Embedding batches] 550/1798 (30.6%) | elapsed=2m 43s | eta=6m 11s | chunks=4400/14377
# [Embedding batches] 560/1798 (31.1%) | elapsed=2m 47s | eta=6m 9s | chunks=4480/14377
# [Embedding batches] 570/1798 (31.7%) | elapsed=2m 49s | eta=6m 5s | chunks=4560/14377
# [Embedding batches] 580/1798 (32.3%) | elapsed=2m 53s | eta=6m 4s | chunks=4640/14377
# [Embedding batches] 590/1798 (32.8%) | elapsed=2m 56s | eta=6m 1s | chunks=4720/14377
# [Embedding batches] 599/1798 (33.3%) | elapsed=3m 1s | eta=6m 3s | chunks=4792/14377
# [Embedding batches] 600/1798 (33.4%) | elapsed=3m 1s | eta=6m 2s | chunks=4800/14377
# [Embedding batches] 608/1798 (33.8%) | elapsed=3m 6s | eta=6m 5s | chunks=4864/14377
# [Embedding batches] 610/1798 (33.9%) | elapsed=3m 7s | eta=6m 5s | chunks=4880/14377
# [Embedding batches] 620/1798 (34.5%) | elapsed=3m 10s | eta=6m 2s | chunks=4960/14377
# [Embedding batches] 630/1798 (35.0%) | elapsed=3m 12s | eta=5m 56s | chunks=5040/14377
# [Embedding batches] 640/1798 (35.6%) | elapsed=3m 14s | eta=5m 52s | chunks=5120/14377
# [Embedding batches] 650/1798 (36.2%) | elapsed=3m 19s | eta=5m 51s | chunks=5200/14377
# [Embedding batches] 660/1798 (36.7%) | elapsed=3m 21s | eta=5m 46s | chunks=5280/14377
# [Embedding batches] 670/1798 (37.3%) | elapsed=3m 24s | eta=5m 45s | chunks=5360/14377
# [Embedding batches] 680/1798 (37.8%) | elapsed=3m 29s | eta=5m 44s | chunks=5440/14377
# [Embedding batches] 689/1798 (38.3%) | elapsed=3m 34s | eta=5m 45s | chunks=5512/14377
# [Embedding batches] 690/1798 (38.4%) | elapsed=3m 35s | eta=5m 45s | chunks=5520/14377
# [Embedding batches] 700/1798 (38.9%) | elapsed=3m 38s | eta=5m 43s | chunks=5600/14377
# [Embedding batches] 710/1798 (39.5%) | elapsed=3m 43s | eta=5m 41s | chunks=5680/14377
# [Embedding batches] 720/1798 (40.0%) | elapsed=3m 44s | eta=5m 36s | chunks=5760/14377
# [Embedding batches] 730/1798 (40.6%) | elapsed=3m 46s | eta=5m 31s | chunks=5840/14377
# [Embedding batches] 740/1798 (41.2%) | elapsed=3m 49s | eta=5m 28s | chunks=5920/14377
# [Embedding batches] 750/1798 (41.7%) | elapsed=3m 51s | eta=5m 23s | chunks=6000/14377
# [Embedding batches] 760/1798 (42.3%) | elapsed=3m 54s | eta=5m 20s | chunks=6080/14377
# [Embedding batches] 770/1798 (42.8%) | elapsed=3m 56s | eta=5m 15s | chunks=6160/14377
# [Embedding batches] 780/1798 (43.4%) | elapsed=3m 58s | eta=5m 10s | chunks=6240/14377
# [Embedding batches] 790/1798 (43.9%) | elapsed=4m 0s | eta=5m 6s | chunks=6320/14377
# [Embedding batches] 800/1798 (44.5%) | elapsed=4m 1s | eta=5m 1s | chunks=6400/14377
# [Embedding batches] 810/1798 (45.1%) | elapsed=4m 2s | eta=4m 55s | chunks=6480/14377
# [Embedding batches] 820/1798 (45.6%) | elapsed=4m 5s | eta=4m 52s | chunks=6560/14377
# [Embedding batches] 830/1798 (46.2%) | elapsed=4m 10s | eta=4m 51s | chunks=6640/14377
# [Embedding batches] 840/1798 (46.7%) | elapsed=4m 16s | eta=4m 52s | chunks=6720/14377
# [Embedding batches] 850/1798 (47.3%) | elapsed=4m 21s | eta=4m 51s | chunks=6800/14377
# [Embedding batches] 860/1798 (47.8%) | elapsed=4m 26s | eta=4m 50s | chunks=6880/14377
# [Embedding batches] 870/1798 (48.4%) | elapsed=4m 31s | eta=4m 50s | chunks=6960/14377
# [Embedding batches] 880/1798 (48.9%) | elapsed=4m 36s | eta=4m 48s | chunks=7040/14377
# [Embedding batches] 890/1798 (49.5%) | elapsed=4m 40s | eta=4m 46s | chunks=7120/14377
# [Embedding batches] 900/1798 (50.1%) | elapsed=4m 43s | eta=4m 42s | chunks=7200/14377
# [Embedding batches] 909/1798 (50.6%) | elapsed=4m 48s | eta=4m 41s | chunks=7272/14377
# [Embedding batches] 910/1798 (50.6%) | elapsed=4m 48s | eta=4m 41s | chunks=7280/14377
# [Embedding batches] 920/1798 (51.2%) | elapsed=4m 51s | eta=4m 38s | chunks=7360/14377
# [Embedding batches] 930/1798 (51.7%) | elapsed=4m 55s | eta=4m 35s | chunks=7440/14377
# [Embedding batches] 940/1798 (52.3%) | elapsed=5m 1s | eta=4m 34s | chunks=7520/14377
# [Embedding batches] 950/1798 (52.8%) | elapsed=5m 3s | eta=4m 30s | chunks=7600/14377
# [Embedding batches] 960/1798 (53.4%) | elapsed=5m 6s | eta=4m 27s | chunks=7680/14377
# [Embedding batches] 970/1798 (53.9%) | elapsed=5m 8s | eta=4m 23s | chunks=7760/14377
# [Embedding batches] 978/1798 (54.4%) | elapsed=5m 13s | eta=4m 22s | chunks=7824/14377
# [Embedding batches] 980/1798 (54.5%) | elapsed=5m 14s | eta=4m 22s | chunks=7840/14377
# [Embedding batches] 990/1798 (55.1%) | elapsed=5m 17s | eta=4m 19s | chunks=7920/14377
# [Embedding batches] 1000/1798 (55.6%) | elapsed=5m 20s | eta=4m 15s | chunks=8000/14377
# [Embedding batches] 1010/1798 (56.2%) | elapsed=5m 21s | eta=4m 11s | chunks=8080/14377
# [Embedding batches] 1020/1798 (56.7%) | elapsed=5m 25s | eta=4m 8s | chunks=8160/14377
# [Embedding batches] 1030/1798 (57.3%) | elapsed=5m 27s | eta=4m 4s | chunks=8240/14377
# [Embedding batches] 1039/1798 (57.8%) | elapsed=5m 32s | eta=4m 3s | chunks=8312/14377
# [Embedding batches] 1040/1798 (57.8%) | elapsed=5m 33s | eta=4m 2s | chunks=8320/14377
# [Embedding batches] 1050/1798 (58.4%) | elapsed=5m 34s | eta=3m 58s | chunks=8400/14377
# [Embedding batches] 1060/1798 (59.0%) | elapsed=5m 37s | eta=3m 55s | chunks=8480/14377
# [Embedding batches] 1070/1798 (59.5%) | elapsed=5m 40s | eta=3m 51s | chunks=8560/14377
# [Embedding batches] 1080/1798 (60.1%) | elapsed=5m 43s | eta=3m 48s | chunks=8640/14377
# [Embedding batches] 1090/1798 (60.6%) | elapsed=5m 45s | eta=3m 44s | chunks=8720/14377
# [Embedding batches] 1100/1798 (61.2%) | elapsed=5m 47s | eta=3m 40s | chunks=8800/14377
# [Embedding batches] 1110/1798 (61.7%) | elapsed=5m 50s | eta=3m 37s | chunks=8880/14377
# [Embedding batches] 1120/1798 (62.3%) | elapsed=5m 51s | eta=3m 33s | chunks=8960/14377
# [Embedding batches] 1130/1798 (62.8%) | elapsed=5m 56s | eta=3m 30s | chunks=9040/14377
# [Embedding batches] 1140/1798 (63.4%) | elapsed=5m 58s | eta=3m 26s | chunks=9120/14377
# [Embedding batches] 1149/1798 (63.9%) | elapsed=6m 3s | eta=3m 25s | chunks=9192/14377
# [Embedding batches] 1150/1798 (64.0%) | elapsed=6m 4s | eta=3m 25s | chunks=9200/14377
# [Embedding batches] 1160/1798 (64.5%) | elapsed=6m 7s | eta=3m 21s | chunks=9280/14377
# [Embedding batches] 1170/1798 (65.1%) | elapsed=6m 10s | eta=3m 18s | chunks=9360/14377
# [Embedding batches] 1180/1798 (65.6%) | elapsed=6m 14s | eta=3m 16s | chunks=9440/14377
# [Embedding batches] 1190/1798 (66.2%) | elapsed=6m 17s | eta=3m 13s | chunks=9520/14377
# [Embedding batches] 1200/1798 (66.7%) | elapsed=6m 21s | eta=3m 10s | chunks=9600/14377
# [Embedding batches] 1210/1798 (67.3%) | elapsed=6m 24s | eta=3m 6s | chunks=9680/14377
# [Embedding batches] 1220/1798 (67.9%) | elapsed=6m 28s | eta=3m 4s | chunks=9760/14377
# [Embedding batches] 1230/1798 (68.4%) | elapsed=6m 32s | eta=3m 1s | chunks=9840/14377
# [Embedding batches] 1240/1798 (69.0%) | elapsed=6m 34s | eta=2m 57s | chunks=9920/14377
# [Embedding batches] 1250/1798 (69.5%) | elapsed=6m 37s | eta=2m 54s | chunks=10000/14377
# [Embedding batches] 1260/1798 (70.1%) | elapsed=6m 40s | eta=2m 50s | chunks=10080/14377
# [Embedding batches] 1270/1798 (70.6%) | elapsed=6m 44s | eta=2m 48s | chunks=10160/14377
# [Embedding batches] 1277/1798 (71.0%) | elapsed=6m 49s | eta=2m 47s | chunks=10216/14377
# [Embedding batches] 1280/1798 (71.2%) | elapsed=6m 50s | eta=2m 46s | chunks=10240/14377
# [Embedding batches] 1290/1798 (71.7%) | elapsed=6m 54s | eta=2m 43s | chunks=10320/14377
# [Embedding batches] 1300/1798 (72.3%) | elapsed=6m 58s | eta=2m 40s | chunks=10400/14377
# [Embedding batches] 1310/1798 (72.9%) | elapsed=7m 1s | eta=2m 36s | chunks=10480/14377
# [Embedding batches] 1320/1798 (73.4%) | elapsed=7m 2s | eta=2m 32s | chunks=10560/14377
# [Embedding batches] 1329/1798 (73.9%) | elapsed=7m 7s | eta=2m 30s | chunks=10632/14377
# [Embedding batches] 1330/1798 (74.0%) | elapsed=7m 7s | eta=2m 30s | chunks=10640/14377
# [Embedding batches] 1340/1798 (74.5%) | elapsed=7m 11s | eta=2m 27s | chunks=10720/14377
# [Embedding batches] 1350/1798 (75.1%) | elapsed=7m 14s | eta=2m 24s | chunks=10800/14377
# [Embedding batches] 1360/1798 (75.6%) | elapsed=7m 18s | eta=2m 21s | chunks=10880/14377
# [Embedding batches] 1370/1798 (76.2%) | elapsed=7m 19s | eta=2m 17s | chunks=10960/14377
# [Embedding batches] 1380/1798 (76.8%) | elapsed=7m 21s | eta=2m 13s | chunks=11040/14377
# [Embedding batches] 1390/1798 (77.3%) | elapsed=7m 24s | eta=2m 10s | chunks=11120/14377
# [Embedding batches] 1400/1798 (77.9%) | elapsed=7m 27s | eta=2m 7s | chunks=11200/14377
# [Embedding batches] 1410/1798 (78.4%) | elapsed=7m 31s | eta=2m 4s | chunks=11280/14377
# [Embedding batches] 1420/1798 (79.0%) | elapsed=7m 34s | eta=2m 1s | chunks=11360/14377
# [Embedding batches] 1430/1798 (79.5%) | elapsed=7m 38s | eta=1m 57s | chunks=11440/14377
# [Embedding batches] 1440/1798 (80.1%) | elapsed=7m 39s | eta=1m 54s | chunks=11520/14377
# [Embedding batches] 1450/1798 (80.6%) | elapsed=7m 41s | eta=1m 50s | chunks=11600/14377
# [Embedding batches] 1460/1798 (81.2%) | elapsed=7m 42s | eta=1m 47s | chunks=11680/14377
# [Embedding batches] 1470/1798 (81.8%) | elapsed=7m 44s | eta=1m 43s | chunks=11760/14377
# [Embedding batches] 1480/1798 (82.3%) | elapsed=7m 45s | eta=1m 40s | chunks=11840/14377
# [Embedding batches] 1490/1798 (82.9%) | elapsed=7m 49s | eta=1m 36s | chunks=11920/14377
# [Embedding batches] 1500/1798 (83.4%) | elapsed=7m 52s | eta=1m 33s | chunks=12000/14377
# [Embedding batches] 1510/1798 (84.0%) | elapsed=7m 57s | eta=1m 30s | chunks=12080/14377
# [Embedding batches] 1520/1798 (84.5%) | elapsed=7m 58s | eta=1m 27s | chunks=12160/14377
# [Embedding batches] 1530/1798 (85.1%) | elapsed=7m 59s | eta=1m 24s | chunks=12240/14377
# [Embedding batches] 1540/1798 (85.7%) | elapsed=8m 3s | eta=1m 20s | chunks=12320/14377
# [Embedding batches] 1550/1798 (86.2%) | elapsed=8m 7s | eta=1m 17s | chunks=12400/14377
# [Embedding batches] 1560/1798 (86.8%) | elapsed=8m 11s | eta=1m 14s | chunks=12480/14377
# [Embedding batches] 1570/1798 (87.3%) | elapsed=8m 14s | eta=1m 11s | chunks=12560/14377
# [Embedding batches] 1580/1798 (87.9%) | elapsed=8m 19s | eta=1m 8s | chunks=12640/14377
# [Embedding batches] 1590/1798 (88.4%) | elapsed=8m 21s | eta=1m 5s | chunks=12720/14377
# [Embedding batches] 1600/1798 (89.0%) | elapsed=8m 24s | eta=1m 2s | chunks=12800/14377
# [Embedding batches] 1610/1798 (89.5%) | elapsed=8m 27s | eta=59s | chunks=12880/14377
# [Embedding batches] 1620/1798 (90.1%) | elapsed=8m 32s | eta=56s | chunks=12960/14377
# [Embedding batches] 1630/1798 (90.7%) | elapsed=8m 36s | eta=53s | chunks=13040/14377
# [Embedding batches] 1640/1798 (91.2%) | elapsed=8m 42s | eta=50s | chunks=13120/14377
# [Embedding batches] 1650/1798 (91.8%) | elapsed=8m 46s | eta=47s | chunks=13200/14377
# [Embedding batches] 1660/1798 (92.3%) | elapsed=8m 50s | eta=44s | chunks=13280/14377
# [Embedding batches] 1670/1798 (92.9%) | elapsed=8m 54s | eta=40s | chunks=13360/14377
# [Embedding batches] 1680/1798 (93.4%) | elapsed=8m 59s | eta=37s | chunks=13440/14377
# [Embedding batches] 1690/1798 (94.0%) | elapsed=9m 1s | eta=34s | chunks=13520/14377
# [Embedding batches] 1700/1798 (94.5%) | elapsed=9m 2s | eta=31s | chunks=13600/14377
# [Embedding batches] 1710/1798 (95.1%) | elapsed=9m 7s | eta=28s | chunks=13680/14377
# [Embedding batches] 1720/1798 (95.7%) | elapsed=9m 9s | eta=24s | chunks=13760/14377
# [Embedding batches] 1730/1798 (96.2%) | elapsed=9m 13s | eta=21s | chunks=13840/14377
# [Embedding batches] 1740/1798 (96.8%) | elapsed=9m 18s | eta=18s | chunks=13920/14377
# [Embedding batches] 1750/1798 (97.3%) | elapsed=9m 22s | eta=15s | chunks=14000/14377
# [Embedding batches] 1760/1798 (97.9%) | elapsed=9m 25s | eta=12s | chunks=14080/14377
# [Embedding batches] 1770/1798 (98.4%) | elapsed=9m 29s | eta=9s | chunks=14160/14377
# [Embedding batches] 1780/1798 (99.0%) | elapsed=9m 32s | eta=5s | chunks=14240/14377
# [Embedding batches] 1790/1798 (99.6%) | elapsed=9m 34s | eta=2s | chunks=14320/14377
# [Embedding batches] 1798/1798 (100.0%) | elapsed=9m 37s | eta=0s | chunks=14377/14377
# [Embedding batches] done | elapsed=9m 37s | completed=1798/1798 | embedding complete
# FAISS index 생성 완료
# embedding shape: (14377, 1024)
# FAISS ntotal: 14377
# [FAISS index save] start
# [FAISS index save] done | elapsed=0s
# 인덱스 청크 수: 14377
# FAISS ntotal: 14377

# %%
FAISS_INDEX_PATH = BASELINE_VECTOR_DIR / "index.faiss"
CHUNK_META_PATH = BASELINE_VECTOR_DIR / "chunks.pkl"
EMBEDDING_CONFIG_PATH = BASELINE_VECTOR_DIR / "config.json"

if (
    not FORCE_REBUILD_INDEX
    and FAISS_INDEX_PATH.exists()
    and CHUNK_META_PATH.exists()
):
    with log_step("FAISS index load"):
        index = faiss.read_index(str(FAISS_INDEX_PATH))

        with open(CHUNK_META_PATH, "rb") as f:
            indexed_chunks = pickle.load(f)

else:
    print("FAISS 인덱스 새로 생성")

    index, embeddings = build_faiss_index(
        chunks=standard_chunks,
        embedding_model=embedding_model,
        batch_size=32,
        log_every=10,
    )

    indexed_chunks = standard_chunks

    with log_step("FAISS index save"):
        faiss.write_index(index, str(FAISS_INDEX_PATH))

        with open(CHUNK_META_PATH, "wb") as f:
            pickle.dump(indexed_chunks, f)

        save_json(BASELINE_CONFIG, EMBEDDING_CONFIG_PATH)

print("인덱스 청크 수:", len(indexed_chunks))
print("FAISS ntotal:", index.ntotal)
# Out:
# FAISS 인덱스 새로 생성
# [Embedding batches] start | total=450
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[17], line 19
#      15
#      16 else:
#      17     print("FAISS 인덱스 새로 생성")
#      18
# ---> 19     index, embeddings = build_faiss_index(
#      20         chunks=standard_chunks,
#      21         embedding_model=embedding_model,
#      22         batch_size=32,
#
# Cell In[16], line 36, in build_faiss_index(chunks, embedding_model, batch_size, log_every)
#      32     for start in range(0, total, batch_size):
#      33         end = min(start + batch_size, total)
#      34         batch_texts = texts[start:end]
#      35
# ---> 36         batch_embeddings = embedding_model.encode(
#      37             batch_texts,
#      38             batch_size=batch_size,
#      39             show_progress_bar=False,
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\sentence_transformers\util\decorators.py:41, in deprecated_kwargs.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      39         else:
#      40             kwargs.pop(old_name)
# ---> 41 return func(*args, **kwargs)
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\sentence_transformers\sentence_transformer\model.py:657, in SentenceTransformer.encode(self, inputs, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#     653     features = self._pad_features_for_hpu(features)
#     655 features = batch_to_device(features, device)
# --> 657 out_features = self.forward(features, **kwargs)
#     658 if is_hpu:
#     659     out_features = copy.deepcopy(out_features)
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\sentence_transformers\base\model.py:492, in BaseModel.forward(self, input, **kwargs)
#     486             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#     487         module_kwargs = {
#     488             key: value
#     489             for key, value in kwargs.items()
#     490             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#     491         }
# --> 492     input = module(input, **module_kwargs)
#     493 return input
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\sentence_transformers\base\modules\transformer.py:1090, in Transformer.forward(self, features, **kwargs)
#    1087 if method_output_name is not None and "hidden_states" in method_output_name:
#    1088     filtered_kwargs["output_hidden_states"] = True
# -> 1090 model_output = model_method(**filtered_kwargs)
#    1092 embedding = model_output
#    1093 if method_output_name is not None:
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:825, in XLMRobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     818         extended_attention_mask = _prepare_4d_causal_attention_mask_for_sdpa(
#     819             attention_mask,
#     820             input_shape,
#     821             embedding_output,
#     822             past_key_values_length,
#     823         )
#     824     else:
# --> 825         extended_attention_mask = _prepare_4d_attention_mask_for_sdpa(
#     826             attention_mask, embedding_output.dtype, tgt_len=seq_length
#     827         )
#     828 else:
#     829     # We can provide a self-attention mask of dimensions [batch_size, from_seq_length, to_seq_length]
#     830     # ourselves in which case we just need to make it broadcastable to all heads.
#     831     extended_attention_mask = self.get_extended_attention_mask(attention_mask, input_shape)
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\transformers\modeling_attn_mask_utils.py:457, in _prepare_4d_attention_mask_for_sdpa(mask, dtype, tgt_len)
#     455     return None
#     456 else:
# --> 457     return AttentionMaskConverter._expand_mask(mask=mask, dtype=dtype, tgt_len=tgt_len)
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\transformers\modeling_attn_mask_utils.py:198, in AttentionMaskConverter._expand_mask(mask, dtype, tgt_len)
#     194 expanded_mask = mask[:, None, None, :].expand(bsz, 1, tgt_len, src_len).to(dtype)
#     196 inverted_mask = torch.tensor(1.0, dtype=dtype) - expanded_mask
# --> 198 return inverted_mask.masked_fill(inverted_mask.to(torch.bool), torch.finfo(dtype).min)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 228.00 MiB. GPU 0 has a total capacity of 8.00 GiB of which 4.12 GiB is free. Of the allocated memory 2.78 GiB is allocated by PyTorch, and 26.77 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# # Cell 10. 검색 함수 구현

# %%
def retrieve(
    query: str,
    top_k: int = 5,
) -> List[Dict[str, Any]]:
    """
    질문을 임베딩한 뒤 FAISS에서 top_k 청크를 검색합니다.

    반환 결과의 doc_id는 RAGEvaluator의 retrieval 평가에 사용됩니다.
    """
    query_emb = embedding_model.encode(
        [query],
        convert_to_numpy=True,
        normalize_embeddings=True,
        show_progress_bar=False,
    ).astype("float32")

    scores, indices = index.search(query_emb, top_k)

    results = []

    for rank, (score, idx) in enumerate(zip(scores[0], indices[0]), start=1):
        if idx < 0:
            continue

        chunk = indexed_chunks[int(idx)]

        results.append({
            "rank": rank,
            "score": float(score),
            "chunk_id": chunk.get("chunk_id"),
            "doc_id": chunk.get("doc_id"),
            "text": chunk.get("text", ""),
            "metadata": {
                k: v
                for k, v in chunk.items()
                if k not in {"text"}
            },
        })

    return results

# %%
# Cell 11. 검색 단일 테스트

# %%
test_question = sample_eval_dataset[0]["question"]
retrieved = retrieve(test_question, top_k=BASELINE_CONFIG["top_k"])

print("질문:", test_question)
print("정답 doc_id:", sample_eval_dataset[0]["doc_id"])
print()

for item in retrieved:
    print(
        item["rank"],
        item["score"],
        item["doc_id"],
        item["chunk_id"],
        item["text"][:100].replace("\n", " ")
    )
# Out:
# 질문: 2024년 벤처확인종합관리시스템 기능 고도화 사업에서 고도화하거나 신규로 구축하는 주요 기능은 무엇인가요?
# 정답 doc_id: 20240330003
#
# 1 0.6914678812026978 20240330003 20240330003_section_0550_00 □ 별지서식  <별지서식 1호> 2024년 벤처확인종합관리시스템 기능 고도화 용역사업 제안서 표지  <별지서식 2호> 제안요청서 수용 여부 참조표  <별지서식 3호> 일반현황 및
# 2 0.6390254497528076 20240330003 20240330003_section_0018_00 □ 추진체계  중소벤처기업부  벤처기업확인기관  (시스템 고도화 발주)  자문위원  (법률, 검수·검사 등)  사업 수행업체  벤처확인종합관리시스템 기능 고도화 수행  (복수의결권
# 3 0.6308193206787109 20240330003 20240330003_section_0019_00 □ 추진역할  구 분  역 할  중소벤처기업부  ᆞ사업총괄 운영ᆞ관리 감독  벤처기업확인기관  汤捯ᆞ벤처확인제도 운영기관  ᆞ사업계획 수립, 제안요청서 작성  ᆞ사업관리 및 검사
# 4 0.6127170920372009 20240330003 20240330003_section_0107_00 □ 요구사항 상세  가  기능 요구사항(System Function Requirement)  요구사항 고유번호  SFR-001  요구사항 분류  기능 요구사항  요구사항 명칭  사
# 5 0.6051328182220459 20240330003 20240330003_section_0551_00 □ 붙임자료  [붙임1] 청렴서약서  [붙임2] 근로자 권리보호 이행 서약서  [붙임3] 보안서약서  [붙임4] 정보화 용역사업 보안특약  [붙임5] 소프트웨어 개발사업의 적정 사

# %% [markdown]
# # Cell 12. Qwen LLM 로드

# %%
import os
import gc
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# 1. 메모리 단편화 방지 및 시스템 가비지 캐시 청소
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
gc.collect()
torch.cuda.empty_cache()

# 실제 검증 모델명 지정
llm_model_name = "Qwen/Qwen2.5-1.5B-Instruct"

print("CUDA 사용 가능:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# 2. log_step 의존성 제거 후 토크나이저 로드
print(f"[시작] Tokenizer load: {llm_model_name}")
tokenizer = AutoTokenizer.from_pretrained(
    llm_model_name,
    trust_remote_code=True,
)
print(f"[완료] Tokenizer loaded")

# 3. log_step 의존성 제거 후 LLM 모델 로드
print(f"[시작] LLM model load: {llm_model_name}")
model = AutoModelForCausalLM.from_pretrained(
    llm_model_name,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
    device_map="auto",
    low_cpu_mem_usage=True,  # 페이징 파일 부족 에러(1455) 방지
    trust_remote_code=True,
)
print(f"[완료] LLM model loaded")

model.eval()

# 4. 로드가 끝난 후 잔여 캐시 정리
gc.collect()
torch.cuda.empty_cache()

print("LLM loaded:", llm_model_name)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

llm_model_name = BASELINE_CONFIG["llm_model_name"]

print("CUDA 사용 가능:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

with log_step(f"Tokenizer load: {llm_model_name}"):
    tokenizer = AutoTokenizer.from_pretrained(
        llm_model_name,
        trust_remote_code=True,
    )

with log_step(f"LLM model load: {llm_model_name}"):
    model = AutoModelForCausalLM.from_pretrained(
        llm_model_name,
        torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
        device_map="auto",
        trust_remote_code=True,
    )

model.eval()

print("LLM loaded:", llm_model_name)
# Out:
# CUDA 사용 가능: True
# GPU: NVIDIA GeForce RTX 3070
# [Tokenizer load: Qwen/Qwen2.5-1.5B-Instruct] start
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\sooqw\.cache\huggingface\hub\models--Qwen--Qwen2.5-1.5B-Instruct. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# [Tokenizer load: Qwen/Qwen2.5-1.5B-Instruct] done | elapsed=4s
# [LLM model load: Qwen/Qwen2.5-1.5B-Instruct] start
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# [LLM model load: Qwen/Qwen2.5-1.5B-Instruct] done | elapsed=4m 44s
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[21], line 17
#      13         trust_remote_code=True,
#      14     )
#      15
#      16 with log_step(f"LLM model load: {llm_model_name}"):
# ---> 17     model = AutoModelForCausalLM.from_pretrained(
#      18         llm_model_name,
#      19         torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
#      20         device_map="auto",
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\transformers\models\auto\auto_factory.py:600, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     598     if model_class.config_class == config.sub_configs.get("text_config", None):
#     599         config = config.get_text_config()
# --> 600     return model_class.from_pretrained(
#     601         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     602     )
#     603 raise ValueError(
#     604     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     605     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     606 )
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\transformers\modeling_utils.py:317, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     315 old_dtype = torch.get_default_dtype()
#     316 try:
# --> 317     return func(*args, **kwargs)
#     318 finally:
#     319     torch.set_default_dtype(old_dtype)
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\transformers\modeling_utils.py:5074, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    5064     if dtype_orig is not None:
#    5065         torch.set_default_dtype(dtype_orig)
#    5067     (
#    5068         model,
#    5069         missing_keys,
#    5070         unexpected_keys,
#    5071         mismatched_keys,
#    5072         offload_index,
#    5073         error_msgs,
# -> 5074     ) = cls._load_pretrained_model(
#    5075         model,
#    5076         state_dict,
#    5077         checkpoint_files,
#    5078         pretrained_model_name_or_path,
#    5079         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    5080         sharded_metadata=sharded_metadata,
#    5081         device_map=device_map,
#    5082         disk_offload_folder=offload_folder,
#    5083         offload_state_dict=offload_state_dict,
#    5084         dtype=torch_dtype,
#    5085         hf_quantizer=hf_quantizer,
#    5086         keep_in_fp32_regex=keep_in_fp32_regex,
#    5087         device_mesh=device_mesh,
#    5088         key_mapping=key_mapping,
#    5089         weights_only=weights_only,
#    5090     )
#    5091 # make sure token embedding weights are still tied if needed
#    5092 model.tie_weights()
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\transformers\modeling_utils.py:5537, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, checkpoint_files, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, device_map, disk_offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_regex, device_mesh, key_mapping, weights_only)
#    5534         args_list = logging.tqdm(args_list, desc="Loading checkpoint shards")
#    5536     for args in args_list:
# -> 5537         _error_msgs, disk_offload_index, cpu_offload_index = load_shard_file(args)
#    5538         error_msgs += _error_msgs
#    5540 # Adjust offloaded weights name and save if needed
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\transformers\modeling_utils.py:962, in load_shard_file(args)
#     960 # If shard_file is "", we use the existing state_dict instead of loading it
#     961 if shard_file != "":
# --> 962     state_dict = load_state_dict(
#     963         shard_file, is_quantized=is_quantized, map_location=map_location, weights_only=weights_only
#     964     )
#     966 # Fix the key names
#     967 state_dict = {key_renaming_mapping[k]: v for k, v in state_dict.items() if k in key_renaming_mapping}
#
# File d:\codeit\RAG\RFP-RAG-Extractor\venv\Lib\site-packages\transformers\modeling_utils.py:538, in load_state_dict(checkpoint_file, is_quantized, map_location, weights_only)
#     536 # Use safetensors if possible
#     537 if checkpoint_file.endswith(".safetensors") and is_safetensors_available():
# --> 538     with safe_open(checkpoint_file, framework="pt") as f:
#     539         metadata = f.metadata()
#     541         if metadata is not None and metadata.get("format") not in ["pt", "tf", "flax", "mlx"]:
#
# OSError: 이 작업을 완료하기 위한 페이징 파일이 너무 작습니다. (os error 1455)

# %% [markdown]
# # Cell 13. RFP RAG 프롬프트 구성

# %%
def format_context(retrieved_chunks: List[Dict[str, Any]]) -> str:
    """
    검색된 청크들을 LLM 프롬프트에 넣을 context 문자열로 변환합니다.
    """
    context_blocks = []

    for item in retrieved_chunks:
        metadata = item.get("metadata", {})

        doc_id = item.get("doc_id", "")
        chunk_id = item.get("chunk_id", "")
        score = item.get("score", "")
        text = item.get("text", "")

        section_title = metadata.get("section_title", "")
        section_path = metadata.get("section_path", "")

        block = f"""
[문서 {item['rank']}]
doc_id: {doc_id}
chunk_id: {chunk_id}
score: {score}
section_title: {section_title}
section_path: {section_path}

{text}
""".strip()

        context_blocks.append(block)

    return "\n\n---\n\n".join(context_blocks)


def build_messages(
    question: str,
    retrieved_chunks: List[Dict[str, Any]]
) -> List[Dict[str, str]]:
    """
    Qwen Instruct 모델용 chat messages를 구성합니다.
    """
    context = format_context(retrieved_chunks)

    system_prompt = """
당신은 기업 및 정부 제안요청서(RFP)를 분석하는 전문 RAG Assistant입니다.
반드시 제공된 문서 내용에 근거해서만 답변하세요.

규칙:
1. 문서에 근거가 있는 내용만 답변하세요.
2. 문서에서 확인할 수 없는 내용은 추측하지 말고 "제공된 문서에서 확인할 수 없습니다."라고 답변하세요.
3. 질문이 예산, 기간, 계약방법, 담당자, 연락처처럼 정확한 값을 요구하면 값 중심으로 간결하게 답변하세요.
4. 질문이 사업범위, 추진목표, 기대효과처럼 목록형 답변을 요구하면 핵심 항목을 bullet로 정리하세요.
5. 가능하면 답변 마지막에 근거가 된 doc_id를 적으세요.
""".strip()

    user_prompt = f"""
아래는 검색된 RFP 문서 일부입니다.

[검색 문서]
{context}

[질문]
{question}

[답변]
""".strip()

    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt},
    ]

# %% [markdown]
# # Cell 14. LLM 답변 생성 함수

# %%
def generate_answer(
    question: str,
    retrieved_chunks: List[Dict[str, Any]],
    max_new_tokens: int = 512,
) -> Dict[str, Any]:
    """
    검색된 청크와 질문을 바탕으로 LLM 답변을 생성합니다.

    반환:
    - response
    - input_tokens
    - output_tokens
    - total_tokens
    - generation_latency_sec
    - prompt_text
    """
    messages = build_messages(question, retrieved_chunks)

    prompt_text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
    )

    inputs = tokenizer(
        prompt_text,
        return_tensors="pt",
    ).to(model.device)

    input_tokens = int(inputs["input_ids"].shape[-1])

    start_time = time.perf_counter()

    generation_kwargs = {
        **inputs,
        "max_new_tokens": max_new_tokens,
        "do_sample": BASELINE_CONFIG["do_sample"],
        "pad_token_id": tokenizer.eos_token_id,
    }

    if BASELINE_CONFIG["do_sample"]:
        generation_kwargs["temperature"] = BASELINE_CONFIG["temperature"]

    with torch.no_grad():
        outputs = model.generate(**generation_kwargs)

    generation_latency_sec = time.perf_counter() - start_time

    output_tokens = int(outputs.shape[-1] - inputs["input_ids"].shape[-1])

    generated_ids = outputs[0][inputs["input_ids"].shape[-1]:]

    response_text = tokenizer.decode(
        generated_ids,
        skip_special_tokens=True,
    ).strip()

    return {
        "response": response_text,
        "input_tokens": input_tokens,
        "output_tokens": output_tokens,
        "total_tokens": input_tokens + output_tokens,
        "generation_latency_sec": generation_latency_sec,
        "prompt_text": prompt_text,
    }

# %% [markdown]
# # Cell 15. 단일 RAG 실행 함수

# %%
def run_single_rag(
    eval_item: Dict[str, Any],
    top_k: int = 5,
) -> Dict[str, Any]:
    """
    평가 문항 1개에 대해:
    1. 검색
    2. LLM 답변 생성
    3. 평가에 필요한 결과 row 생성
    """
    question = eval_item["question"]

    start_total = time.perf_counter()

    start_retrieval = time.perf_counter()
    retrieved_chunks = retrieve(question, top_k=top_k)
    retrieval_latency_sec = time.perf_counter() - start_retrieval

    generation_result = generate_answer(
        question=question,
        retrieved_chunks=retrieved_chunks,
        max_new_tokens=BASELINE_CONFIG["max_new_tokens"],
    )

    total_latency_sec = time.perf_counter() - start_total

    retrieved_ids = [
        item.get("doc_id")
        for item in retrieved_chunks
        if item.get("doc_id") is not None
    ]

    retrieved_contexts = [
        item.get("text", "")
        for item in retrieved_chunks
    ]

    result = {
        **eval_item,
        "retrieved_ids": retrieved_ids,
        "retrieved_chunks": [
            {
                "rank": item["rank"],
                "score": item["score"],
                "doc_id": item["doc_id"],
                "chunk_id": item["chunk_id"],
                "text": item["text"][:1500],
            }
            for item in retrieved_chunks
        ],
        "retrieved_contexts": retrieved_contexts,
        "response": generation_result["response"],
        "retrieval_latency_sec": retrieval_latency_sec,
        "generation_latency_sec": generation_result["generation_latency_sec"],
        "total_latency_sec": total_latency_sec,
        "input_tokens": generation_result["input_tokens"],
        "output_tokens": generation_result["output_tokens"],
        "total_tokens": generation_result["total_tokens"],

        # 현재는 로컬 모델이므로 API 비용은 0으로 둡니다.
        # API 모델 실험 시 RAGEvaluator.attach_costs()로 비용 계산 가능.
        "estimated_cost": 0.0,
    }

    return result

# %%
# Cell 16. 단일 질문 테스트

# %%
test_item = sample_eval_dataset[0]

test_result = run_single_rag(
    test_item,
    top_k=BASELINE_CONFIG["top_k"],
)

print("Q:", test_result["question"])
print()
print("A:", test_result["response"])
print()
print("Reference:", test_result["reference"])
print()
print("정답 doc_id:", test_result["doc_id"])
print("retrieved_ids:", test_result["retrieved_ids"])
print("latency:", test_result["total_latency_sec"])
# Out:
# Q: 2024년 벤처확인종합관리시스템 기능 고도화 사업에서 고도화하거나 신규로 구축하는 주요 기능은 무엇인가요?
#
# A: 2024년 벤처확인종합관리시스템 기능 고도화 사업에서 고도화하거나 신규로 구축하는 주요 기능은 다음과 같습니다:
#
# 1. **사용자 인증 기능**: 복수의결권주식 신청자/창업주/대리인 확인절차 기능 기획 및 구현, 스톡옵션 신청자/부여(대상자) 확인절차 기능 기획 및 구현, 주민등록번호 미수집에 따른 대체 인증 방안 제시, 벤처확인종합관리시스템 회원통합을 위한 인증방안 제시 및 구현, 복수의결권주식, 스톡옵션 업무 담당자 인증.
#
# 2. **회원가입 기능**: 중소벤처24 스톡옵션 신청자 회원통합 방안/기획 및 기능 구현, 중소벤처24 Easy Pass 연계, 벤처확인종합관리시스템 이관사용자와의 회원통합, 중소벤처24 스톡옵션 신청자 회원통합 이력 조회 기능 구현.
#
# 3. **중소기업확인서 기능**: 복수의결권주식 발행보고 및 스톡옵션 부여신고 前 중소기업여부 확인, 중소기업확인서 발급정보 연동, 중소기업확인서 발급정보 연동 불가시 파일업로드, 복수의결권주식 발행보고 및 스톡옵션 부여신고 신청단계 중소기업 확인 기능 구현.
#
# 4. **비상장 여부 조회 기능**: 법인등록번호 기준 비상장 조회기능 구현.
#
# 이들 기능들은 벤처확인종합관리시스템의 효율성을 높이고, 사용자 인증, 회원 관리, 중소기업 확인 등의 중요한 기능을 강화함으로써 사업의 성공을 촉진합니다.
#
# Reference: 복수의결권주식의 발행 보고 업무처리 시스템 구축, 벤처기업법에 따라 부여된 스톡옵션(주식매수선택권)의 부여·취소·철회 신고 및 업무시스템 구축, 성과조건부주식교부계약(RS)의 신고 및 업무처리 시스템 구축 등 세 가지 기능의 구축 및 고도화이다.
#
# 정답 doc_id: 20240330003
# retrieved_ids: ['20240330003', '20240330003', '20240330003', '20240330003', '20240330003']
# latency: 15.692668293020688

# %% [markdown]
# # Cell 17. 샘플 20개 전체 RAG 실행

# %%
rag_outputs = []

for item in progress_iter(
    sample_eval_dataset,
    total=len(sample_eval_dataset),
    desc="Running baseline RAG",
    log_every=1,
    min_interval_sec=0.0,
):
    try:
        result = run_single_rag(
            item,
            top_k=BASELINE_CONFIG["top_k"],
        )
        rag_outputs.append(result)

    except Exception as e:
        error_result = {
            **item,
            "retrieved_ids": [],
            "retrieved_chunks": [],
            "retrieved_contexts": [],
            "response": "",
            "error": repr(e),
            "retrieval_latency_sec": 0.0,
            "generation_latency_sec": 0.0,
            "total_latency_sec": 0.0,
            "input_tokens": 0,
            "output_tokens": 0,
            "total_tokens": 0,
            "estimated_cost": 0.0,
        }
        rag_outputs.append(error_result)

save_json(rag_outputs, RAG_OUTPUT_PATH)

print("RAG 실행 결과 저장:", RAG_OUTPUT_PATH)
print("결과 수:", len(rag_outputs))
# Out:
# [Running baseline RAG] start | total=20
# [Running baseline RAG] 1/20 (5.0%) | elapsed=15s | eta=4m 52s
# [Running baseline RAG] 2/20 (10.0%) | elapsed=16s | eta=2m 27s
# [Running baseline RAG] 3/20 (15.0%) | elapsed=17s | eta=1m 41s
# [Running baseline RAG] 4/20 (20.0%) | elapsed=21s | eta=1m 27s
# [Running baseline RAG] 5/20 (25.0%) | elapsed=23s | eta=1m 10s
# [Running baseline RAG] 6/20 (30.0%) | elapsed=31s | eta=1m 14s
# [Running baseline RAG] 7/20 (35.0%) | elapsed=32s | eta=1m 0s
# [Running baseline RAG] 8/20 (40.0%) | elapsed=37s | eta=56s
# [Running baseline RAG] 9/20 (45.0%) | elapsed=43s | eta=52s
# [Running baseline RAG] 10/20 (50.0%) | elapsed=44s | eta=44s
# [Running baseline RAG] 11/20 (55.0%) | elapsed=44s | eta=36s
# [Running baseline RAG] 12/20 (60.0%) | elapsed=46s | eta=30s
# [Running baseline RAG] 13/20 (65.0%) | elapsed=46s | eta=25s
# [Running baseline RAG] 14/20 (70.0%) | elapsed=55s | eta=23s
# [Running baseline RAG] 15/20 (75.0%) | elapsed=1m 1s | eta=20s
# [Running baseline RAG] 16/20 (80.0%) | elapsed=1m 9s | eta=17s
# [Running baseline RAG] 17/20 (85.0%) | elapsed=1m 11s | eta=12s
# [Running baseline RAG] 18/20 (90.0%) | elapsed=1m 19s | eta=8s
# [Running baseline RAG] 19/20 (95.0%) | elapsed=1m 28s | eta=4s
# [Running baseline RAG] 20/20 (100.0%) | elapsed=1m 37s | eta=0s
# [Running baseline RAG] done | elapsed=1m 37s | completed=20/20
# RAG 실행 결과 저장: /home/user1/RFP-RAG-Extractor/data/processed/eval/rag_outputs_baseline_section_sample_20.json
# 결과 수: 20

# %%
# Cell 18. RAG 실행 결과 확인

# %%
rag_df = pd.DataFrame([
    {
        "qid": row.get("qid"),
        "doc_id": row.get("doc_id"),
        "question_type": row.get("question_type"),
        "response_len": len(row.get("response", "")),
        "retrieved_ids": row.get("retrieved_ids"),
        "total_latency_sec": row.get("total_latency_sec"),
        "input_tokens": row.get("input_tokens"),
        "output_tokens": row.get("output_tokens"),
        "error": row.get("error", ""),
    }
    for row in rag_outputs
])

display(rag_df)
print("에러 개수:", rag_df["error"].astype(bool).sum())
# Out:
#                         qid         doc_id question_type  response_len  \
# 0         20240330003_llm_1    20240330003         llm_1           654
# 1   20240404154_fact_budget    20240404154   fact_budget            31
# 2         20240408682_llm_1    20240408682         llm_1            54
# 3         20240430896_llm_2    20240430896         llm_2           147
# 4   20240430918_fact_budget    20240430918   fact_budget            86
# 5         20240430918_llm_2    20240430918         llm_2           378
# 6         20240523741_llm_1    20240523741         llm_1            19
# 7         20240531285_llm_1    20240531285         llm_1           232
# 8         20240531542_llm_2    20240531542         llm_2           272
# 9   20240723270_fact_budget    20240723270   fact_budget            31
# 10  20240827859_fact_budget    20240827859   fact_budget            19
# 11        20240903688_llm_1    20240903688         llm_1            66
# 12  20240904268_fact_budget    20240904268   fact_budget            31
# 13        20240910050_llm_1    20240910050         llm_1           414
# 14        20240910050_llm_2    20240910050         llm_2           244
# 15        20241030067_llm_1    20241030067         llm_1           391
# 16  20241118572_fact_budget    20241118572   fact_budget            87
# 17        20241213403_llm_2    20241213403         llm_2           352
# 18        20241217596_llm_2    20241217596         llm_2           389
# 19      R25BK00601569_llm_1  R25BK00601569         llm_1           427
#
#                                         retrieved_ids  total_latency_sec  \
# 0   [20240330003, 20240330003, 20240330003, 202403...          15.377135
# 1   [20240404154, 20240404154, 20240404154, 202404...           1.051589
# 2   [20240408682, 20240408682, DOC_0026, 202404086...           1.444478
# 3   [20240531160, DOC_0026, 20240903676, R25BK0056...           3.956837
# 4   [20240430918, 20240430918, 20240430918, 202404...           1.525542
# 5   [R25BK00604826, 20240414353, 20240419826, 2024...           8.499642
# 6   [20240419826, 20240611568, 20241218257, 202410...           0.577121
# 7   [20240531285, 20240531013, DOC_0007, DOC_0047,...           5.139049
# 8   [20240420207, DOC_0007, 20240419826, 202406053...           5.638485
# 9   [20240812818, 20240815487, DOC_0048, 202407232...           0.980074
# 10  [20240827859, 20241217596, 20240539643, 202410...           0.637023
# 11  [20240541684, 20240539319, 20240430918, DOC_00...           1.175110
# 12  [20241217596, 20241002912, DOC_0046, 202409042...           0.966013
# 13  [20240910050, 20240910050, 20240910050, 202409...           8.844340
# 14  [20241138828, 20240430918, 20240531285, DOC_00...           5.641499
# 15  [20240903688, 20240541684, DOC_0049, DOC_0018,...           7.842709
# 16  [20241118572, 20241118572, 20241118572, 202411...           2.435167
# 17  [20240903688, DOC_0007, 20240420207, DOC_0018,...           7.606614
# 18  [20241217596, 20241217596, 20241217596, 202412...           9.376959
# 19  [20240624914, 20240524568, 20240404154, 202408...           8.628703
#
#     input_tokens  output_tokens error
# 0           2235            465
# 1           2701             26
# 2           2221             39
# 3           2462            113
# 4           3451             38
# 5           2769            248
# 6           1134             15
# 7           3703            144
# 8           1713            166
# 9           2370             24
# 10          1546             16
# 11          2838             29
# 12          1535             26
# 13          4098            255
# 14          1555            167
# 15          1147            235
# 16          5661             59
# 17          1526            226
# 18          1442            270
# 19          1604            251
# 에러 개수: 0

# %%
# Cell 19. RAGEvaluator 생성

# %%
evaluator = RAGEvaluator(
    auto_download_nltk=False,
    use_nltk_tokenizer=False,
)

print("RAGEvaluator ready")
# Out:
# RAGEvaluator ready

# %% [markdown]
# # Cell 20. 전체 평가 실행

# %%
with log_step("Evaluate all metrics"):
    metrics = evaluator.evaluate_all(
        rag_outputs,
        k=BASELINE_CONFIG["top_k"],
    )

metrics
# Out:
# [Evaluate all metrics] start
# [Evaluate all metrics] done | elapsed=28s
# {'hits@5': np.float64(0.55),
#  'precision@5': np.float64(0.11000000000000001),
#  'recall@5': np.float64(0.55),
#  'mrr@5': np.float64(0.475),
#  'retrieval_eval_count': 20,
#  'retrieval_eval_skipped_count': 0,
#  'avg_bleu': 0.009225972380367882,
#  'avg_rougeL': 0.18595238095238095,
#  'avg_token_f1': 0.07771066966892115,
#  'avg_keyword_group_recall': 0.25916666666666666,
#  'exact_keyword_group_match_rate': 0.05,
#  'avg_matched_keyword_groups': 0.95,
#  'avg_total_keyword_groups': 2.85,
#  'avg_retrieval_latency_sec': 0.027366297756088898,
#  'avg_generation_latency_sec': 4.8321209686400834,
#  'avg_total_latency_sec': 4.867204390402184,
#  'p50_total_latency_sec': 5.1390488520264626,
#  'p95_total_latency_sec': 9.376959030982107,
#  'avg_input_tokens': 2385.55,
#  'avg_output_tokens': 140.6,
#  'avg_total_tokens': 2526.15,
#  'total_tokens': 50523.0,
#  'avg_cost_per_query': 0.0,
#  'total_cost': 0.0}

# %% [markdown]
# # Cell 21. 질문 유형별 평가

# %%
with log_step("Evaluate by question_type"):
    metrics_by_question_type = evaluator.evaluate_by_group(
        rag_outputs,
        group_key="question_type",
        k=BASELINE_CONFIG["top_k"],
    )

metrics_by_question_type
# Out:
# [Evaluate by question_type] start
# [Evaluate by question_type] done | elapsed=10s
# {'llm_1': {'hits@5': np.float64(0.5),
#   'precision@5': np.float64(0.1),
#   'recall@5': np.float64(0.5),
#   'mrr@5': np.float64(0.5),
#   'retrieval_eval_count': 8,
#   'retrieval_eval_skipped_count': 0,
#   'avg_bleu': 0.017784708874941876,
#   'avg_rougeL': 0.125,
#   'avg_token_f1': 0.10391049792384062,
#   'avg_keyword_group_recall': 0.3770833333333333,
#   'exact_keyword_group_match_rate': 0.125,
#   'avg_matched_keyword_groups': 1.25,
#   'avg_total_keyword_groups': 3.375,
#   'avg_retrieval_latency_sec': 0.02715682314010337,
#   'avg_generation_latency_sec': 6.093779354385333,
#   'avg_total_latency_sec': 6.128580633492675,
#   'p50_total_latency_sec': 7.842709079035558,
#   'p95_total_latency_sec': 15.377135135931894,
#   'avg_input_tokens': 2372.5,
#   'avg_output_tokens': 179.125,
#   'avg_total_tokens': 2551.625,
#   'total_tokens': 20413.0,
#   'avg_cost_per_query': 0.0,
#   'total_cost': 0.0,
#   'num_rows': 8},
#  'fact_budget': {'hits@5': np.float64(1.0),
#   'precision@5': np.float64(0.19999999999999998),
#   'recall@5': np.float64(1.0),
#   'mrr@5': np.float64(0.75),
#   'retrieval_eval_count': 6,
#   'retrieval_eval_skipped_count': 0,
#   'avg_bleu': 0.0,
#   'avg_rougeL': 0.36984126984126986,
#   'avg_token_f1': 0.0,
#   'avg_keyword_group_recall': 0.0,
#   'exact_keyword_group_match_rate': 0.0,
#   'avg_matched_keyword_groups': 0.0,
#   'avg_total_keyword_groups': 1.0,
#   'avg_retrieval_latency_sec': 0.02793040215813865,
#   'avg_generation_latency_sec': 1.2288051931342732,
#   'avg_total_latency_sec': 1.265901156856368,
#   'p50_total_latency_sec': 0.9800741290673614,
#   'p95_total_latency_sec': 2.4351666739676148,
#   'avg_input_tokens': 2877.3333333333335,
#   'avg_output_tokens': 31.5,
#   'avg_total_tokens': 2908.8333333333335,
#   'total_tokens': 17453.0,
#   'avg_cost_per_query': 0.0,
#   'total_cost': 0.0,
#   'num_rows': 6},
#  'llm_2': {'hits@5': np.float64(0.16666666666666666),
#   'precision@5': np.float64(0.03333333333333333),
#   'recall@5': np.float64(0.16666666666666666),
#   'mrr@5': np.float64(0.16666666666666666),
#   'retrieval_eval_count': 6,
#   'retrieval_eval_skipped_count': 0,
#   'avg_bleu': 0.007040296101303772,
#   'avg_rougeL': 0.08333333333333333,
#   'avg_token_f1': 0.12048823499794968,
#   'avg_keyword_group_recall': 0.3611111111111111,
#   'exact_keyword_group_match_rate': 0.0,
#   'avg_matched_keyword_groups': 1.5,
#   'avg_total_keyword_groups': 4.0,
#   'avg_retrieval_latency_sec': 0.027081492842019845,
#   'avg_generation_latency_sec': 6.7532255631522276,
#   'avg_total_latency_sec': 6.7866726331606815,
#   'p50_total_latency_sec': 5.641499083954841,
#   'p95_total_latency_sec': 9.376959030982107,
#   'avg_input_tokens': 1911.1666666666667,
#   'avg_output_tokens': 198.33333333333334,
#   'avg_total_tokens': 2109.5,
#   'total_tokens': 12657.0,
#   'avg_cost_per_query': 0.0,
#   'total_cost': 0.0,
#   'num_rows': 6}}

# %%
evaluator.save_metrics(
    metrics_by_question_type,
    str(METRICS_BY_QTYPE_PATH),
)
# Out:
# 평가 결과 저장 완료: /home/user1/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_by_question_type.json

# %% [markdown]
# # Cell 22. source_type / answer_format / file_type별 평가

# %%
with log_step("Evaluate by source_type"):
    metrics_by_source_type = evaluator.evaluate_by_group(
        rag_outputs,
        group_key="source_type",
        k=BASELINE_CONFIG["top_k"],
    )

with log_step("Evaluate by answer_format"):
    metrics_by_answer_format = evaluator.evaluate_by_group(
        rag_outputs,
        group_key="answer_format",
        k=BASELINE_CONFIG["top_k"],
    )

with log_step("Evaluate by file_type"):
    metrics_by_file_type = evaluator.evaluate_by_group(
        rag_outputs,
        group_key="file_type",
        k=BASELINE_CONFIG["top_k"],
    )

metrics_by_source_type, metrics_by_answer_format, metrics_by_file_type
# Out:
# [Evaluate by source_type] start
# [Evaluate by source_type] done | elapsed=0s
# [Evaluate by answer_format] start
# [Evaluate by answer_format] done | elapsed=0s
# [Evaluate by file_type] start
# [Evaluate by file_type] done | elapsed=0s
# ({'document': {'hits@5': np.float64(0.35714285714285715),
#    'precision@5': np.float64(0.07142857142857142),
#    'recall@5': np.float64(0.35714285714285715),
#    'mrr@5': np.float64(0.35714285714285715),
#    'retrieval_eval_count': 14,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.013179960543382689,
#    'avg_rougeL': 0.10714285714285714,
#    'avg_token_f1': 0.11101524238417307,
#    'avg_keyword_group_recall': 0.37023809523809526,
#    'exact_keyword_group_match_rate': 0.07142857142857142,
#    'avg_matched_keyword_groups': 1.3571428571428572,
#    'avg_total_keyword_groups': 3.642857142857143,
#    'avg_retrieval_latency_sec': 0.027124538726639003,
#    'avg_generation_latency_sec': 6.376399158142574,
#    'avg_total_latency_sec': 6.41062006192182,
#    'p50_total_latency_sec': 5.641499083954841,
#    'p95_total_latency_sec': 9.376959030982107,
#    'avg_input_tokens': 2174.785714285714,
#    'avg_output_tokens': 187.35714285714286,
#    'avg_total_tokens': 2362.1428571428573,
#    'total_tokens': 33070.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 14},
#   'metadata': {'hits@5': np.float64(1.0),
#    'precision@5': np.float64(0.19999999999999998),
#    'recall@5': np.float64(1.0),
#    'mrr@5': np.float64(0.75),
#    'retrieval_eval_count': 6,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.0,
#    'avg_rougeL': 0.36984126984126986,
#    'avg_token_f1': 0.0,
#    'avg_keyword_group_recall': 0.0,
#    'exact_keyword_group_match_rate': 0.0,
#    'avg_matched_keyword_groups': 0.0,
#    'avg_total_keyword_groups': 1.0,
#    'avg_retrieval_latency_sec': 0.02793040215813865,
#    'avg_generation_latency_sec': 1.2288051931342732,
#    'avg_total_latency_sec': 1.265901156856368,
#    'p50_total_latency_sec': 0.9800741290673614,
#    'p95_total_latency_sec': 2.4351666739676148,
#    'avg_input_tokens': 2877.3333333333335,
#    'avg_output_tokens': 31.5,
#    'avg_total_tokens': 2908.8333333333335,
#    'total_tokens': 17453.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 6}},
#  {'list': {'hits@5': np.float64(0.36363636363636365),
#    'precision@5': np.float64(0.07272727272727274),
#    'recall@5': np.float64(0.36363636363636365),
#    'mrr@5': np.float64(0.36363636363636365),
#    'retrieval_eval_count': 11,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.01329462520832152,
#    'avg_rougeL': 0.09090909090909091,
#    'avg_token_f1': 0.11183222487043841,
#    'avg_keyword_group_recall': 0.3803030303030303,
#    'exact_keyword_group_match_rate': 0.09090909090909091,
#    'avg_matched_keyword_groups': 1.4545454545454546,
#    'avg_total_keyword_groups': 4.0,
#    'avg_retrieval_latency_sec': 0.02715397800784558,
#    'avg_generation_latency_sec': 7.168150004920211,
#    'avg_total_latency_sec': 7.202494519815611,
#    'p50_total_latency_sec': 7.606614031014033,
#    'p95_total_latency_sec': 15.377135135931894,
#    'avg_input_tokens': 2211.181818181818,
#    'avg_output_tokens': 211.0,
#    'avg_total_tokens': 2422.181818181818,
#    'total_tokens': 26644.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 11},
#   'money': {'hits@5': np.float64(1.0),
#    'precision@5': np.float64(0.19999999999999998),
#    'recall@5': np.float64(1.0),
#    'mrr@5': np.float64(0.75),
#    'retrieval_eval_count': 6,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.0,
#    'avg_rougeL': 0.36984126984126986,
#    'avg_token_f1': 0.0,
#    'avg_keyword_group_recall': 0.0,
#    'exact_keyword_group_match_rate': 0.0,
#    'avg_matched_keyword_groups': 0.0,
#    'avg_total_keyword_groups': 1.0,
#    'avg_retrieval_latency_sec': 0.02793040215813865,
#    'avg_generation_latency_sec': 1.2288051931342732,
#    'avg_total_latency_sec': 1.265901156856368,
#    'p50_total_latency_sec': 0.9800741290673614,
#    'p95_total_latency_sec': 2.4351666739676148,
#    'avg_input_tokens': 2877.3333333333335,
#    'avg_output_tokens': 31.5,
#    'avg_total_tokens': 2908.8333333333335,
#    'total_tokens': 17453.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 6},
#   'period': {'hits@5': np.float64(0.5),
#    'precision@5': np.float64(0.1),
#    'recall@5': np.float64(0.5),
#    'mrr@5': np.float64(0.5),
#    'retrieval_eval_count': 2,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.019139285157910454,
#    'avg_rougeL': 0.25,
#    'avg_token_f1': 0.16202945990180032,
#    'avg_keyword_group_recall': 0.5,
#    'exact_keyword_group_match_rate': 0.0,
#    'avg_matched_keyword_groups': 1.5,
#    'avg_total_keyword_groups': 3.0,
#    'avg_retrieval_latency_sec': 0.026788112067151815,
#    'avg_generation_latency_sec': 4.937220031453762,
#    'avg_total_latency_sec': 4.972060253494419,
#    'p50_total_latency_sec': 1.4444781850324944,
#    'p95_total_latency_sec': 8.499642321956344,
#    'avg_input_tokens': 2495.0,
#    'avg_output_tokens': 143.5,
#    'avg_total_tokens': 2638.5,
#    'total_tokens': 5277.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 2},
#   'summary': {'hits@5': np.float64(0.0),
#    'precision@5': np.float64(0.0),
#    'recall@5': np.float64(0.0),
#    'mrr@5': np.float64(0.0),
#    'retrieval_eval_count': 1,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.0,
#    'avg_rougeL': 0.0,
#    'avg_token_f1': 0.0,
#    'avg_keyword_group_recall': 0.0,
#    'exact_keyword_group_match_rate': 0.0,
#    'avg_matched_keyword_groups': 0.0,
#    'avg_total_keyword_groups': 1.0,
#    'avg_retrieval_latency_sec': 0.02747355995234102,
#    'avg_generation_latency_sec': 0.5454980969661847,
#    'avg_total_latency_sec': 0.57712064194493,
#    'p50_total_latency_sec': 0.57712064194493,
#    'p95_total_latency_sec': 0.57712064194493,
#    'avg_input_tokens': 1134.0,
#    'avg_output_tokens': 15.0,
#    'avg_total_tokens': 1149.0,
#    'total_tokens': 1149.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 1}},
#  {'hwp': {'hits@5': np.float64(0.5263157894736842),
#    'precision@5': np.float64(0.10526315789473686),
#    'recall@5': np.float64(0.5263157894736842),
#    'mrr@5': np.float64(0.4473684210526316),
#    'retrieval_eval_count': 19,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.009711549874071454,
#    'avg_rougeL': 0.1536340852130326,
#    'avg_token_f1': 0.08180070491465384,
#    'avg_keyword_group_recall': 0.27280701754385966,
#    'exact_keyword_group_match_rate': 0.05263157894736842,
#    'avg_matched_keyword_groups': 1.0,
#    'avg_total_keyword_groups': 2.9473684210526314,
#    'avg_retrieval_latency_sec': 0.02720077190008995,
#    'avg_generation_latency_sec': 5.033168136203465,
#    'avg_total_latency_sec': 5.068026265999499,
#    'p50_total_latency_sec': 5.1390488520264626,
#    'p95_total_latency_sec': 9.376959030982107,
#    'avg_input_tokens': 2368.9473684210525,
#    'avg_output_tokens': 146.6315789473684,
#    'avg_total_tokens': 2515.5789473684213,
#    'total_tokens': 47796.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 19},
#   'pdf': {'hits@5': np.float64(1.0),
#    'precision@5': np.float64(0.2),
#    'recall@5': np.float64(1.0),
#    'mrr@5': np.float64(1.0),
#    'retrieval_eval_count': 1,
#    'retrieval_eval_skipped_count': 0,
#    'avg_bleu': 0.0,
#    'avg_rougeL': 0.8,
#    'avg_token_f1': 0.0,
#    'avg_keyword_group_recall': 0.0,
#    'exact_keyword_group_match_rate': 0.0,
#    'avg_matched_keyword_groups': 0.0,
#    'avg_total_keyword_groups': 1.0,
#    'avg_retrieval_latency_sec': 0.030511289020068944,
#    'avg_generation_latency_sec': 1.0122247849358246,
#    'avg_total_latency_sec': 1.0515887540532276,
#    'p50_total_latency_sec': 1.0515887540532276,
#    'p95_total_latency_sec': 1.0515887540532276,
#    'avg_input_tokens': 2701.0,
#    'avg_output_tokens': 26.0,
#    'avg_total_tokens': 2727.0,
#    'total_tokens': 2727.0,
#    'avg_cost_per_query': 0.0,
#    'total_cost': 0.0,
#    'num_rows': 1}})

# %%
evaluator.save_metrics(
    metrics_by_source_type,
    str(METRICS_BY_SOURCE_TYPE_PATH),
)

evaluator.save_metrics(
    metrics_by_answer_format,
    str(METRICS_BY_ANSWER_FORMAT_PATH),
)

evaluator.save_metrics(
    metrics_by_file_type,
    str(METRICS_BY_FILE_TYPE_PATH),
)
# Out:
# 평가 결과 저장 완료: /home/user1/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_by_source_type.json
# 평가 결과 저장 완료: /home/user1/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_by_answer_format.json
# 평가 결과 저장 완료: /home/user1/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_by_file_type.json

# %% [markdown]
# # Cell 23. 검색 실패 케이스 분석

# %%
with log_step("Extract retrieval failure cases"):
    retrieval_failures = evaluator.get_retrieval_failure_cases(
        rag_outputs,
        k=BASELINE_CONFIG["top_k"],
    )

print("검색 실패 케이스 수:", len(retrieval_failures))

evaluator.save_rows_as_csv(
    retrieval_failures,
    str(RETRIEVAL_FAILURE_PATH),
)

pd.DataFrame(retrieval_failures).head()
# Out:
# [Extract retrieval failure cases] start
# [Extract retrieval failure cases] done | elapsed=0s
# 검색 실패 케이스 수: 9
# CSV 저장 완료: /home/user1/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_retrieval_failures.csv / 9건
#                  qid       doc_id question_type source_type answer_format  \
# 0  20240430896_llm_2  20240430896         llm_2    document          list
# 1  20240430918_llm_2  20240430918         llm_2    document        period
# 2  20240523741_llm_1  20240523741         llm_1    document       summary
# 3  20240531542_llm_2  20240531542         llm_2    document          list
# 4  20240903688_llm_1  20240903688         llm_1    document          list
#
#                             project_name organization  \
# 0           봉화군 재난통합관리시스템 고도화 사업(협상)(긴급)     경상북도 봉화군
# 1                   도시계획위원회 통합관리시스템 구축용역        인천광역시
# 2                  축산물이력관리시스템 개선(정보화 사업)     축산물품질평가원
# 3  (긴급)「2024년도 차세대 응급의료 상황관리시스템 구축」 위탁용역      국립중앙의료원
# 4           JST 공유대학(원) xAPI기반 LRS시스템 구축        전북대학교
#
#                                             question  \
# 0    자가진단표와 관련된 사업범위는 무엇이며, 제출해야 할 별지서식 번호는 어느 것인가요?
# 1  과업내용 변경이나 계약금액·기간 조정이 필요할 때 어떤 절차로 요청해야 하고, 그 ...
# 2                                 이 사업의 주관기관은 어디인가요?
# 3   이 사업이 추진되는 배경(주요 문제)은 무엇이고, 사업범위에는 어떤 내용이 포함되나요?
# 4                    이 사업에서 구축하려는 시스템의 기술 기반은 무엇인가요?
#
#                                            reference  \
# 0  사업범위는 자가진단표 분야에 대한 사업수행실적 평가표이며, 관련 별지서식은 별지서식...
# 1  과업내용 변경 및 계약금액·계약기간 조정이 필요하면 계약상대자는 국가기관등의 장에게...
# 2                                           축산물품질평가원
# 3  추진배경은 응급실 섭외 지연(병원 전 단계에서 치료 가능한 응급실 섭외 문제)과 병...
# 4  JST 공유대학(원) 내에 xAPI 기반의 LRS(학습기록저장소) 시스템을 구축하는...
#
#                                        retrieved_ids  \
# 0  [20240531160, DOC_0026, 20240903676, R25BK0056...
# 1  [R25BK00604826, 20240414353, 20240419826, 2024...
# 2  [20240419826, 20240611568, 20241218257, 202410...
# 3  [20240420207, DOC_0007, 20240419826, 202406053...
# 4  [20240541684, 20240539319, 20240430918, DOC_00...
#
#                                             response
# 0  자가진단표와 관련된 사업범위는 다음과 같습니다:\n\n1. 핵심투입인력 필수자격요건...
# 1  과업내용 변경이나 계약금액·기간 조정이 필요할 때, 다음과 같은 절차를 거쳐야 합니...
# 2                                주관기관은 한국건강가정진흥원입니다.
# 3  이 사업이 추진되는 배경(주요 문제)은 미술진흥법에 따른 통합미술정보시스템 구축 및...
# 4  이 사업에서 구축하려는 시스템의 기술 기반은 GIS(Geographic Inform...

# %% [markdown]
# # Cell 24. 키워드 실패 케이스 분석

# %%
with log_step("Extract keyword failure cases"):
    keyword_failures = evaluator.get_keyword_failure_cases(
        rag_outputs,
        threshold=1.0,
    )

print("키워드 실패 케이스 수:", len(keyword_failures))

evaluator.save_rows_as_csv(
    keyword_failures,
    str(KEYWORD_FAILURE_PATH),
)

pd.DataFrame(keyword_failures).head()
# Out:
# [Extract keyword failure cases] start
# [Extract keyword failure cases] done | elapsed=0s
# 키워드 실패 케이스 수: 19
# CSV 저장 완료: /home/user1/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_keyword_failures.csv / 19건
#                        qid       doc_id question_type source_type  \
# 0        20240330003_llm_1  20240330003         llm_1    document
# 1  20240404154_fact_budget  20240404154   fact_budget    metadata
# 2        20240408682_llm_1  20240408682         llm_1    document
# 3        20240430896_llm_2  20240430896         llm_2    document
# 4  20240430918_fact_budget  20240430918   fact_budget    metadata
#
#   answer_format                         project_name organization  \
# 0          list   2024년 벤처확인종합관리시스템 기능 고도화 용역사업 입찰공고    (사)벤처기업협회
# 1         money  2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 용역        서울특별시
# 2        period           2024년도 GKL  그룹웨어 시스템 구축 용역  그랜드코리아레저(주)
# 3          list         봉화군 재난통합관리시스템 고도화 사업(협상)(긴급)     경상북도 봉화군
# 4         money                 도시계획위원회 통합관리시스템 구축용역        인천광역시
#
#                                             question  \
# 0  2024년 벤처확인종합관리시스템 기능 고도화 사업에서 고도화하거나 신규로 구축하는 ...
# 1  서울특별시에서 발주한 '2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 ...
# 2                  GKL 그룹웨어 시스템 구축사업의 사업기간은 언제까지인가요?
# 3    자가진단표와 관련된 사업범위는 무엇이며, 제출해야 할 별지서식 번호는 어느 것인가요?
# 4  인천광역시에서 발주한 '도시계획위원회 통합관리시스템 구축용역' 사업의 배정 예산은 ...
#
#                                            reference  \
# 0  복수의결권주식의 발행 보고 업무처리 시스템 구축, 벤처기업법에 따라 부여된 스톡옵션...
# 1                                  493,763,000원 입니다.
# 2                                  계약일로부터 6개월 이내입니다.
# 3  사업범위는 자가진단표 분야에 대한 사업수행실적 평가표이며, 관련 별지서식은 별지서식...
# 4                                  150,000,000원 입니다.
#
#                                             response  keyword_group_recall  \
# 0  2024년 벤처확인종합관리시스템 기능 고도화 사업에서 고도화하거나 신규로 구축하는 ...              0.666667
# 1                    배정 예산은 금493,763천원(부가가치세 포함)입니다.              0.000000
# 2  GKL 그룹웨어 시스템 구축사업의 사업기간은 계약체결일로부터 6개월 (안정화 1개월...              0.500000
# 3  자가진단표와 관련된 사업범위는 다음과 같습니다:\n\n1. 핵심투입인력 필수자격요건...              0.666667
# 4  죄송합니다, 현재 문서에서는 특정 사업의 예산 정보나 배정 예산에 대한 정보가 제공...              0.000000
#
#    matched_keyword_group_count  total_keyword_group_count  \
# 0                            2                          3
# 1                            0                          1
# 2                            1                          2
# 3                            2                          3
# 4                            0                          1
#
#                                  matched_groups  \
# 0   [[복수의결권주식, 복수 의결권], [스톡옵션, 주식매수선택권, 스톡 옵션]]
# 1                                            []
# 2                    [[6개월, 6개월 이내, 6개월 이내입니다]]
# 3  [[자가진단표, 자가 진단표, 정량 평가], [사업범위, 사업수행실적 평가표]]
# 4                                            []
#
#                                missed_groups
# 0             [[성과조건부주식교부, 성과조건부주식교부계약, RS]]
# 1  [[493,763,000원, 493763000원, 4억9천3백7십6만원]]
# 2                            [[계약일로부터, 계약일]]
# 3                 [[별지서식 11호, 별지서식11호, 11호]]
# 4       [[150,000,000원, 150000000원, 1억5천만원]]

# %% [markdown]
# # Cell 25. row별 keyword score 부착 후 저장

# %%
with log_step("Attach keyword scores"):
    scored_outputs = evaluator.attach_keyword_scores(rag_outputs)

evaluator.save_rows_as_json(
    scored_outputs,
    str(RAG_OUTPUT_SCORED_PATH),
)

print("scored output 저장:", RAG_OUTPUT_SCORED_PATH)
# Out:
# [Attach keyword scores] start
# [Attach keyword scores] done | elapsed=0s
# JSON 저장 완료: /home/user1/RFP-RAG-Extractor/data/processed/eval/rag_outputs_baseline_section_sample_20_scored.json / 20건
# scored output 저장: /home/user1/RFP-RAG-Extractor/data/processed/eval/rag_outputs_baseline_section_sample_20_scored.json

# %% [markdown]
# # Cell 26. 요약 CSV 생성

# %%
summary_rows = []

for row in scored_outputs:
    retrieved_ids_topk = row.get("retrieved_ids", [])[:BASELINE_CONFIG["top_k"]]

    summary_rows.append({
        "qid": row.get("qid"),
        "doc_id": row.get("doc_id"),
        "question_type": row.get("question_type"),
        "source_type": row.get("source_type"),
        "answer_format": row.get("answer_format"),
        "file_type": row.get("file_type"),
        "project_name": row.get("project_name"),
        "organization": row.get("organization"),
        "question": row.get("question"),
        "reference": row.get("reference"),
        "response": row.get("response"),
        "retrieved_ids": json.dumps(row.get("retrieved_ids", []), ensure_ascii=False),
        "retrieval_hit": row.get("doc_id") in set(retrieved_ids_topk),
        "keyword_group_recall": row.get("keyword_group_recall"),
        "matched_keyword_group_count": row.get("matched_keyword_group_count"),
        "total_keyword_group_count": row.get("total_keyword_group_count"),
        "missed_groups": json.dumps(row.get("missed_groups", []), ensure_ascii=False),
        "retrieval_latency_sec": row.get("retrieval_latency_sec"),
        "generation_latency_sec": row.get("generation_latency_sec"),
        "total_latency_sec": row.get("total_latency_sec"),
        "input_tokens": row.get("input_tokens"),
        "output_tokens": row.get("output_tokens"),
        "error": row.get("error", ""),
    })

summary_df = pd.DataFrame(summary_rows)

summary_df.to_csv(
    SUMMARY_CSV_PATH,
    index=False,
    encoding="utf-8-sig",
)

print("요약 CSV 저장:", SUMMARY_CSV_PATH)
display(summary_df.head())
# Out:
# 요약 CSV 저장: /home/user1/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_summary.csv
#                        qid       doc_id question_type source_type  \
# 0        20240330003_llm_1  20240330003         llm_1    document
# 1  20240404154_fact_budget  20240404154   fact_budget    metadata
# 2        20240408682_llm_1  20240408682         llm_1    document
# 3        20240430896_llm_2  20240430896         llm_2    document
# 4  20240430918_fact_budget  20240430918   fact_budget    metadata
#
#   answer_format file_type                         project_name organization  \
# 0          list       hwp   2024년 벤처확인종합관리시스템 기능 고도화 용역사업 입찰공고    (사)벤처기업협회
# 1         money       pdf  2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 용역        서울특별시
# 2        period       hwp           2024년도 GKL  그룹웨어 시스템 구축 용역  그랜드코리아레저(주)
# 3          list       hwp         봉화군 재난통합관리시스템 고도화 사업(협상)(긴급)     경상북도 봉화군
# 4         money       hwp                 도시계획위원회 통합관리시스템 구축용역        인천광역시
#
#                                             question  \
# 0  2024년 벤처확인종합관리시스템 기능 고도화 사업에서 고도화하거나 신규로 구축하는 ...
# 1  서울특별시에서 발주한 '2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 ...
# 2                  GKL 그룹웨어 시스템 구축사업의 사업기간은 언제까지인가요?
# 3    자가진단표와 관련된 사업범위는 무엇이며, 제출해야 할 별지서식 번호는 어느 것인가요?
# 4  인천광역시에서 발주한 '도시계획위원회 통합관리시스템 구축용역' 사업의 배정 예산은 ...
#
#                                            reference  ...  \
# 0  복수의결권주식의 발행 보고 업무처리 시스템 구축, 벤처기업법에 따라 부여된 스톡옵션...  ...
# 1                                  493,763,000원 입니다.  ...
# 2                                  계약일로부터 6개월 이내입니다.  ...
# 3  사업범위는 자가진단표 분야에 대한 사업수행실적 평가표이며, 관련 별지서식은 별지서식...  ...
# 4                                  150,000,000원 입니다.  ...
#
#   keyword_group_recall matched_keyword_group_count  total_keyword_group_count  \
# 0             0.666667                           2                          3
# 1             0.000000                           0                          1
# 2             0.500000                           1                          2
# 3             0.666667                           2                          3
# 4             0.000000                           0                          1
#
#                                      missed_groups  retrieval_latency_sec  \
# 0             [["성과조건부주식교부", "성과조건부주식교부계약", "RS"]]               0.028735
# 1  [["493,763,000원", "493763000원", "4억9천3백7십6만원"]]               0.030511
# 2                              [["계약일로부터", "계약일"]]               0.026596
# 3                 [["별지서식 11호", "별지서식11호", "11호"]]               0.026746
# 4       [["150,000,000원", "150000000원", "1억5천만원"]]               0.027289
#
#    generation_latency_sec total_latency_sec  input_tokens  output_tokens  \
# 0               15.341774         15.377135          2235            465
# 1                1.012225          1.051589          2701             26
# 2                1.410877          1.444478          2221             39
# 3                3.922587          3.956837          2462            113
# 4                1.487514          1.525542          3451             38
#
#    error
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 23 columns]

# %% [markdown]
# # Cell 27. 주요 지표 출력

# %%
top_k = BASELINE_CONFIG["top_k"]

print("===== Baseline RAG Evaluation =====")
print(f"LLM: {BASELINE_CONFIG['llm_model_name']}")
print(f"Embedding: {BASELINE_CONFIG['embedding_model_name']}")
print(f"Vector DB: {BASELINE_CONFIG['vector_db']}")
print(f"Chunking: {BASELINE_CONFIG['chunking_strategy']}")
print(f"Top-K: {top_k}")
print(f"Sample Size: {BASELINE_CONFIG['sample_size']}")

print("\n--- Retrieval ---")
for key in [
    f"hits@{top_k}",
    f"precision@{top_k}",
    f"recall@{top_k}",
    f"mrr@{top_k}",
    "retrieval_eval_count",
    "retrieval_eval_skipped_count",
]:
    print(f"{key}: {metrics.get(key)}")

print("\n--- Generation ---")
for key in [
    "avg_bleu",
    "avg_rougeL",
    "avg_token_f1",
]:
    print(f"{key}: {metrics.get(key)}")

print("\n--- Keyword ---")
for key in [
    "avg_keyword_group_recall",
    "exact_keyword_group_match_rate",
    "avg_matched_keyword_groups",
    "avg_total_keyword_groups",
]:
    print(f"{key}: {metrics.get(key)}")

print("\n--- Efficiency ---")
for key in [
    "avg_retrieval_latency_sec",
    "avg_generation_latency_sec",
    "avg_total_latency_sec",
    "p50_total_latency_sec",
    "p95_total_latency_sec",
    "avg_input_tokens",
    "avg_output_tokens",
    "avg_total_tokens",
    "total_tokens",
    "avg_cost_per_query",
    "total_cost",
]:
    print(f"{key}: {metrics.get(key)}")

print("\n--- Failures ---")
print("retrieval_failures:", len(retrieval_failures))
print("keyword_failures:", len(keyword_failures))
# Out:
# ===== Baseline RAG Evaluation =====
# LLM: Qwen/Qwen2.5-1.5B-Instruct
# Embedding: nlpai-lab/KURE-v1
# Vector DB: FAISS
# Chunking: section
# Top-K: 5
# Sample Size: 20
#
# --- Retrieval ---
# hits@5: 0.55
# precision@5: 0.11000000000000001
# recall@5: 0.55
# mrr@5: 0.475
# retrieval_eval_count: 20
# retrieval_eval_skipped_count: 0
#
# --- Generation ---
# avg_bleu: 0.009225972380367882
# avg_rougeL: 0.18595238095238095
# avg_token_f1: 0.07771066966892115
#
# --- Keyword ---
# avg_keyword_group_recall: 0.25916666666666666
# exact_keyword_group_match_rate: 0.05
# avg_matched_keyword_groups: 0.95
# avg_total_keyword_groups: 2.85
#
# --- Efficiency ---
# avg_retrieval_latency_sec: 0.027366297756088898
# avg_generation_latency_sec: 4.8321209686400834
# avg_total_latency_sec: 4.867204390402184
# p50_total_latency_sec: 5.1390488520264626
# p95_total_latency_sec: 9.376959030982107
# avg_input_tokens: 2385.55
# avg_output_tokens: 140.6
# avg_total_tokens: 2526.15
# total_tokens: 50523.0
# avg_cost_per_query: 0.0
# total_cost: 0.0
#
# --- Failures ---
# retrieval_failures: 9
# keyword_failures: 19

# %% [markdown]
# # Cell 28. 다음 실험을 위한 메모 저장

# %%
experiment_summary = {
    "config": BASELINE_CONFIG,
    "paths": {
        "section_chunk_path": str(SECTION_CHUNK_PATH),
        "eval_dataset_path": str(EVAL_DATASET_PATH),
        "eval_sample_path": str(EVAL_SAMPLE_PATH),
        "vector_dir": str(BASELINE_VECTOR_DIR),
        "rag_output_path": str(RAG_OUTPUT_PATH),
        "metrics_path": str(METRICS_PATH),
        "summary_csv_path": str(SUMMARY_CSV_PATH),
    },
    "metrics": metrics,
    "num_rag_outputs": len(rag_outputs),
    "num_retrieval_failures": len(retrieval_failures),
    "num_keyword_failures": len(keyword_failures),
}

EXPERIMENT_SUMMARY_PATH = REPORT_DIR / "baseline_section_sample20_experiment_summary.json"

evaluator.save_metrics(
    experiment_summary,
    str(EXPERIMENT_SUMMARY_PATH),
)

print("실험 요약 저장:", EXPERIMENT_SUMMARY_PATH)
# Out:
# 평가 결과 저장 완료: /home/user1/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_experiment_summary.json
# 실험 요약 저장: /home/user1/RFP-RAG-Extractor/reports/evaluation/baseline_section_sample20_experiment_summary.json
