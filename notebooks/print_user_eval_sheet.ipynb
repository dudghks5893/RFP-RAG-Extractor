# %%
from pathlib import Path
import pandas as pd
from IPython.display import display, Markdown

# notebooks/ 기준 프로젝트 루트
PROJECT_ROOT = Path.cwd().parents[0]

csv_path = PROJECT_ROOT / "reports" / "real_user_eval_sheet.csv"

print("CSV path:", csv_path)
print("exists:", csv_path.exists())

df = pd.read_csv(csv_path)

print("shape:", df.shape)
# Out:
# CSV path: /home/user1/RFP-RAG-Extractor/reports/real_user_eval_sheet.csv
# exists: True
# shape: (8, 9)

# %%
def print_human_eval_row_full(row, idx=None):
    title = f"[{idx}] " if idx is not None else ""

    print("=" * 120)
    print(f"{title}질문")
    print("-" * 120)
    print(row.get("1. 실제 사용자 질문 (Question)", ""))

    print("\nRAG 최종 답변")
    print("-" * 120)
    print(row.get("3. RAG 최종 답변 (Response)", ""))

    print("\nRAG 참고 문서")
    print("-" * 120)
    print(row.get("2. RAG 참고 문서 (Context)", ""))

    print("\n팀원 평가")
    print("-" * 120)

    score_cols = [
        "질문 적합성 점수 (1~5)",
        "핵심 정보 포함 점수 (1~5)",
        "근거 일치성 점수 (1~5)",
        "환각 여부 (Y/N)",
        "실무 활용 가능성 점수 (1~5)",
        "코멘트",
    ]

    for col in score_cols:
        print(f"{col}: {row.get(col, '')}")

    print("=" * 120)
    print()

# %%
# 특정 행 하나만 전체 출력
print_human_eval_row_full(df.iloc[0], idx=0)
# Out:
# ========================================================================================================================
# [0] 질문
# ------------------------------------------------------------------------------------------------------------------------
# 국민연금공단이 발주한 이러닝시스템 관련 사업 요구사항을 정리해 줘.
#
# RAG 최종 답변
# ------------------------------------------------------------------------------------------------------------------------
# ### 국공연금공단이 발주한 이러닝시스템 관련 사업 요구사항 정리:
#
# 1. **요구사항 구성**
#    - **교육**:
#      - 요구사항 분류: 교육
#      - 고유번호: FUR-001
#      - 요구사항 명칭: 국민연금공단 역량 모델 기반의 TRM 제시
#      - 설명: 국민연금공단 역량 모델 기반의 TRM(Training Road Map) 제시
#
#    - **이러닝**:
#      - 요구사항 분류: 이러닝
#      - 고유번호: SFR-001
#      - 요구사항 명칭: 이러닝시스템 구축 및 관리 기본방향
#
#    - **학사관리**:
#      - 요구사항 분류: 학사관리
#      - 고유번호: LMR-001
#      - 요구사항 명칭: 학습관리시스템(LMS) 제공
#
# 2. **품질 요구사항**
#    - **품질 요구사항 - QUR**
#      - 고유번호: QUR-001
#      - 요구사항 명칭: 教育콘텐츠 평가 및 품질관리 방안 제시
#
# 3. **보안 요구사항**
#    - **보안 요구사항 - SER**
#      - 고유번호: SER-001
#      - 요구사항 명칭: 개인보안 및 정보보안
#
# 4. **기타**
#    - **프로젝트 관리 요구사항 - PMR**
#      - 고유번호: PMR-001
#      - 요구사항 명칭: 계약체결 후 수행사항
#
# 5. **제약사항**
#    - **제약사항 - COR**
#      - 고유번호: COR-001
#      - 요구사항 명칭: 저작권 및 지적재산권 보호
#
# 6. **프로젝트 지원 요구사항**
#    - **프로젝트 지원 요구사항 - PSR**
#      - 고유번호: PSR-001
#      - 요구사항 명칭: 동영상 촬영 및 실시간 강의 지원
#
# 7. **개인정보보호 및 정보보안**
#    - **개인정보보호 및 정보보안 - SER**
#      - 고유번호: SER-00
#
# RAG 참고 문서
# ------------------------------------------------------------------------------------------------------------------------
# 3. 공단의 정보보안 및 개인정보보호 정책에 반하는 행위로 야기되는 문제에 대해 민·형사상 책임을 진다.
#
# 본인은 위의 사항을 숙지하여 이를 성실히 준수할 것이며 만일 이를 위반하였을 경우 「개인정보 보호법」 및 「부정경쟁방지 및 영업비밀에 관한 법률」 등 관련 법령에 따른 민·형사상의 책임을 감수함은 물론, 공단에 끼친 손해에 대해 지체없이 변상·복구할 것을 서약합니다.
#
# 20 . . .
#
# 소속 : ɣĀ (수탁 업체명)
#
# 서약자 : (수탁업체 직원) (인)
#
# 국민연금공단 귀하
#
# 【서식#11】
#
# 근로자 권리보호 이행 서약서
#
# 당사는 국민연금공단에서 시행하는 "2024년 이러닝시스템 운영 용역" 계약업체로서 근로자(하도급업체포함)의 인권보호·고용안정·노동환경 등의 권리보호를 위해 다음 사항을 이행할 것을 서약합니다.
#
# 1. 공단의 시스템 현황
#
# □ 국민연금 정보시스템 구성도 및 인프라(H/W, S/W 등) 현황은 입찰 참가 사업자의 요청이 있는 경우 공단에서 제안서 작성에 필요하다고 판단되면 보안 서약서를 받고 담당자 입회하에 열람 가능
#
# 『행정기관 및 공공기관 정보시스템 구축.운영 지침』(행정안전부고시 제2023-27호 2023.4.13.) 제17조 참고
#
# 4. 본인은 하도급업체를 통한 사업 수행시 하도급업체로 인해 발생하는 위반사항에 대하여 모든 책임을 부담한다.
#
# 년 월 일
#
# 서 약 자 업 체 명 :
#
# (업체대표) 직 위 :
#
# 성 명 : (서명)
#
# ྠĀ ྠĀ
#
# 서약집행자 소 속 :
#
# (공단직원) 직 위 :
#
# 성 명 : (서명)
#
# 국민연금공단 이사장
#
# 【서식#8-3】
#
# 보안서약서(직원용)
#
# 본인은 년 월 일부로 「2024년 이러닝시스템 운영 용역」 관련 사업(업무)을 수행함에 있어 다음 사항을 준수할 것을 엄숙히 서약합니다.
#
# 2. 요구사항 구성
#
# 구분
#
# 요구사항 분류
#
# 고유번호
#
# 汤捯요구사항 명칭
#
# 교육
#
# 운영
#
# 기능 요구사항 - FUR
#
# FUR-001
#
# 국민연금공단 역량 모델 기반의 TRM 제시
#
# FUR-002
#
# 교육운영 방법
#
# FUR-003
#
# 교육 예상인원
#
# FUR-004
#
# 외부콘텐츠 제시 기준
#
# FUR-005
#
# 외부콘텐츠 기타 요청사항
#
# 품질 요구사항 - QUR
#
# QUR-001
#
# 교육콘텐츠 평가 및 품질관리 방안 제시
#
# 이러닝
#
# 시스템 운영
#
# 시스템 기능 요구사항 - SFR
#
# SFR-001
#
# 이러닝시스템 구축 및 관리 기본방향
#
# SFR-002
#
# 사이버(모바일)연수원 구축
#
# SFR-003
#
# "학습 이벤트" 운영
#
# SFR-004
#
# "큐레이션 서비스" 운영
#
# SFR-005
#
# "소셜러닝" 운영
#
# SFR-006
#
# "나의 학습노트" 운영
#
# SFR-007
#
# "직무지식진단" 운영
#
# SFR-008
#
# "역량진단" 운영
#
# 학사관리 요구사항 - LMR
#
# LMR-001
#
# 학습관리시스템(LMS) 제공
#
# LMR-002
#
# 학습참여 유인체계 제시
#
# 콘텐츠 개발
#
# 관리
#
# 개발 요구사항 - DER
#
# DER-001
#
# 콘텐츠 개발 범위
#
# DER-002
#
# 콘텐츠 개발 요건
#
# DER-003
#
# 콘텐츠 검사 및 검수
#
# 유지관리 수행 요구사항 - MAR
#
# MAR-001
#
# 관리 범위
#
# MAR-002
#
# 수행사항
#
# 프로젝트 지원 요구사항 - PSR
#
# PSR-001
#
# 동영상 촬영 및 실시간(화상)강의 지원
#
# 개인정보보호 및 정보보안
#
# 보안 요구사항 - SER
#
# SER-001
#
# 개인정보보호 및 정보보안
#
# 제약사항 - COR
#
# COR-001
#
# 저작권 및 지적 재산권 보호
#
# 기타
#
# 사항
#
# 프로젝트 관리 요구사항 - PMR
#
# PMR-001
#
# 계약체결 후 수행사항
#
# PMR-002
#
# 운영계획서 후 수행사항
#
# PMR-003
#
# 사업보고 및 제출서류
#
# PMR-004
#
# 대금결제 사항
#
# PMR-005
#
# 계약종료 시 수행사항
#
# PMR-006
#
# 인수인계 사항
#
# 2-1. 교육과정 운영
#
# 요구사항 분류
#
# 기능 요구사항
#
# 요구사항 고유번호
#
# FUR-001
#
# 요구사항 명칭
#
# 국민연금공단 역량 모델 기반의 TRM(Training Road Map) 제시
#
# 요구
#
# 사항
#
# 상세
#
# 설명
#
# 정의
#
# 국민연금공단 역량 모델 기반의 TRM(Training Road Map) 제시
#
# 세부
#
# 내용
#
# < 국민연금공단 역량 모델 >
#
# ◦ 공단 역량 모델(리더십, 직무, 공통)에 따른 이러닝 교육체계 수립 및 제시
#
# IV. 지원부문
#
# ▫개인정보보호, 정보보안 체계 및 재해 시 복구지원 방안 제시
#
# ▫기밀보안 체계, 위기상황 시 대책, 저작권 보호방안 제시
#
# ▫각종 데이터 및 소스코드(게시자료 포함) 인수인계 방안 제시
#
# ▫기타 과업수행의 차별화된 추가제안 제시
#
# [별지 4]
#
# 세부 기술평가기준
#
# 제안사의 실적 평가기준
#
# ▸배점 : 2점 (제안사의 이러닝시스템 운영 수행실적)
#
# 순번
#
# 이러닝 운영 용역 사업 수행 규모 및 경험
#
# 배점
#
# 1
#
# 최근 3년간('21.1.1 ~ 용역공고일) 유사한 용역으로 계약금액 2억원 이상의 용역 3개 이상
#
# 2.0
#
# 2
#
# 최근 3년간('21.1.1 ~ 용역공고일) 유사한 용역으로 계약금액 2억원 이상의 용역 2개 이상
#
# 1.7
#
# 3
#
# 최근 3년간('21.1.1 ~ 용역공고일) 유사한 용역으로 계약금액 2억원 이상의 용역 1개 이하
#
# 1.4
#
# ※ 유사 용역: 입찰공고일 기준 최근 3년 이내 준공(완료)된 공공기관 혹은 민간기업체 대상 단일계약(1건) 2억 원(VAT포함) 이상의 이러닝 위탁운영 용역 수행실적
#
# 팀원 평가
# ------------------------------------------------------------------------------------------------------------------------
# 질문 적합성 점수 (1~5): nan
# 핵심 정보 포함 점수 (1~5): nan
# 근거 일치성 점수 (1~5): nan
# 환각 여부 (Y/N): nan
# 실무 활용 가능성 점수 (1~5): nan
# 코멘트: nan
# ========================================================================================================================
